# %% [markdown]
# # 1. IMPORTS

# %%
#data_propbankbr lives within datasets
import sys
sys.path.append('../datasets/')

import re
import numpy as np
import pandas as pd 
from data_propbankbr import propbankbr_parser, propbankbr_parser2, propbankbr_argument_stats, propbankbr_split

# %%
# This dataframe has all multiple arguments on columns ARG0 ~ARG6
synthdf = propbankbr_parser()
synthdf.head()
# Out:
#   ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# 0  1  1  0    0            Brasília            Brasília   PROP        F|S
# 1  2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2  3  1  0    0           publicada            publicar  V-PCP        F|S
# 3  4  1  0    0                hoje                hoje    ADV          -
# 4  5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#   DTREE  FUNC      CTREE     PRED  ARG0 ARG1 ARG2 ARG3 ARG4 ARG5 ARG6
# 0     5  ADVL  (FCL(NP*)        -     *    *    *    *  NaN  NaN  NaN
# 1     5  SUBJ       (NP*        -  (A0*    *    *    *  NaN  NaN  NaN
# 2     2    N<  (ICL(VP*)        -     *    *    *    *  NaN  NaN  NaN
# 3     3  ADVL  (ADVP*)))        -    *)    *    *    *  NaN  NaN  NaN
# 4     0   STA      (VP*)  revelar  (V*)    *    *    *  NaN  NaN  NaN

# %%
dtreedf = propbankbr_parser2()
dtreedf.head()
# Out:
#   ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# 0  1  1  0    0            Brasília            Brasília   PROP        F|S
# 1  2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2  3  1  0    0           publicada            publicar  V-PCP        F|S
# 3  4  1  0    0                hoje                hoje    ADV          -
# 4  5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#   DTREE  FUNC      CTREE     PRED ARG0 ARG1 ARG2 ARG3  ARG4  ARG5  ARG6
# 0     5  ADVL  (FCL(NP*)        -    -    -    -    -  None  None  None
# 1     5  SUBJ       (NP*        -   A0    -    -    -  None  None  None
# 2     2    N<  (ICL(VP*)        -    -    -    -    -  None  None  None
# 3     3  ADVL  (ADVP*)))        -    -    -    -    -  None  None  None
# 4     0   STA      (VP*)  revelar    -    -    -    -  None  None  None

# %% [markdown]
#  ### 1. 1 Normalization
# Convert each record into a machine learning example i.e one argument per row
# * Filter        .: each ARG column
# * Create        .: tmp row holding the number of the argument ( for further ordering )
# * Concatenate   .: everybody afterwards by rows
# * Sort          .: reorder by S and TMP

# %%
def unstack_df(df):
    '''
        Unstack outputs
        args:
            df :DataFrame either dependency or synthatic format
        returns:
            df :DataFrame
    '''
    columns_features= df.columns[:12]
    df_feature= df.loc[:,columns_features].copy()

    dataframes=[]
    num_records=0
    for i in range(7):
        col= 'ARG{:}'.format(i)
        df_target= df[col].dropna().to_frame()
        df_arg = df_feature.join(df_target, how='right')
        df_arg = df_arg.rename(index=str, columns={col: 'ARG'})
        df_arg['TMP']=i+1
    
        num_records+=df_arg.shape[0]
        print('{:}-\tnew records: {:}\ttotal records: {:}'.format(i, df_arg.shape[0],num_records))
        dataframes.append(df_arg)

    #Concatente, sort by sentence & argument, reindex
    df = pd.concat(dataframes,axis=0)
    df.sort_values(by=['S','TMP'],axis=0 ,kind='mergesort', inplace=True)    
    df= df.reset_index(drop=True)
    df.index.names=['INDEX']
    return df

# %%
synthdf = unstack_df(synthdf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-caa1dd25c825> in <module>()
# ----> 1 synthdf = unstack_df(synthdf)
#
# <ipython-input-4-1142702c2133> in unstack_df(df)
#      15         col= 'ARG{:}'.format(i)
#      16         df_target= df[col].dropna().to_frame()
# ---> 17         df_arg = df_feature.join(df_target, how='right')
#      18         df_arg = df_arg.rename(index=str, columns={col: 'ARG'})
#      19         df_arg['TMP']=i+1
#
# ~/anaconda/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    5314         # For SparseDataFrame's benefit
#    5315         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 5316                                  rsuffix=rsuffix, sort=sort)
#    5317
#    5318     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/anaconda/envs/tensorflow/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    5329             return merge(self, other, left_on=on, how=how,
#    5330                          left_index=on is None, right_index=True,
# -> 5331                          suffixes=(lsuffix, rsuffix), sort=sort)
#    5332         else:
#    5333             if on is not None:
#
# ~/anaconda/envs/tensorflow/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      56                          copy=copy, indicator=indicator,
#      57                          validate=validate)
# ---> 58     return op.get_result()
#      59
#      60
#
# ~/anaconda/envs/tensorflow/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     586
#     587         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 588                                                      rdata.items, rsuf)
#     589
#     590         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# ~/anaconda/envs/tensorflow/lib/python3.6/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5024         if not lsuffix and not rsuffix:
#    5025             raise ValueError('columns overlap but no suffix specified: %s' %
# -> 5026                              to_rename)
#    5027
#    5028         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['ARG0'], dtype='object')

# %%
synthdf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED   ARG  TMP
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -     *    1
# 1         5  SUBJ       (NP*        0        -  (A0*    1
# 2         2    N<  (ICL(VP*)        0        -     *    1
# 3         3  ADVL  (ADVP*)))        0        -    *)    1
# 4         0   STA      (VP*)        1  revelar  (V*)    1

# %%
dtreedf = unstack_df(dtreedf)
# Out:
# 0-	new records: 69723	total records: 69723
# 1-	new records: 42159	total records: 111882
# 2-	new records: 19309	total records: 131191
# 3-	new records: 7114	total records: 138305
# 4-	new records: 2357	total records: 140662
# 5-	new records: 717	total records: 141379
# 6-	new records: 240	total records: 141619

# %%
dtreedf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED ARG  TMP
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -   -    1
# 1         5  SUBJ       (NP*        0        -  A0    1
# 2         2    N<  (ICL(VP*)        0        -   -    1
# 3         3  ADVL  (ADVP*)))        0        -   -    1
# 4         0   STA      (VP*)        1  revelar   -    1

# %% [markdown]
#  ### 1.2 FIXING EXISTING FEATURES
#  #### 1.2.1 FIXING PREDICATE
#   * __PRED__ must be non empty only when ARG is (V*)
#   * Drop column __TMP__

# %%
def fix_pred(df):
    index= (df['TMP'] == df['P_S'])
    df.loc[~index,'PRED']= '-'
    df = df.drop(labels='TMP', axis=1)
    return df

# %%
#Fix predicate 
synthdf = fix_pred(synthdf)
synthdf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED   ARG
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -     *
# 1         5  SUBJ       (NP*        0        -  (A0*
# 2         2    N<  (ICL(VP*)        0        -     *
# 3         3  ADVL  (ADVP*)))        0        -    *)
# 4         0   STA      (VP*)        1  revelar  (V*)

# %%
#Fix predicate 
dtreedf = fix_pred(dtreedf)
dtreedf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED ARG
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -   -
# 1         5  SUBJ       (NP*        0        -  A0
# 2         2    N<  (ICL(VP*)        0        -   -
# 3         3  ADVL  (ADVP*)))        0        -   -
# 4         0   STA      (VP*)        1  revelar   -

# %% [markdown]
#  #### 1.2.2 FIXING P
#   __P__ will be a range like id over the predicates.

# %%
def fix_p(df):
    P=[]
    P_S=[]
    S= list(set(df['S'].values))
    p=1

    for s in S:
        sindex=df['S'] == s
        ind= [int(x) for x in 
            df.loc[sindex,'ID'].values]
        p_s= [int(x) for x in 
            df.loc[sindex,'P_S'].values]
        l =max(ind)
        n_p= len(set(filter(lambda x : x > 0, p_s)))
        
        # redefining p_s
        for p_s in range(n_p):
            P+= l*[p]
            P_S+= l*[p_s]
            p+=1

    df['P']=P        
    df['P_S']=P_S        
    return df

# %%
synthdf = fix_p(synthdf)
synthdf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  1    0            Brasília            Brasília   PROP        F|S
# 1      2  1  1    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  1    0           publicada            publicar  V-PCP        F|S
# 3      4  1  1    0                hoje                hoje    ADV          -
# 4      5  1  1    0              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED   ARG
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -     *
# 1         5  SUBJ       (NP*        0        -  (A0*
# 2         2    N<  (ICL(VP*)        0        -     *
# 3         3  ADVL  (ADVP*)))        0        -    *)
# 4         0   STA      (VP*)        1  revelar  (V*)

# %%
synthdf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  1    0            Brasília            Brasília   PROP        F|S
# 1      2  1  1    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  1    0           publicada            publicar  V-PCP        F|S
# 3      4  1  1    0                hoje                hoje    ADV          -
# 4      5  1  1    0              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED   ARG
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -     *
# 1         5  SUBJ       (NP*        0        -  (A0*
# 2         2    N<  (ICL(VP*)        0        -     *
# 3         3  ADVL  (ADVP*)))        0        -    *)
# 4         0   STA      (VP*)        1  revelar  (V*)

# %%
synthdf.to_csv('../datasets/csvs/gs.csv', encoding='utf-8')

# %%
dtreedf = fix_p(dtreedf)
dtreedf.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  1    0            Brasília            Brasília   PROP        F|S
# 1      2  1  1    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  1    0           publicada            publicar  V-PCP        F|S
# 3      4  1  1    0                hoje                hoje    ADV          -
# 4      5  1  1    0              revela             revelar  V-FIN  PR|3S|IND
#
#       DTREE  FUNC      CTREE  IS_PRED     PRED ARG
# INDEX
# 0         5  ADVL  (FCL(NP*)        0        -   -
# 1         5  SUBJ       (NP*        0        -  A0
# 2         2    N<  (ICL(VP*)        0        -   -
# 3         3  ADVL  (ADVP*)))        0        -   -
# 4         0   STA      (VP*)        1  revelar   -

# %%
dtreedf.to_csv('../datasets/csvs/gsdtree.csv', encoding='utf-8')
