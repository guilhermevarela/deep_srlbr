# %% [markdown]
# # Corpus Words Study

# %%
# imports a sister directory: ../datasets
import sys, os 
sys.path.append(os.path.join(os.path.dirname(sys.path[0]),'datasets')) 
sys.path.append('../datasets/')

import pandas as pd 
from data_vocabularies import vocab_word2vec

INPUT_DIR= '../datasets/inputs/00'
CSV_DIR= '../datasets/csvs'

INPUT_CORPUS= '{:}/{:}'.format(CSV_DIR, 'zhou.csv')
df = pd.read_csv(INPUT_CORPUS)
df.shape
# Out:
# (141730, 18)

# %% [markdown]
# ### 1. Fetch LEMMA and Word2Vec model
#
# Under propbankbr lemmas are transformed tokens ( column 'FORM' ).
# * verbs, go to infinitive
# * plural gets converted to singular
# * multi word terms are joint by underscode '\_'. ( That comes from token )

# %%
df_lemma= df.drop_duplicates(subset='LEMMA')
lemmas=df_lemma['LEMMA'].values.tolist()
print('unique lemmas',len(lemmas))
# Out:
# unique lemmas 9071

# %%
word2vec= vocab_word2vec(dataset_name='glove_s50')

# %%
missing=[]
for lemma in lemmas:
    try:
        word2vec[lemma]
    except KeyError:
        missing.append(lemma)

print('missing lemmas:{:d}\t missing(%):{:.2f}%'.format(len(missing), 100*float(len(missing))/len(lemmas)))
# Out:
# missing lemmas:3284	 missing(%):36.20%

# %% [markdown]
# ### 2. Preprocessing
#
# Embeddings from:
# >  http://nilc.icmc.usp.br/embeddings
#
# have been trained with lower cased words.

# %% [markdown]
# #### 2.1 Lower case

# %%
lower_missing=[]
for lemma in lemmas:
    try:
        word2vec[lemma.lower()]
    except KeyError:
        lower_missing.append(lemma)

print('missing lemmas:{:d}\t missing(%):{:.2f}%'.format(len(lower_missing), 100*float(len(lower_missing))/len(lemmas)))
# Out:
# missing lemmas:2134	 missing(%):23.53%

# %% [markdown]
# #### 2.2 Remove  punctuations

# %%
import string
import re
re_punctuation= re.compile(r'[{:}]'.format(string.punctuation), re.UNICODE)

no_punctuation_missing=[]
for lemma in lower_missing:
    try:
        lemma2= re_punctuation.sub('', lemma.lower())
        word2vec[lemma2]
    except KeyError:
        no_punctuation_missing.append(lemma)

print('missing lemmas:{:d}\t missing(%):{:.2f}%'.format(len(no_punctuation_missing), 100*float(len(no_punctuation_missing))/len(lemmas)))
# Out:
# missing lemmas:1984	 missing(%):21.87%

# %% [markdown]
# #### 2.3 All numbers are mapped to zero.

# %%
re_number= re.compile(r'^\d+$')

no_number_missing=[]
for lemma in no_punctuation_missing:
    try:
        lemma2= re_punctuation.sub('', lemma.lower())
        lemma2= re_number.sub('0', lemma2)        
        word2vec[lemma2]
    except KeyError:
        no_number_missing.append(lemma)
print('missing lemmas:{:d}\t missing(%):{:.2f}%'.format(len(no_number_missing), 100*float(len(no_number_missing))/len(lemmas)))
# Out:
# missing lemmas:1584	 missing(%):17.46%

# %% [markdown]
# #### 2.4 Separate NER like from unknowns

# %%
re_uppercase= re.compile(r'[A-Z]')
ner_candidates=[]
unknowns=[]
for lemma in no_number_missing:
        if re_uppercase.match(lemma):
            ner_candidates.append(lemma)    
        else:
            unknowns.append(lemma)
print('saving unknowns')
with open('corpus-words-missing-unknowns.txt','w+',encoding="utf-8") as f:
    for word in unknowns:
        f.write('{:}\n'.format(word))
print('unknown lemmas:{:d}\t missing(%):{:.2f}%'.format(len(unknowns), 100*float(len(unknowns))/len(lemmas)))        

with open('corpus-words-missing-ner.txt','w+',encoding="utf-8") as f:
    for word in ner_candidates:
        f.write('{:}\n'.format(word))
        
print(len(ner_candidates))        

print('ner candidates lemmas:{:d}\t missing(%):{:.2f}%'.format(len(ner_candidates), 100*float(len(ner_candidates))/len(lemmas)))
# Out:
# unknown lemmas:280	 missing(%):3.09%
# ner candidates lemmas:1304	 missing(%):14.38%

# %% [markdown]
# #### 3.Manual NER
#
# Manually tagging NER entities using following pattern:
#
# John  lives in New   York  and works for the European Union
#
#
# B-PER O     O  B-LOC I-LOC O   O     O   O   B-ORG    I-ORG
#
# Use PER: person, LOC: location, ORG: organization O: nothing

# %%
ner_tag=''
with open('corpus-words-missing-ner-tags.txt','w+',encoding="utf-8") as f:
    for word in ner_candidates:
        while not(ner_tag in ['PER', 'ORG', 'LOC', 'O']):
            ner_tag= input('{:} is ''PER'', ''ORG'', ''LOC'', or ''O''?\t'.format(word))
        f.write('{:}\t{:}\n'.format(word, ner_tag))
        ner_tag=''
# Out:
# Pesquisa_Datafolha is PER, ORG, LOC, or O?	O
# Fernando_Henrique_Cardoso is PER, ORG, LOC, or O?	PER
# Confissões_de_Adolescente is PER, ORG, LOC, or O?	O
# TCF1 is PER, ORG, LOC, or O?	O
# Câmera_Manchete is PER, ORG, LOC, or O?	O
# Rede_Manchete is PER, ORG, LOC, or O?	ORG
# Ronaldo_Rosas is PER, ORG, LOC, or O?	PER
# Sônia_Pompeu is PER, ORG, LOC, or O?	{ER
# Sônia_Pompeu is PER, ORG, LOC, or O?	PER
# Ewaldo_Ruy is PER, ORG, LOC, or O?	PER
# Primeiro_Mundo is PER, ORG, LOC, or O?	O
# Free_shop is PER, ORG, LOC, or O?	O
# Lx_810 is PER, ORG, LOC, or O?	O
# Ministério_da_Fazenda is PER, ORG, LOC, or O?	ORG
# Sérgio_Danese is PER, ORG, LOC, or O?	PER
# Rubens_Ricúpero is PER, ORG, LOC, or O?	PER
# Benedito_Vieira_Pereira is PER, ORG, LOC, or O?	PER
# Suzuki_Swift is PER, ORG, LOC, or O?	O
# Herbert_Berger is PER, ORG, LOC, or O?	PER
# Honda_Civic is PER, ORG, LOC, or O?	O
# Exterminador_do_Futuro_2_-_O_Julgamento_Final is PER, ORG, LOC, or O?	O
# Alexandre_Cardoso is PER, ORG, LOC, or O?	PER
# João_Havelange is PER, ORG, LOC, or O?	PER
# Antonio_Matarrese is PER, ORG, LOC, or O?	PER
# Conferência_Internacional_sobre_Transtornos_Alimentares is PER, ORG, LOC, or O?	ORG
# Harrison_Pope is PER, ORG, LOC, or O?	PER
# Escola_de_Medicina is PER, ORG, LOC, or O?	ORG
# Alfredo_Volpi is PER, ORG, LOC, or O?	PER
# Nivaldo_Silva_Costenaro is PER, ORG, LOC, or O?	PER
# Fundação_Instituto_Brasileiro_de_Geografia_e_Estatística is PER, ORG, LOC, or O?	ORG
# British_Medical_Journal is PER, ORG, LOC, or O?	ORG
# Os_Papéis_De_FLAVIO-SHIRÓ is PER, ORG, LOC, or O?	O
# Centro_de_Coordenação_de_Operações_de_Combate_ao_Crime_Organizado is PER, ORG, LOC, or O?	ORG
# Ccocco is PER, ORG, LOC, or O?	O
# Exxon_Váldez is PER, ORG, LOC, or O?	ORG
# Aibus_300 is PER, ORG, LOC, or O?	O
# David_Campitti is PER, ORG, LOC, or O?	PER
# Projeto_Acqua is PER, ORG, LOC, or O?	O
# Carlos_EDUARDO_LINS_da_Silva is PER, ORG, LOC, or O?	PER
# Titã_2 is PER, ORG, LOC, or O?	O
# Clementine_1 is PER, ORG, LOC, or O?	O
# Organização_de_Defesa_de_Mísseis_Balísticos is PER, ORG, LOC, or O?	PER
# Luís_Eduardo_de_Assis is PER, ORG, LOC, or O?	PER
# Brasileiro_de_Fórmula_Ford is PER, ORG, LOC, or O?	ORG
# Polícia_Civil_de_Ourinhos is PER, ORG, LOC, or O?	ORG
# Jonas_Rúbio is PER, ORG, LOC, or O?	PER
# Claudirene_Contijo is PER, ORG, LOC, or O?	PER
# Celso_Antonio_Borlina is PER, ORG, LOC, or O?	PER
# Assembléia_de_Deus is PER, ORG, LOC, or O?	ORG
# São_Luiz is PER, ORG, LOC, or O?	LOC
# Organização_Internacional_do_Café is PER, ORG, LOC, or O?	ORG
# Arby\'s is PER, ORG, LOC, or O?	ORG
# Roberto_Capuano is PER, ORG, LOC, or O?	PER
# Conselho_Regional_de_Corretores_de_Imóveis is PER, ORG, LOC, or O?	ORG
# United_Collors is PER, ORG, LOC, or O?	O
# Marinko_Gagro is PER, ORG, LOC, or O?	PER
# L\'_Osservatore_Romano is PER, ORG, LOC, or O?	LOC
# Le_Figaro is PER, ORG, LOC, or O?	ORG
# Frankfurter_Allgemeine is PER, ORG, LOC, or O?	PER
# Ilmar_Galvão is PER, ORG, LOC, or O?	PER
# Moreira_Alves is PER, ORG, LOC, or O?	PER
# Sra._Oke is PER, ORG, LOC, or O?	PER
# Okehurst is PER, ORG, LOC, or O?	O
# Condenados_pelo_Vício is PER, ORG, LOC, or O?	O
# John_Fante is PER, ORG, LOC, or O?	PER
# Pergunte_ao_Pó is PER, ORG, LOC, or O?	O
# Michael_Schumacher is PER, ORG, LOC, or O?	PER
# Bernard_Nussbaum is PER, ORG, LOC, or O?	PER
# Comissão_Parlamentar_de_Inquérito is PER, ORG, LOC, or O?	ORG
# Lloyd_Bentsen is PER, ORG, LOC, or O?	PER
# Assuntos_Especiais is PER, ORG, LOC, or O?	O
# Eliezer_Baptista is PER, ORG, LOC, or O?	PER
# Robert_Johnson is PER, ORG, LOC, or O?	PER
# David_Byrne is PER, ORG, LOC, or O?	PER
# Asia_Classics is PER, ORG, LOC, or O?	O
# Luaka_Bop is PER, ORG, LOC, or O?	PER
# Tom_Zé is PER, ORG, LOC, or O?	PER
# Classics_Byrne is PER, ORG, LOC, or O?	O
# Secretaria_das_Relações_do_Trabalho is PER, ORG, LOC, or O?	ORG
# Emerson_Fittipaldi is PER, ORG, LOC, or O?	PER
# Lake_Powell is PER, ORG, LOC, or O?	O
# Jim_Greer is PER, ORG, LOC, or O?	PER
# Henry_Bogdan is PER, ORG, LOC, or O?	PER
# Secretaria_Nacional_de_Direito_Econômico is PER, ORG, LOC, or O?	ORG
# Estatuto_da_Criança_e_do_Adolescente is PER, ORG, LOC, or O?	ORG
# Márcia_Mendes is PER, ORG, LOC, or O?	PER
# Associaçãos_dos_Pais_de_Alunos is PER, ORG, LOC, or O?	ORG
# Cy_Twombly is PER, ORG, LOC, or O?	PER
# Edouard_Balladur is PER, ORG, LOC, or O?	PER
# They_Can\'t_Take_That_Away_From_Me is PER, ORG, LOC, or O?	O
# Let\'s_Call_the_Whole_Thing_Off is PER, ORG, LOC, or O?	O
# A_Foggy_Day is PER, ORG, LOC, or O?	O
# Nice_Work_if_You_Can_Get_it is PER, ORG, LOC, or O?	O
# They_All_Laughed is PER, ORG, LOC, or O?	O
# Love_Walked_In is PER, ORG, LOC, or O?	O
# Love_Is_Here_to_Stay is PER, ORG, LOC, or O?	O
# Hotel_Delmonicos is PER, ORG, LOC, or O?	LOC
# Park_Avenue is PER, ORG, LOC, or O?	LOC
# Marco_Cesar_Meira_Naslausky is PER, ORG, LOC, or O?	PER
# Peter_Luger_Steak_House is PER, ORG, LOC, or O?	PER
# Ayrton_Senna is PER, ORG, LOC, or O?	PER
# J.J._Letho is PER, ORG, LOC, or O?	PER
# Pedro_Lamy is PER, ORG, LOC, or O?	PER
# EDNA_Dantas is PER, ORG, LOC, or O?	PER
# Receita_Federal is PER, ORG, LOC, or O?	ORG
# Luiz_Henrique_Barros_de_Arruda is PER, ORG, LOC, or O?	PER
# João_Carlos_Martins is PER, ORG, LOC, or O?	PER
# Ettore_Gagliardi is PER, ORG, LOC, or O?	PER
# Lord_Hotel is PER, ORG, LOC, or O?	ORG
# Ronaldo_Graça_Couto is PER, ORG, LOC, or O?	PER
# Metavídeo/Metalivros is PER, ORG, LOC, or O?	O
# Pinacoteca_de_São_Paulo is PER, ORG, LOC, or O?	LOC
# Brasil_dos_Viajantes is PER, ORG, LOC, or O?	O
# Apresentando_Rembrandt_-_Pintor,_Gravador,_Professor is PER, ORG, LOC, or O?	O
# Alexander_Sturgis is PER, ORG, LOC, or O?	PER
# Glauco_Pereira_Chaves is PER, ORG, LOC, or O?	PER
# Nirlando_Beirão is PER, ORG, LOC, or O?	PER
# Centro_para_Direitos_Econômicos_e_Sociais is PER, ORG, LOC, or O?	ORG
# Universidade_Harvard is PER, ORG, LOC, or O?	ORG
# Agência_de_Proteção_Ambiental is PER, ORG, LOC, or O?	ORG
# Rio_de_Janeiro is PER, ORG, LOC, or O?	LOC
# Presidente_da_República is PER, ORG, LOC, or O?	O
# José_Sarney is PER, ORG, LOC, or O?	PER
# Sexta-feira,_Folha is PER, ORG, LOC, or O?	O
# Plano_Real is PER, ORG, LOC, or O?	O
# Taxa_Referencial is PER, ORG, LOC, or O?	O
# Banco_do_Brasil is PER, ORG, LOC, or O?	ORG
# Imposto_de_Renda is PER, ORG, LOC, or O?	O
# Master_System is PER, ORG, LOC, or O?	O
# Pense_Bem is PER, ORG, LOC, or O?	O
# PC_1.000 is PER, ORG, LOC, or O?	O
# Telepapo is PER, ORG, LOC, or O?	O
# Tá_Na_Hora is PER, ORG, LOC, or O?	O
# Carlos_Menem is PER, ORG, LOC, or O?	PER
# Museu_Britânico is PER, ORG, LOC, or O?	ORG
# Jean-François_Champollion is PER, ORG, LOC, or O?	PER
# Academia_de_Inscrições_e_Belas_Artes is PER, ORG, LOC, or O?	ORG
# Vercoutter is PER, ORG, LOC, or O?	O
# Silvio_Berlusconi is PER, ORG, LOC, or O?	PER
# Chora_Menino is PER, ORG, LOC, or O?	O
# Departamento_de_Fotografia is PER, ORG, LOC, or O?	ORG
# Waldemar_Cordeiro is PER, ORG, LOC, or O?	PER
# Tonya_Harding is PER, ORG, LOC, or O?	PER
# Nancy_Kerrigan is PER, ORG, LOC, or O?	PER
# USA_Today is PER, ORG, LOC, or O?	ORG
# Jeff_Gillooly is PER, ORG, LOC, or O?	PER
# Painel_do_Leitor is PER, ORG, LOC, or O?	O
# Marilena_Ansaldi is PER, ORG, LOC, or O?	PER
# Teatro_da_Dança is PER, ORG, LOC, or O?	O
# Sala_Gil_Vicente is PER, ORG, LOC, or O?	O
# Teatro_Ruth_Escobar is PER, ORG, LOC, or O?	O
# Sonia_Motta is PER, ORG, LOC, or O?	PER
# Sendero_Luminoso is PER, ORG, LOC, or O?	ORG
# Octavio_Paz is PER, ORG, LOC, or O?	PER
# Van_Himst is PER, ORG, LOC, or O?	PER
# Vital_Borkelmans is PER, ORG, LOC, or O?	PER
# MIT_Dealing_Management_Inc. is PER, ORG, LOC, or O?	O
# Luiz_Henrique is PER, ORG, LOC, or O?	PER
# Faria_Lima is PER, ORG, LOC, or O?	O
# Luís_Carlos_Berrini is PER, ORG, LOC, or O?	PER
# Júlio_Neves is PER, ORG, LOC, or O?	PER
# Saaras is PER, ORG, LOC, or O?	O
# Força_Sindical is PER, ORG, LOC, or O?	ORG
# Sindicato_dos_Metalúrgicos is PER, ORG, LOC, or O?	ORG
# Grande_Rio is PER, ORG, LOC, or O?	LOC
# Carlos_Eduardo_Lins_da_Silva is PER, ORG, LOC, or O?	PER
# Lawton_Chiles is PER, ORG, LOC, or O?	PER
# Partido_Democrata is PER, ORG, LOC, or O?	ORG
# Bill_Clinton is PER, ORG, LOC, or O?	PER
# George_Bush is PER, ORG, LOC, or O?	PER
# Santiago_Bernabeu is PER, ORG, LOC, or O?	PER
# Itamar_Franco is PER, ORG, LOC, or O?	PER
# Alexis_Stepanenko is PER, ORG, LOC, or O?	PER
# Minas_e_Energia is PER, ORG, LOC, or O?	ORG
# Mariano_Gonçalves_Neto is PER, ORG, LOC, or O?	PER
# Ernane_Galvêas is PER, ORG, LOC, or O?	PER
# Banco_Nacional_de_Habitação is PER, ORG, LOC, or O?	ORG
# Ministério_do_Interior is PER, ORG, LOC, or O?	ORG
# Bradesco_VISA is PER, ORG, LOC, or O?	ORG
# Marco_Antonio_Nahum is PER, ORG, LOC, or O?	PER
# Winfreys is PER, ORG, LOC, or O?	O
# Taras_Liskevich is PER, ORG, LOC, or O?	PER
# Rio_Branco is PER, ORG, LOC, or O?	O
# Santo_André is PER, ORG, LOC, or O?	LOC
# Bruno_José_Daniel is PER, ORG, LOC, or O?	PER
# Paulo_Cesar is PER, ORG, LOC, or O?	PER
# Ronald_Reagan is PER, ORG, LOC, or O?	PER
# Diário_da_Justiça is PER, ORG, LOC, or O?	ORG
# Free_Press is PER, ORG, LOC, or O?	O
# PSDB-PFL-PTB is PER, ORG, LOC, or O?	ORG
# Gustavo_Franco is PER, ORG, LOC, or O?	PER
# Comissão_Justiça_e_Paz is PER, ORG, LOC, or O?	ORG
# Regina_Casé is PER, ORG, LOC, or O?	PER
# Luiz_Zerbini is PER, ORG, LOC, or O?	PER
# Muir_Woods is PER, ORG, LOC, or O?	PER
# Itamar_Borges is PER, ORG, LOC, or O?	PER
# Santa_Fé_do_Sul is PER, ORG, LOC, or O?	LOC
# José_Machado_de_Campos_Filho is PER, ORG, LOC, or O?	PER
# Alberto_Goldman is PER, ORG, LOC, or O?	PER
# Aurélio_Alonso is PER, ORG, LOC, or O?	PER
# Folha_Norte is PER, ORG, LOC, or O?	O
# Burle_Filho is PER, ORG, LOC, or O?	PER
# Antônio_Carlos_Biscaia is PER, ORG, LOC, or O?	PER
# Três_Tristes_Tigres is PER, ORG, LOC, or O?	O
# Tokyo_Journal is PER, ORG, LOC, or O?	PER
# Rio_De_Janeiro is PER, ORG, LOC, or O?	LOC
# Bloco_da_Galinha_Azul is PER, ORG, LOC, or O?	ORG
# Ah_bem is PER, ORG, LOC, or O?	O
# Piranhos is PER, ORG, LOC, or O?	O
# Monte_líbano is PER, ORG, LOC, or O?	O
# Clube_das_Mulheres is PER, ORG, LOC, or O?	ORG
# Clube_das_Bigodudas is PER, ORG, LOC, or O?	ORG
# Napapiiri is PER, ORG, LOC, or O?	O
# São_José_do_Rio_Preto is PER, ORG, LOC, or O?	LOC
# Atlas_Folha_/_«_The_New_York_Times_» is PER, ORG, LOC, or O?	O
# Vale_do_Ribeira is PER, ORG, LOC, or O?	LOC
# Milton_Julio_Zanluqui is PER, ORG, LOC, or O?	PER
# Paraklin_Pára-raios is PER, ORG, LOC, or O?	O
# Gaiola_de_Faraday is PER, ORG, LOC, or O?	O
# Bolsa_de_Mercadorias is PER, ORG, LOC, or O?	O
# A_Marca_da_Maldade is PER, ORG, LOC, or O?	O
# Stan_Kenton is PER, ORG, LOC, or O?	PER
# Peter_Gunn is PER, ORG, LOC, or O?	PER
# Dizem_que_É_Amor is PER, ORG, LOC, or O?	O
# High_Time is PER, ORG, LOC, or O?	O
# Bonequinha_de_Luxo is PER, ORG, LOC, or O?	O
# Vício_Maldito is PER, ORG, LOC, or O?	O
# A_Pantera_Cor-de-Rosa is PER, ORG, LOC, or O?	PER
# Dias_Gomes is PER, ORG, LOC, or O?	PER
# Irmãos_Coragem is PER, ORG, LOC, or O?	O
# Janete_Clair is PER, ORG, LOC, or O?	PER
# Alfio_Basile is PER, ORG, LOC, or O?	PER
# Reginaldo_Duarte is PER, ORG, LOC, or O?	PER
# Juazeiro_do_Norte is PER, ORG, LOC, or O?	LOC
# Tasso_Jereissati is PER, ORG, LOC, or O?	PER
# Jônice_Tristão is PER, ORG, LOC, or O?	PER
# Elcio_Álvares is PER, ORG, LOC, or O?	PER
# Jornal_Nacional is PER, ORG, LOC, or O?	O
# Levir_Culpi is PER, ORG, LOC, or O?	PER
# Fernando_Fortes is PER, ORG, LOC, or O?	PER
# Luiz_Inácio_Lula_da_Silva is PER, ORG, LOC, or O?	PER
# IRLF is PER, ORG, LOC, or O?	O
# Luís_Carlos_dos_Santos is PER, ORG, LOC, or O?	PER
# Tatiana_Marques_Pedrosa is PER, ORG, LOC, or O?	PER
# São_Clemente is PER, ORG, LOC, or O?	O
# Feira_Internacional_de_Tecelagem is PER, ORG, LOC, or O?	ORG
# Imposto_Único is PER, ORG, LOC, or O?	O
# Trio_Irakitan is PER, ORG, LOC, or O?	O
# Jorge_Bornhausen is PER, ORG, LOC, or O?	PER
# Gustavo_Krause is PER, ORG, LOC, or O?	PER
# Olho_Mágico is PER, ORG, LOC, or O?	O
# Rio_Piedra is PER, ORG, LOC, or O?	LOC
# Terceiro_Mundo is PER, ORG, LOC, or O?	O
# Euclides_da_Cunha is PER, ORG, LOC, or O?	PER
# Jeca_Tatu is PER, ORG, LOC, or O?	O
# Osvaldo_Aranha is PER, ORG, LOC, or O?	PER
# TVs_Bandeirantes is PER, ORG, LOC, or O?	ORG
# Salvo_Lima is PER, ORG, LOC, or O?	PER
# Ignacio_Perea is PER, ORG, LOC, or O?	PER
# Pérsio_Arida is PER, ORG, LOC, or O?	PER
# Marluce_Dias_da_Silva is PER, ORG, LOC, or O?	PER
# Young_Gods is PER, ORG, LOC, or O?	O
# Nine_Inch_Nails is PER, ORG, LOC, or O?	ORG
# Ministério_do_Planejamento is PER, ORG, LOC, or O?	ORG
# Ministério_dos_Transportes is PER, ORG, LOC, or O?	ORG
# Santa_Catarina is PER, ORG, LOC, or O?	LOC
# Belo_Horizonte is PER, ORG, LOC, or O?	LOC
# O_Estado_de_Minas is PER, ORG, LOC, or O?	O
# Hélio_Costa is PER, ORG, LOC, or O?	PER
# Fogo_Cruzado is PER, ORG, LOC, or O?	O
# Divisão_de_Vigilância_Sanitária is PER, ORG, LOC, or O?	ORG
# Banco_de_Leite_Humano is PER, ORG, LOC, or O?	O
# Secretaria_Estadual_de_Saúde is PER, ORG, LOC, or O?	ORG
# Fausto_Cardoso is PER, ORG, LOC, or O?	ORG
# Cássia_Kiss is PER, ORG, LOC, or O?	PER
# Maria_do_Carmo_Nascimento_Alves is PER, ORG, LOC, or O?	PER
# José_Arthur_Giannotti is PER, ORG, LOC, or O?	PER
# Roberto_Schwarz is PER, ORG, LOC, or O?	PER
# Paul_Singer is PER, ORG, LOC, or O?	PER
# Capitalismo_e_Escravidão_no_Brasil_Meridional is PER, ORG, LOC, or O?	O
# Rubens_Barrichello is PER, ORG, LOC, or O?	PER
# Christian_Fittipaldi is PER, ORG, LOC, or O?	PER
# Karl_Wendlinger is PER, ORG, LOC, or O?	PER
# Noélia_Soares is PER, ORG, LOC, or O?	PER
# João_Paulo_2º is PER, ORG, LOC, or O?	PER
# Emília_Ehrlich is PER, ORG, LOC, or O?	PER
# Livraria_da_Vila is PER, ORG, LOC, or O?	O
# Supremo_Tribunal_Federal is PER, ORG, LOC, or O?	ORG
# M2.000 is PER, ORG, LOC, or O?	O
# M2.000_Summer_Concerts is PER, ORG, LOC, or O?	O
# Capão_da_Canoa is PER, ORG, LOC, or O?	LOC
# José_Paulo_Bisol is PER, ORG, LOC, or O?	PER
# Francisco_Rossi is PER, ORG, LOC, or O?	PER
# Mário_Covas is PER, ORG, LOC, or O?	PER
# Uno_Mille is PER, ORG, LOC, or O?	O
# Clean_Car is PER, ORG, LOC, or O?	O
# Seguridade_Social is PER, ORG, LOC, or O?	O
# Renato_Batista_Pedroso is PER, ORG, LOC, or O?	PER
# Douglas_José_da_Silva is PER, ORG, LOC, or O?	PER
# Roberto_Ilhesca is PER, ORG, LOC, or O?	PER
# Copa_Africana_de_Nações is PER, ORG, LOC, or O?	ORG
# Elijah_Litana is PER, ORG, LOC, or O?	PER
# Emmanuel_Amunike is PER, ORG, LOC, or O?	PER
# Fundo_Social_de_Emergência is PER, ORG, LOC, or O?	O
# Ricki_Lake is PER, ORG, LOC, or O?	PER
# Karl_Lagerfeld is PER, ORG, LOC, or O?	PER
# People_for_Ethical_Treatment_of_Animals is PER, ORG, LOC, or O?	ORG
# Steve_Wonder is PER, ORG, LOC, or O?	PER
# Stevie_Wonder is PER, ORG, LOC, or O?	PER
# Wilson_Romão is PER, ORG, LOC, or O?	PER
# Miguel_Kodja_Neto is PER, ORG, LOC, or O?	PER
# Samir_Abdul_Hack is PER, ORG, LOC, or O?	PER
# João_Paulo_Bordon is PER, ORG, LOC, or O?	PER
# Eldorado_S/A is PER, ORG, LOC, or O?	ORG
# Fidel_Castro is PER, ORG, LOC, or O?	PER
# Companhia_de_Dança is PER, ORG, LOC, or O?	ORG
# Deborah_Colker is PER, ORG, LOC, or O?	PER
# Alma_Corsária is PER, ORG, LOC, or O?	PER
# Carlos_Reichenbach is PER, ORG, LOC, or O?	PER
# Mil_e_Uma is PER, ORG, LOC, or O?	O
# Suzana_de_Moraes is PER, ORG, LOC, or O?	PER
# Cannes-94 is PER, ORG, LOC, or O?	ORG
# Quinzena_dos_Realizadores is PER, ORG, LOC, or O?	O
# La_Reina_de_La_Noche is PER, ORG, LOC, or O?	O
# Arturo_Ripstein is PER, ORG, LOC, or O?	PER
# Um_Certo_Olhar is PER, ORG, LOC, or O?	O
# Los_Naufragos is PER, ORG, LOC, or O?	O
# Miguel_Littin is PER, ORG, LOC, or O?	PER
# Sin_Compassion is PER, ORG, LOC, or O?	O
# Francisco_Lombardi is PER, ORG, LOC, or O?	PER
# Los_AngelesDetroitLos_Angeles is PER, ORG, LOC, or O?	O
# Guarda_Municipal is PER, ORG, LOC, or O?	ORG
# Mauro_Silva is PER, ORG, LOC, or O?	PER
# Bradesco_Visa is PER, ORG, LOC, or O?	ORG
# Seminário_Internacional is PER, ORG, LOC, or O?	O
# Qualidade_Total is PER, ORG, LOC, or O?	O
# Tsunezaemon_Maeda is PER, ORG, LOC, or O?	PER
# Sagaken is PER, ORG, LOC, or O?	O
# Santa_Tereza is PER, ORG, LOC, or O?	LOC
# Arnaldo_Leite is PER, ORG, LOC, or O?	PER
# Programa_de_Capacitação_Gerencial is PER, ORG, LOC, or O?	O
# Serviço_Brasileiro_de_Apoio_às_Micro_e_Pequenas_Empresas is PER, ORG, LOC, or O?	O
# Tribunal_de_Contas is PER, ORG, LOC, or O?	ORG
# Justiça_Eleitoral is PER, ORG, LOC, or O?	ORG
# Tribunais_Regionais_Eleitorais is PER, ORG, LOC, or O?	ORG
# Departamento_de_Controle_e_Uso_de_Imóveis is PER, ORG, LOC, or O?	ORG
# Cine_West_Plaza_3 is PER, ORG, LOC, or O?	O
# Joilson_da_Silva is PER, ORG, LOC, or O?	PER
# Waldir_de_Arruda_Miranda_Carneiro is PER, ORG, LOC, or O?	PER
# Boathouse_Cafe is PER, ORG, LOC, or O?	O
# East_72 is PER, ORG, LOC, or O?	O
# Park_Drive_North is PER, ORG, LOC, or O?	LOC
# Central_Park is PER, ORG, LOC, or O?	LOC
# Christo\'s is PER, ORG, LOC, or O?	O
# Cacá_Diegues is PER, ORG, LOC, or O?	PER
# TV_Cultura is PER, ORG, LOC, or O?	ORG
# Jorge_Ben_Jor is PER, ORG, LOC, or O?	PER
# Ferreira_Jr. is PER, ORG, LOC, or O?	PER
# O_Amanuense_Belmiro is PER, ORG, LOC, or O?	PER
# Luiza_Erundina is PER, ORG, LOC, or O?	PER
# Paulo_Maluf is PER, ORG, LOC, or O?	PER
# Associação_Nacional_de_Agências_de_Viagens is PER, ORG, LOC, or O?	ORG
# Sérgio_Nogueira is PER, ORG, LOC, or O?	PER
# Associação_Nacional_de_Pós-graduação_em_Ciências_Sociais is PER, ORG, LOC, or O?	ORG
# Buenos_Aires is PER, ORG, LOC, or O?	LOC
# Othon_Bastos is PER, ORG, LOC, or O?	PER
# Lambari_d'_Oeste is PER, ORG, LOC, or O?	O
# Reinaldo_Lourenço is PER, ORG, LOC, or O?	PER
# Walter_Rodrigues is PER, ORG, LOC, or O?	PER
# Der_Haten is PER, ORG, LOC, or O?	O
# Viva_Viva is PER, ORG, LOC, or O?	O
# Sucumbe_a_Cólera is PER, ORG, LOC, or O?	O
# Cia._do_Linho is PER, ORG, LOC, or O?	O
# Special_K is PER, ORG, LOC, or O?	O
# Lorenzo_Merlino is PER, ORG, LOC, or O?	PER
# Anderson_Rubbo is PER, ORG, LOC, or O?	PER
# Cacá_di_Guglielmo is PER, ORG, LOC, or O?	PRE
# Cacá_di_Guglielmo is PER, ORG, LOC, or O?	PER
# Alessandro_Tierni is PER, ORG, LOC, or O?	PER
# Claudia_Guimarães is PER, ORG, LOC, or O?	PER
# Folha_Imagem is PER, ORG, LOC, or O?	O
# Bolsa_de_Valores_de_São_Paulo is PER, ORG, LOC, or O?	ORG
# Conselho_Monetário_Nacional is PER, ORG, LOC, or O?	ORG
# Plano_Verão is PER, ORG, LOC, or O?	O
# Mighty_Max is PER, ORG, LOC, or O?	O
# Juan_Manuel_Fangio is PER, ORG, LOC, or O?	PER
# Fórmula_1 is PER, ORG, LOC, or O?	O
# Fórmula_Indy is PER, ORG, LOC, or O?	O
# Dan_Gurney is PER, ORG, LOC, or O?	PER
# União_Européia is PER, ORG, LOC, or O?	ORG
# Fittipaldi_Promoções is PER, ORG, LOC, or O?	O
# Special_Girolando is PER, ORG, LOC, or O?	O
# Salute_Milk is PER, ORG, LOC, or O?	O
# Instituto_Médico_Legal is PER, ORG, LOC, or O?	ORG
# Taboão_da_Serra is PER, ORG, LOC, or O?	LOC
# Itaim_Paulista is PER, ORG, LOC, or O?	LOC
# Kalef_João_Francisco is PER, ORG, LOC, or O?	PER
# Gazeta_Filho is PER, ORG, LOC, or O?	O
# Francisco_Morato is PER, ORG, LOC, or O?	PER
# ISO-9002 is PER, ORG, LOC, or O?	O
# Volta_Redonda is PER, ORG, LOC, or O?	LOC
# Polícia_Federal is PER, ORG, LOC, or O?	ORG
# Juan_Jose_Galeano is PER, ORG, LOC, or O?	PER
# Superior_Tribunal_de_Justiça is PER, ORG, LOC, or O?	ORG
# Ministério_Público_Federal is PER, ORG, LOC, or O?	ORG
# Orestes_Quércia is PER, ORG, LOC, or O?	PER
# Associação_dos_Engenheiros is PER, ORG, LOC, or O?	ORG
# Bulletin_Board_Systems is PER, ORG, LOC, or O?	O
# Departamento_de_Defesa is PER, ORG, LOC, or O?	ORG
# Itereí is PER, ORG, LOC, or O?	O
# Arnaldo_Baptista is PER, ORG, LOC, or O?	PER
# Vera_Lucia_Vassouras is PER, ORG, LOC, or O?	PER
# Suburbano_Coração is PER, ORG, LOC, or O?	O
# Lovemar is PER, ORG, LOC, or O?	O
# Andréa_Beltrão is PER, ORG, LOC, or O?	PER
# Marco_Nanini is PER, ORG, LOC, or O?	PER
# Naum_Alves_de_Souza is PER, ORG, LOC, or O?	PER
# Marisa_Orth is PER, ORG, LOC, or O?	PER
# Pedro_Paulo_Rangel is PER, ORG, LOC, or O?	PER
# Diogo_Vilela is PER, ORG, LOC, or O?	PER
# Rio_Grande_do_Sul is PER, ORG, LOC, or O?	LOC
# Minas_Gerais is PER, ORG, LOC, or O?	LOC
# Espírito_Santo is PER, ORG, LOC, or O?	LOC
# Mato_Grosso_do_Sul is PER, ORG, LOC, or O?	LOC
# Memorial_de_Menininha_do_Gantois is PER, ORG, LOC, or O?	O
# Menininha_do_Gantois is PER, ORG, LOC, or O?	O
# Instituto_Brasileiro_do_Patrimônio_Cultural is PER, ORG, LOC, or O?	ORG
# Museu_Victor_Meirelles is PER, ORG, LOC, or O?	LOC
# A_Primeira_Missa_no_Brasil is PER, ORG, LOC, or O?	O
# Cartilha_da_Segurança_Escolar is PER, ORG, LOC, or O?	O
# Isaac_Ainhorn is PER, ORG, LOC, or O?	PER
# Raymond_Kelly is PER, ORG, LOC, or O?	PER
# Porto_Príncipe is PER, ORG, LOC, or O?	LOC
# Inteligência_Fiscal is PER, ORG, LOC, or O?	O
# Marcos_Vinícius_Lima is PER, ORG, LOC, or O?	PER
# Imposto_de_Importação is PER, ORG, LOC, or O?	O
# Imposto_sobre_Produtos_Industrializados is PER, ORG, LOC, or O?	O
# Manoel_Carlos_Marques_Beato is PER, ORG, LOC, or O?	PER
# José_Sebastião_Figueiredo is PER, ORG, LOC, or O?	PER
# La_Bicocca is PER, ORG, LOC, or O?	O
# Concurso_Brasileiro_de_Sommeliers is PER, ORG, LOC, or O?	O
# Jack_«Girafa»_Charlton is PER, ORG, LOC, or O?	PER
# Jack_Girafa is PER, ORG, LOC, or O?	PER
# Flávio_Ferrari is PER, ORG, LOC, or O?	PER
# Ibope_Mídia is PER, ORG, LOC, or O?	O
# Plácido_Domingo is PER, ORG, LOC, or O?	PER
# Richard_Strauss is PER, ORG, LOC, or O?	PER
# LUÍS_ANTÔNIO_GIRON is PER, ORG, LOC, or O?	PER
# Austríaca_de_Turismo is PER, ORG, LOC, or O?	O
# Visconde_da_Luz is PER, ORG, LOC, or O?	PER
# Companhia_de_Engenharia_de_Tráfego is PER, ORG, LOC, or O?	ORG
# João_Cachoeira is PER, ORG, LOC, or O?	PER
# Clodomiro_Amazonas is PER, ORG, LOC, or O?	PER
# Fernando_Henrique is PER, ORG, LOC, or O?	PER
# Esperidião_Amin is PER, ORG, LOC, or O?	PER
# Boeing_737 is PER, ORG, LOC, or O?	O
# China_Southern_Airlines is PER, ORG, LOC, or O?	ORG
# Aerospace_146 is PER, ORG, LOC, or O?	O
# China_Northwest_Airlines is PER, ORG, LOC, or O?	ORG
# Ningxia_Hui is PER, ORG, LOC, or O?	PER
# Ráscal_Pizza_&_Cozinha is PER, ORG, LOC, or O?	ORG
# Grupo_Viena is PER, ORG, LOC, or O?	ORG
# Grupo_de_Juiz_de_Fora is PER, ORG, LOC, or O?	ORG
# Ella_Fitzgerald is PER, ORG, LOC, or O?	PER
# Laerte_Cordeiro_&_Associados is PER, ORG, LOC, or O?	ORG
# Pacto_de_Varsóvia is PER, ORG, LOC, or O?	O
# José_Carreras is PER, ORG, LOC, or O?	PER
# Thomas_Hampson is PER, ORG, LOC, or O?	PER
# Ben_Heppner is PER, ORG, LOC, or O?	PER
# Sergei_Leiferkus is PER, ORG, LOC, or O?	PER
# Bryn_Terfei is PER, ORG, LOC, or O?	PER
# Cecilia_Bartoli is PER, ORG, LOC, or O?	PER
# Jessye_Norman is PER, ORG, LOC, or O?	PER
# Anne_Sofie_von_Otter is PER, ORG, LOC, or O?	PER
# Dawn_Upshaw is PER, ORG, LOC, or O?	PER
# Galina_Gorchakova is PER, ORG, LOC, or O?	PER
# Classical_Music_Award is PER, ORG, LOC, or O?	O
# BBC_Music_Magazine is PER, ORG, LOC, or O?	O
# The_Independent is PER, ORG, LOC, or O?	O
# Márcio_Santos is PER, ORG, LOC, or O?	PER
# Kennet_Andersson is PER, ORG, LOC, or O?	PER
# Antonio_Jorge is PER, ORG, LOC, or O?	PER
# Pete_Sampras is PER, ORG, LOC, or O?	PER
# Michael_Stich is PER, ORG, LOC, or O?	PER
# Torneio_de_Doha is PER, ORG, LOC, or O?	O
# Karim_Alami is PER, ORG, LOC, or O?	PER
# Ronald_Agenor is PER, ORG, LOC, or O?	PER
# Stefan_Edberg is PER, ORG, LOC, or O?	PER
# Anders_Jarryd is PER, ORG, LOC, or O?	PER
# Cosmética\'94 is PER, ORG, LOC, or O?	O
# Parque_Anhembi is PER, ORG, LOC, or O?	LOC
# Secretaria_das_Finanças is PER, ORG, LOC, or O?	ORG
# Prefeitura_de_São_Paulo is PER, ORG, LOC, or O?	ORG
# Unidade_Fiscal_do_Município is PER, ORG, LOC, or O?	ORG
# Tributação_no_Brasil_e_o_Imposto_Único is PER, ORG, LOC, or O?	O
# Marcos_Cintra is PER, ORG, LOC, or O?	PER
# Santo_Américo is PER, ORG, LOC, or O?	O
# MONIQUE_EVANS is PER, ORG, LOC, or O?	PER
# Monique_Evans is PER, ORG, LOC, or O?	PER
# Tribunal_de_Justiça_Militar is PER, ORG, LOC, or O?	ORG
# Casa_de_Detenção is PER, ORG, LOC, or O?	LOC
# Conselho_Municipal_de_Defesa_dos_Direitos_das_Mulheres_e_das_Minorias is PER, ORG, LOC, or O?	ORG
# Coordenadoria_Especial_da_Mulher is PER, ORG, LOC, or O?	ORG
# Catuaí_Shopping_Center is PER, ORG, LOC, or O?	LOC
# Marta_Suplicy is PER, ORG, LOC, or O?	PER
# Delegacia_Regional_do_Trabalho is PER, ORG, LOC, or O?	ORG
# Instituro_Pedro_Melo is PER, ORG, LOC, or O?	ORG
# More_Fun is PER, ORG, LOC, or O?	O
# Takeo_Hirata is PER, ORG, LOC, or O?	PER
# Takuo_Hirano is PER, ORG, LOC, or O?	PER
# Tetsuyuki_Hirano is PER, ORG, LOC, or O?	PER
# Hirano_Design_International_Inc. is PER, ORG, LOC, or O?	ORG
# Teatro_Nacional is PER, ORG, LOC, or O?	O
# June_Drummond is PER, ORG, LOC, or O?	PER
# Companhia_das_Letras is PER, ORG, LOC, or O?	ORG
# Caça_aos_Turistas is PER, ORG, LOC, or O?	O
# Caupenne_d\'Armagnac is PER, ORG, LOC, or O?	O
# Volta_da_França is PER, ORG, LOC, or O?	O
# Piotr_Wator is PER, ORG, LOC, or O?	PER
# Gajowianka is PER, ORG, LOC, or O?	O
# Wator is PER, ORG, LOC, or O?	O
# Fausto_Camper is PER, ORG, LOC, or O?	PER
# Jabaury_Jr. is PER, ORG, LOC, or O?	PER
# Banco_Nacional is PER, ORG, LOC, or O?	O
# American_Express is PER, ORG, LOC, or O?	ORG
# Jockey_Club is PER, ORG, LOC, or O?	ORG
# Fundação_Getúlio_Vargas is PER, ORG, LOC, or O?	ORG
# Associação_Paulista_de_Propaganda is PER, ORG, LOC, or O?	ORG
# Recanto_da_Cachoeira is PER, ORG, LOC, or O?	LOC
# São_Silvestre is PER, ORG, LOC, or O?	ORG
# Bob_Fernandes is PER, ORG, LOC, or O?	PER
# Luiz_Antônio_de_Medeiros is PER, ORG, LOC, or O?	PER
# Comissão_de_Assuntos_Econômicos is PER, ORG, LOC, or O?	ORG
# Justiça_do_Trabalho is PER, ORG, LOC, or O?	ORG
# Alex_Trotman is PER, ORG, LOC, or O?	PER
# Comunidade_de_Estados_Independentes is PER, ORG, LOC, or O?	ORG
# Douglas_Ivester is PER, ORG, LOC, or O?	PER
# Francisco_Lafayette is PER, ORG, LOC, or O?	PER
# Banco_Banorte is PER, ORG, LOC, or O?	ORG
# Adolfo_Moruzzi is PER, ORG, LOC, or O?	PER
# Secretaria_de_Vias_Públicas is PER, ORG, LOC, or O?	ORG
# Michael_Myers is PER, ORG, LOC, or O?	PER
# Freddy_Krueger is PER, ORG, LOC, or O?	PER
# Rubens_Ricupero is PER, ORG, LOC, or O?	PER
# Assuntos_Internacionais is PER, ORG, LOC, or O?	O
# Tab_Ramos is PER, ORG, LOC, or O?	PER
# Meca_Vargas is PER, ORG, LOC, or O?	PER
# Associação_Médica_Norte-americana is PER, ORG, LOC, or O?	ORG
# Jos_Verstappen is PER, ORG, LOC, or O?	PER
# Deborah_Caldas is PER, ORG, LOC, or O?	PER
# Vera_Bononi is PER, ORG, LOC, or O?	PER
# Asuapi is PER, ORG, LOC, or O?	O
# Departamento_de_Estado is PER, ORG, LOC, or O?	ORG
# Federal_Bureau_Investigation is PER, ORG, LOC, or O?	ORG
# Agropecuária_América is PER, ORG, LOC, or O?	ORG
# Citrovita_Agropecuária is PER, ORG, LOC, or O?	ORG
# Congresso_Nacional is PER, ORG, LOC, or O?	ORG
# Programa_de_Integração_Social is PER, ORG, LOC, or O?	O
# Fundo_de_Participação_dos_Estados_e_municípios is PER, ORG, LOC, or O?	O
# João_Alves is PER, ORG, LOC, or O?	PER
# Caio_Gorentzvaig is PER, ORG, LOC, or O?	PER
# Anjos_da_Noite is PER, ORG, LOC, or O?	ORG
# Wilson_Barros is PER, ORG, LOC, or O?	PER
# Marilia_Pêra is PER, ORG, LOC, or O?	PER
# Márcia_Cibilis_Viana is PER, ORG, LOC, or O?	PER
# Paulo_de_Almeida is PER, ORG, LOC, or O?	PER
# Aluizio_de_Castro is PER, ORG, LOC, or O?	PER
# Nilton_Cerqueira is PER, ORG, LOC, or O?	PER
# Emir_Larangeira is PER, ORG, LOC, or O?	PER
# Barra_Mansa is PER, ORG, LOC, or O?	LOC
# Instituto_Brasileiro_de_Turismo is PER, ORG, LOC, or O?	PORG
# Instituto_Brasileiro_de_Turismo is PER, ORG, LOC, or O?	ORG
# Secretaria_da_Fazenda is PER, ORG, LOC, or O?	ORG
# Estado_de_São_Paulo is PER, ORG, LOC, or O?	LOC
# Marcelo_Negrão is PER, ORG, LOC, or O?	PER
# Líbero_Badaró is PER, ORG, LOC, or O?	PER
# São_Bento is PER, ORG, LOC, or O?	O
# Japan_Steel is PER, ORG, LOC, or O?	O
# Sete_Ondas is PER, ORG, LOC, or O?	O
# Casa_da_Cultura_dos_Povos is PER, ORG, LOC, or O?	O
# Centro_Internacional_de_Arte_e_Escultura is PER, ORG, LOC, or O?	ORG
# Organização_dos_Estados_Americanos is PER, ORG, LOC, or O?	ORG
# João_do_Amaral_Gurgel is PER, ORG, LOC, or O?	PER
# Mogi_Mirim is PER, ORG, LOC, or O?	LOC
# Superliga_Nacional_Masculina is PER, ORG, LOC, or O?	ORG
# Tijuca_Tênis_Clune is PER, ORG, LOC, or O?	ORG
# Brendan_Fraser is PER, ORG, LOC, or O?	PER
# Gore_Vidal is PER, ORG, LOC, or O?	PER
# Organizações_Globo is PER, ORG, LOC, or O?	ORG
# Companhia_de_Mineração is PER, ORG, LOC, or O?	ORG
# Rede_RBS is PER, ORG, LOC, or O?	ORG
# Net_Brasil is PER, ORG, LOC, or O?	ORG
# Parque_São_Carlos is PER, ORG, LOC, or O?	LOC
# Nova_Iguaçu is PER, ORG, LOC, or O?	LOC
# Robert_McDuffie is PER, ORG, LOC, or O?	PER
# Mohamed_6º is PER, ORG, LOC, or O?	PER
# Tratado_de_Sèvres is PER, ORG, LOC, or O?	O
# Mustafá_Kemal is PER, ORG, LOC, or O?	PER
# Primeira_Guerra_Mundial is PER, ORG, LOC, or O?	O
# Assembléia_Nacional is PER, ORG, LOC, or O?	ORG
# Josip_Weber is PER, ORG, LOC, or O?	ORG
# Carmelita_Aralse_Tebele is PER, ORG, LOC, or O?	ORG
# Beth_Tebele is PER, ORG, LOC, or O?	PER
# Albano_Miguel_Ferreira is PER, ORG, LOC, or O?	PER
# Santa_Cecília is PER, ORG, LOC, or O?	LOC
# Administração_Regional is PER, ORG, LOC, or O?	ORG
# Leonilson_Ribeiro is PER, ORG, LOC, or O?	PER
# Parque_Nacional_da_Lagoa_do_Peixe is PER, ORG, LOC, or O?	LOC
# Hyatt_Regency_Aruba is PER, ORG, LOC, or O?	LOC
# Banco_Mercantil is PER, ORG, LOC, or O?	ORG
# Maria_Bethânia is PER, ORG, LOC, or O?	PER
# Gilberto_Gil is PER, ORG, LOC, or O?	PER
# Magda_Collares is PER, ORG, LOC, or O?	PER
# Fausto_Silva is PER, ORG, LOC, or O?	PER
# David_Postman is PER, ORG, LOC, or O?	PER
# Murilo_Mendes is PER, ORG, LOC, or O?	PER
# Los_Angeles is PER, ORG, LOC, or O?	LOC
# Epson_Stylus_800 is PER, ORG, LOC, or O?	O
# Compaq_Aero is PER, ORG, LOC, or O?	O
# J&R_Computer_World is PER, ORG, LOC, or O?	O
# Jânio_Quadros is PER, ORG, LOC, or O?	PER
# Mario_Covas is PER, ORG, LOC, or O?	PER
# Nove_de_Julho is PER, ORG, LOC, or O?	O
# Reynaldo_de_Barros is PER, ORG, LOC, or O?	PER
# Vias_Públicas is PER, ORG, LOC, or O?	O
# Secretaria_da_Saúde is PER, ORG, LOC, or O?	ORG
# Fundação_Nacional_de_Saúde is PER, ORG, LOC, or O?	ORG
# Zoneamento_Ecológico-Econômico is PER, ORG, LOC, or O?	O
# Clarismino_Júnior is PER, ORG, LOC, or O?	PER
# Meia_Ponte is PER, ORG, LOC, or O?	O
# Dolores_de_Pança is PER, ORG, LOC, or O?	PER
# IPC-amplo is PER, ORG, LOC, or O?	O
# Nuno_Leal_Maia is PER, ORG, LOC, or O?	PER
# Alexandre_Moreno is PER, ORG, LOC, or O?	PER
# Raul_Pelegrini is PER, ORG, LOC, or O?	PER
# Tarcísio_Meira is PER, ORG, LOC, or O?	PER
# Justiça_Federal is PER, ORG, LOC, or O?	ORG
# Dom_Isidoro_Oliveira_Preto is PER, ORG, LOC, or O?	PER
# Banco_de_Boston is PER, ORG, LOC, or O?	ORG
# Akzo/Tintas_Ypiranga is PER, ORG, LOC, or O?	O
# Castor_de_Andrade is PER, ORG, LOC, or O?	PER
# Polícia_Civil is PER, ORG, LOC, or O?	ORG
# Juscelino_Kubitschek is PER, ORG, LOC, or O?	PER
# José_Maria_Alkimin is PER, ORG, LOC, or O?	PER
# Automóvel_Clube is PER, ORG, LOC, or O?	ORG
# Sara_Lemos is PER, ORG, LOC, or O?	PER
# Jayme_Lemos is PER, ORG, LOC, or O?	PER
# Prêmio_Simbólico is PER, ORG, LOC, or O?	O
# Roberto_Dávila is PER, ORG, LOC, or O?	PER
# Cerimônia_de_Casamento is PER, ORG, LOC, or O?	O
# The_New_York_Times is PER, ORG, LOC, or O?	ORG
# Said_Miguel is PER, ORG, LOC, or O?	O
# Comissão_de_Agricultura is PER, ORG, LOC, or O?	ORG
# Câmara_dos_Deputados is PER, ORG, LOC, or O?	ORG
# Fernando_Collor is PER, ORG, LOC, or O?	PER
# Luís_Carlos_Chaves is PER, ORG, LOC, or O?	PER
# Golden_Horn is PER, ORG, LOC, or O?	O
# Matis-Paris_Brasil is PER, ORG, LOC, or O?	O
# Lourenço_Lopes is PER, ORG, LOC, or O?	PER
# Iti_Fuji is PER, ORG, LOC, or O?	PER
# Luiz_Estevão is PER, ORG, LOC, or O?	PER
# Casa_da_Dinda is PER, ORG, LOC, or O?	LOC
# Eunícia_Guimarães is PER, ORG, LOC, or O?	PER
# Pedro_Collor is PER, ORG, LOC, or O?	PER
# Aloizio_Mercadante is PER, ORG, LOC, or O?	PER
# José_Dirceu is PER, ORG, LOC, or O?	PER
# João_Hermann is PER, ORG, LOC, or O?	PER
# Reuters_Holdings is PER, ORG, LOC, or O?	PER
# Eufrasio_Veículos is PER, ORG, LOC, or O?	ORG
# Campos_do_Jordão is PER, ORG, LOC, or O?	LOC
# Câmara_Americana is PER, ORG, LOC, or O?	ORG
# Sonia_Braga is PER, ORG, LOC, or O?	per
# Sonia_Braga is PER, ORG, LOC, or O?	PER
# Andy_Garcia is PER, ORG, LOC, or O?	PER
# Arantxa_Sanchez is PER, ORG, LOC, or O?	PER
# Us_Open is PER, ORG, LOC, or O?	O
# Monica_Seles is PER, ORG, LOC, or O?	PER
# Um_Paraíso_Perdido is PER, ORG, LOC, or O?	O
# Empresa_Metropolitana_de_Transportes_Urbanos is PER, ORG, LOC, or O?	ORG
# José_Scafura is PER, ORG, LOC, or O?	PER
# Luis_Carlos_Scafura is PER, ORG, LOC, or O?	PER
# Vasco_da_Gama is PER, ORG, LOC, or O?	ORG
# Luís_de_Camões is PER, ORG, LOC, or O?	PER
# Souza_Cruz is PER, ORG, LOC, or O?	O
# Míton_Cabral is PER, ORG, LOC, or O?	PER
# World_Trade_Center is PER, ORG, LOC, or O?	LOC
# Santana_de_Parnaíba is PER, ORG, LOC, or O?	LOC
# Lei_8.666 is PER, ORG, LOC, or O?	O
# All-Star_Music_Resort is PER, ORG, LOC, or O?	O
# Fome_e_desemprego_._Agricultura_é_a_solução is PER, ORG, LOC, or O?	O
# Costa_e_Silva is PER, ORG, LOC, or O?	PER
# Champs_Elysèes is PER, ORG, LOC, or O?	LOC
# Sérgio_Amaral is PER, ORG, LOC, or O?	PER
# Ibsen_Pinheiro is PER, ORG, LOC, or O?	PER
# Carlos_Alberto_Parreira is PER, ORG, LOC, or O?	PER
# Folha/«The_New_York_Times» is PER, ORG, LOC, or O?	O
# Sesc_Pompéia is PER, ORG, LOC, or O?	ORG
# Nuno_Ramos is PER, ORG, LOC, or O?	PER
# Exercícios_Visuais is PER, ORG, LOC, or O?	O
# Pinheiros_Vivo is PER, ORG, LOC, or O?	O
# Vila_Olímpia_Viva is PER, ORG, LOC, or O?	O
# Horácio_Galvanese is PER, ORG, LOC, or O?	PER
# Siegbert_Zanettini is PER, ORG, LOC, or O?	PER
# Instituto_de_Pesquisas_Econômicas_e_Administrativas/MG is PER, ORG, LOC, or O?	ORG
# Fúria_Metal is PER, ORG, LOC, or O?	O
# Iggy_Pop is PER, ORG, LOC, or O?	PER
# Blitzkrieg_Bop is PER, ORG, LOC, or O?	O
# I_Wanna_Live is PER, ORG, LOC, or O?	O
# Poison_Heart is PER, ORG, LOC, or O?	O
# Santa_Maria_da_Vitória is PER, ORG, LOC, or O?	LOC
# Arthur_Sendas is PER, ORG, LOC, or O?	PER
# Via_Dutra is PER, ORG, LOC, or O?	LOC
# Linha_Vermelha is PER, ORG, LOC, or O?	LOC
# Nacional_Iguatemi_Empreendimentos is PER, ORG, LOC, or O?	ORG
# Palácio_Bandeirantes is PER, ORG, LOC, or O?	LOC
# Juca_Chaves is PER, ORG, LOC, or O?	PER
# Jucabaré-Theatro_Inteligente is PER, ORG, LOC, or O?	O
# Major_Sertório is PER, ORG, LOC, or O?	PER
# Fundo_Social_de_Solidariedade is PER, ORG, LOC, or O?	O
# Casa_Legislativa is PER, ORG, LOC, or O?	ORG
# Vladimir_Rioli is PER, ORG, LOC, or O?	PER
# Os_Imperdoáveis is PER, ORG, LOC, or O?	O
# Um_Mundo_Perfeito is PER, ORG, LOC, or O?	O
# Philip_Perry is PER, ORG, LOC, or O?	PER
# T.J._Lowther is PER, ORG, LOC, or O?	PER
# Butch_Haynes is PER, ORG, LOC, or O?	PER
# Kevin_Costner is PER, ORG, LOC, or O?	PER
# Neil_Armstrong is PER, ORG, LOC, or O?	PER
# Rene_Degni-Segui is PER, ORG, LOC, or O?	PER
# Costa_do_Marfim is PER, ORG, LOC, or O?	LOC
# Nova_Força is PER, ORG, LOC, or O?
# Nova_Força is PER, ORG, LOC, or O?	O
# Djalma_Falcão is PER, ORG, LOC, or O?	PER
# Congresso_Internacional_de_Direitos_Autorais is PER, ORG, LOC, or O?	ORG
# Luiz_Roberto_Nascimento_Silva is PER, ORG, LOC, or O?	PER
# Conselho_Nacional_de_Direito_Autoral is PER, ORG, LOC, or O?	ORG
# Espiridião_Amin is PER, ORG, LOC, or O?	PER
# Ronan_Tito is PER, ORG, LOC, or O?	PER
# Gilberto_Miranda is PER, ORG, LOC, or O?	PER
# Renata_Lourenção is PER, ORG, LOC, or O?	PER
# Secretaria_Estadual_da_Saúde is PER, ORG, LOC, or O?	ORG
# Centro_de_Vigilância_Epidemiológica is PER, ORG, LOC, or O?	ORG
# Wagner_Costa is PER, ORG, LOC, or O?	PER
# Luiz_Antonio_Fleury_Filho is PER, ORG, LOC, or O?	ORG
# Johan_Cruyff is PER, ORG, LOC, or O?	PER
# Telê_Santana is PER, ORG, LOC, or O?	PER
# Parque_Antarctica is PER, ORG, LOC, or O?	LOC
# Lanternas_Vermelhas is PER, ORG, LOC, or O?	O
# Zhang_Yimou is PER, ORG, LOC, or O?	PER
# Bolsa_de_Mercadorias_e_Futuros is PER, ORG, LOC, or O?	ORG
# Sant\'Anna is PER, ORG, LOC, or O?	O
# Los_Gatos is PER, ORG, LOC, or O?	O
# Propaganda_-_O_Poder_da_Imagem is PER, ORG, LOC, or O?	O
# Universidade_Federal_da_Paraíba is PER, ORG, LOC, or O?	ORG
# John_Ritchings is PER, ORG, LOC, or O?	PER
# Ritchings is PER, ORG, LOC, or O?	PER
# Markus_Sokol is PER, ORG, LOC, or O?	PER
# Fundação_Dom_Cabral is PER, ORG, LOC, or O?	ORG
# STC-Executivo is PER, ORG, LOC, or O?	O
# Paulo_Ubiratan is PER, ORG, LOC, or O?	PER
# Laerte_Leite_Cordeiro is PER, ORG, LOC, or O?	PER
# Guerra_Fria is PER, ORG, LOC, or O?	O
# Houston_Rockets is PER, ORG, LOC, or O?	ORG
# Estado_de_Direito is PER, ORG, LOC, or O?	O
# Carlos_Andrés_Pérez is PER, ORG, LOC, or O?	EPR
# Carlos_Andrés_Pérez is PER, ORG, LOC, or O?	PER
# João_Gilberto is PER, ORG, LOC, or O?	PER
# Isso_é_Bossa_Nova is PER, ORG, LOC, or O?	O
# União_São_João is PER, ORG, LOC, or O?	O
# Copa_Bandeirantes is PER, ORG, LOC, or O?	O
# Série_A-1 is PER, ORG, LOC, or O?	O
# A-2 is PER, ORG, LOC, or O?	O
# Campeonato_Paulista is PER, ORG, LOC, or O?	ORG
# Letícia_Zioni_Gomes is PER, ORG, LOC, or O?	PER
# Bruno_Fanizzi is PER, ORG, LOC, or O?	PER
# Manoela_Nicoletti is PER, ORG, LOC, or O?	PER
# Lennart_Johansson is PER, ORG, LOC, or O?	PER
# Onze_de_Ouro is PER, ORG, LOC, or O?	O
# Onze_Mundial is PER, ORG, LOC, or O?	O
# Nosso_Senhor_do_Bonfim is PER, ORG, LOC, or O?	O
# Comissão_Mista_de_Orçamento is PER, ORG, LOC, or O?	ORG
# Universidade_Estadual_Paulista is PER, ORG, LOC, or O?	ORG
# Luiz_Gushiken is PER, ORG, LOC, or O?	PER
# Luiz_Azevedo is PER, ORG, LOC, or O?	PER
# Ministério_Público is PER, ORG, LOC, or O?	ORG
# Corrente_Sindical_Classista is PER, ORG, LOC, or O?	ORG
# Bourgueil_LÉchellerie is PER, ORG, LOC, or O?	O
# Les_Granges is PER, ORG, LOC, or O?	O
# Oscar_Tadaioshi_Izumi is PER, ORG, LOC, or O?	PER
# Wilma_Kovesi is PER, ORG, LOC, or O?	PER
# Tratado_de_Assunção is PER, ORG, LOC, or O?	O
# Beverly_Boulevard is PER, ORG, LOC, or O?	O
# Errol_Flynn is PER, ORG, LOC, or O?	PER
# Frank_Sinatra is PER, ORG, LOC, or O?	PER
# Billy_Wilder is PER, ORG, LOC, or O?	PER
# Dominick\'s is PER, ORG, LOC, or O?	O
# Bruce_Mendes_Campos is PER, ORG, LOC, or O?	PER
# Aloysio_Campos_da_Paz is PER, ORG, LOC, or O?	PER
# Márcio_Putnoki is PER, ORG, LOC, or O?	PER
# Q1 is PER, ORG, LOC, or O?	O
# Faculdade_de_Medicina is PER, ORG, LOC, or O?	O
# Banco_Real is PER, ORG, LOC, or O?	ORG
# João_Pessoa is PER, ORG, LOC, or O?	O
# Interferon_Beta is PER, ORG, LOC, or O?	O
# Faculdade_de_Direito is PER, ORG, LOC, or O?	O
# Barnes_and_Nobles is PER, ORG, LOC, or O?	ORG
# Viação_Boa_Vista is PER, ORG, LOC, or O?	ORG
# Polícia_Rodoviária is PER, ORG, LOC, or O?	ORG
# Hospital_Mário_Gatti is PER, ORG, LOC, or O?	ORG
# Centros_Populares_de_Cultura is PER, ORG, LOC, or O?	ORG
# União_Nacional_dos_Estudantes is PER, ORG, LOC, or O?	ORG
# Margaret_Thatcher is PER, ORG, LOC, or O?	PER
# Mancha_Verde is PER, ORG, LOC, or O?	ORG
# Gaviões_da_Fiel is PER, ORG, LOC, or O?	ORG
# Tribunal_Regional_Eleitoral is PER, ORG, LOC, or O?	ORG
# Rui_Ramos is PER, ORG, LOC, or O?	PER
# Sá_Freire is PER, ORG, LOC, or O?	PER
# Walter_Queiroz is PER, ORG, LOC, or O?	PER
# Renato_Trindade is PER, ORG, LOC, or O?	PER
# Gilberto_Fernandes is PER, ORG, LOC, or O?	PRE
# Gilberto_Fernandes is PER, ORG, LOC, or O?	PER
# A_Pesca_no_Amazonas_-_Segredos,_Roteiros_e_Estórias is PER, ORG, LOC, or O?	O
# Polícia_Militar is PER, ORG, LOC, or O?	ORG
# AM-10 is PER, ORG, LOC, or O?	O
# Céramus is PER, ORG, LOC, or O?	O
# Claude_Durand is PER, ORG, LOC, or O?	PER
# Ulysses_Guimarães is PER, ORG, LOC, or O?	PER
# Leitão_de_Abreu is PER, ORG, LOC, or O?	PER
# Gabinete_Civil is PER, ORG, LOC, or O?	ORG
# Tim_Maia is PER, ORG, LOC, or O?	PER
# Roger_Sperry is PER, ORG, LOC, or O?	PER
# Prêmio_Nobel is PER, ORG, LOC, or O?	O
# Instituto_da_Califórnia_para_Tecnologia_Avançada is PER, ORG, LOC, or O?	ORG
# Grupo_dos_Sete is PER, ORG, LOC, or O?	O
# Super-301 is PER, ORG, LOC, or O?	O
# Comando_Vermelho is PER, ORG, LOC, or O?	ORG
# Maurício_Corrêa is PER, ORG, LOC, or O?	PER
# Digable_Planets is PER, ORG, LOC, or O?	O
# Banco_Itamarati is PER, ORG, LOC, or O?	ORG
# Companhia_Brasileira_de_Alumínio is PER, ORG, LOC, or O?	ORG
# OAS_Participações is PER, ORG, LOC, or O?	ORG
# Antonio_Carlos_de_Moura is PER, ORG, LOC, or O?	PER
# Folha_da_Manhã_S/A is PER, ORG, LOC, or O?	ORG
# Partido_Revolucionário_Institucional is PER, ORG, LOC, or O?	ORG
# Ernesto_Zedillo is PER, ORG, LOC, or O?	PER
# Banana_Banana is PER, ORG, LOC, or O?	O
# Palácio_da_Justiça is PER, ORG, LOC, or O?	O
# José_Genoino is PER, ORG, LOC, or O?	PER
# José_Serra is PER, ORG, LOC, or O?	PER
# Zé_Milionário is PER, ORG, LOC, or O?	PER
# José_Carlos_Araújo is PER, ORG, LOC, or O?	PER
# Octávio_Cavalcanti_Lacombe is PER, ORG, LOC, or O?	PER
# Maria_Estela is PER, ORG, LOC, or O?	PER
# Ministério_Público_Estadual is PER, ORG, LOC, or O?	ORG
# Empresa_de_Correios_e_Telégrafos is PER, ORG, LOC, or O?	ORG
# Caixa_Econômica_Federal is PER, ORG, LOC, or O?	ORG
# Flávio_Pozzuto is PER, ORG, LOC, or O?	PER
# Hubert_Imóveis_e_Administração is PER, ORG, LOC, or O?	ORG
# Vila_Nova_Cachoeirinha is PER, ORG, LOC, or O?	LOC
# Tide_Setubal is PER, ORG, LOC, or O?	PER
# Revolução_dos_Cravos is PER, ORG, LOC, or O?	O
# Secretaria_Municipal_da_Administração is PER, ORG, LOC, or O?	PER
# Diário_Oficial is PER, ORG, LOC, or O?	O
# Rodney_King is PER, ORG, LOC, or O?	PER
# Osires_Lopes_Filho is PER, ORG, LOC, or O?	PER
# McDonald\'s is PER, ORG, LOC, or O?	ORG
# William_Rhodes is PER, ORG, LOC, or O?	ORG
# Segurança_Pública is PER, ORG, LOC, or O?	O
# Antônio_Correia_Meyer is PER, ORG, LOC, or O?	ORG
# Federação_Paulista_de_Futebol is PER, ORG, LOC, or O?	ORG
# Raul_Torres_&_Florêncio is PER, ORG, LOC, or O?	O
# Márcio_Ribeiro is PER, ORG, LOC, or O?	PER
# Departamento_de_Estradas_de_Rodagem is PER, ORG, LOC, or O?	ORG
# Through_the_Woods is PER, ORG, LOC, or O?	O
# Por_o_Bosque is PER, ORG, LOC, or O?	O
# At_the_Seashore is PER, ORG, LOC, or O?	O
# Em_a_Praia is PER, ORG, LOC, or O?	O
# Eliezer_Batista is PER, ORG, LOC, or O?	PER
# F-1 is PER, ORG, LOC, or O?	ORG
# Mário_Luna is PER, ORG, LOC, or O?	ORG
# Departamento_de_Crédito_e_Financiamento is PER, ORG, LOC, or O?	ORG
# Jair_Pereira is PER, ORG, LOC, or O?	EPR
# Jair_Pereira is PER, ORG, LOC, or O?	PER
# Caio_Martins is PER, ORG, LOC, or O?	ER
# Caio_Martins is PER, ORG, LOC, or O?	PER
# Alexander_Popov is PER, ORG, LOC, or O?	EPR
# Alexander_Popov is PER, ORG, LOC, or O?	PEr
# Alexander_Popov is PER, ORG, LOC, or O?	PER
# Financial_Times is PER, ORG, LOC, or O?	ORG
# O_Olho_da_Revolução is PER, ORG, LOC, or O?	O
# Antigo_Testamento is PER, ORG, LOC, or O?	O
# Presidência_da_República is PER, ORG, LOC, or O?	O
# Tribunal_Superior_Eleitoral is PER, ORG, LOC, or O?	PER
# Segunda_Guerra is PER, ORG, LOC, or O?	O
# Bruto_Rosé is PER, ORG, LOC, or O?	O
# João_Pato is PER, ORG, LOC, or O?	PER
# Cabernet_Sauvignon is PER, ORG, LOC, or O?	O
# Ana_Moser is PER, ORG, LOC, or O?	PER
# América_Latina is PER, ORG, LOC, or O?	O
# Sudeste_Asiático is PER, ORG, LOC, or O?	LOC
# Exército_Republicano_Irlandês is PER, ORG, LOC, or O?	ORG
# Irlanda_do_Norte is PER, ORG, LOC, or O?	LOC
# Frank_Kerr is PER, ORG, LOC, or O?	PER
# Jardim_Mutinga is PER, ORG, LOC, or O?	O
# Cia._City_de_Desenvolvimento is PER, ORG, LOC, or O?	O
# Sérgio_Ueta is PER, ORG, LOC, or O?	PER
# Ueta_Indústria_e_Comércio_de_Aparelhos_Eletrônicos is PER, ORG, LOC, or O?	ORG
# Empresarial_Jaraguá is PER, ORG, LOC, or O?	O
# Martin_Luther_King is PER, ORG, LOC, or O?	PER
# Humberto_Lucena is PER, ORG, LOC, or O?	PER
# Adylson_Motta is PER, ORG, LOC, or O?	PER
# Ambito_Financiero is PER, ORG, LOC, or O?	O
# Donna_Karan is PER, ORG, LOC, or O?	PER
# Bryant_Park is PER, ORG, LOC, or O?	PER
# Biblioteca_Nacional is PER, ORG, LOC, or O?	O
# Benito_Gama is PER, ORG, LOC, or O?	PER
# John_Paul_Getty is PER, ORG, LOC, or O?	PER
# John_Paul_Getty_2º is PER, ORG, LOC, or O?	PER
# Antonio_Canova is PER, ORG, LOC, or O?	PER
# Grande_Prêmio is PER, ORG, LOC, or O?	O
# Senna_erra_e_Schumacher_vence is PER, ORG, LOC, or O?	O
# Sean_Connery is PER, ORG, LOC, or O?	PER
# Kate_Moss is PER, ORG, LOC, or O?	PER
# Beni_Veras is PER, ORG, LOC, or O?	PER
# Gama\'a_al-Islamiya is PER, ORG, LOC, or O?	O
# Vale_do_São_Francisco is PER, ORG, LOC, or O?	LOC
# Francisco_Badenes is PER, ORG, LOC, or O?	PER
# Comissão_de_Processos_Administrativos_Especiais is PER, ORG, LOC, or O?	ORG
# Wilson_Barbosa is PER, ORG, LOC, or O?	PER
# Michael_Stipe is PER, ORG, LOC, or O?	PER
# Mike_Mills is PER, ORG, LOC, or O?	PER
# Losing_My_Religion is PER, ORG, LOC, or O?	O
# Roberto_Requião is PER, ORG, LOC, or O?	PER
# Movimento_Zona_Sul is PER, ORG, LOC, or O?	O
# Luiz_Antonio_Siqueira_Dias is PER, ORG, LOC, or O?	PER
# Folha_Informações is PER, ORG, LOC, or O?	O
# Instituto_Ulysses_Guimarães_de_Estudos_Políticos_e_Sociais is PER, ORG, LOC, or O?	ORG
# Forças_Armadas is PER, ORG, LOC, or O?	ORG
# Guatemala_Blues is PER, ORG, LOC, or O?	O
# Mostar_Sarajevo is PER, ORG, LOC, or O?	O
# Yasuhi_Akashi is PER, ORG, LOC, or O?	PER
# Saulo_Ramos is PER, ORG, LOC, or O?	PER
# Medida_Provisória is PER, ORG, LOC, or O?	O
# Unidade_Real_de_Valor is PER, ORG, LOC, or O?	PER
# Newmann/Hass is PER, ORG, LOC, or O?	O
# Raul_Boesel is PER, ORG, LOC, or O?	PER
# Joyce_Pascowitch is PER, ORG, LOC, or O?	PER
# Bruno_Bettelheim is PER, ORG, LOC, or O?	PER
# Câmara_Setorial is PER, ORG, LOC, or O?	PER
# Finame_Rural is PER, ORG, LOC, or O?	O
# Dennis_Robertson is PER, ORG, LOC, or O?	PER
# Lionel_Robbins is PER, ORG, LOC, or O?	PER
# Fernando_Casal_de_Rey is PER, ORG, LOC, or O?	O
# Jackie_O. is PER, ORG, LOC, or O?	PER
# O_Magnata_Grego is PER, ORG, LOC, or O?	O
# The_Greek_Tycoon is PER, ORG, LOC, or O?	O
# Anthony_Quinn is PER, ORG, LOC, or O?	PER
# Sócrates_Onassis is PER, ORG, LOC, or O?	PER
# Onassis:_The_Richest_Man_in_the_World is PER, ORG, LOC, or O?	O
# Manuel_Pacheco is PER, ORG, LOC, or O?	PER
# Plano_Cruzado is PER, ORG, LOC, or O?	O
# Igreja_Católica is PER, ORG, LOC, or O?	ORG
# Gianetti_da_Fonseca is PER, ORG, LOC, or O?	ORG
# Freddy_Tatoo is PER, ORG, LOC, or O?	O
# Tyes is PER, ORG, LOC, or O?	O
# André_Meyer is PER, ORG, LOC, or O?	PER
# José_Carlo_Dri is PER, ORG, LOC, or O?	PER
# Evander_Holyfield is PER, ORG, LOC, or O?	PER
# Associação_Mundial is PER, ORG, LOC, or O?	ORG
# Federação_Internacional is PER, ORG, LOC, or O?	ORG
# Michael_Moorer is PER, ORG, LOC, or O?	PER
# Manoel_Lopes_Duarte is PER, ORG, LOC, or O?	PER
# Bil_T._Jones is PER, ORG, LOC, or O?	PER
# An_American_Evening is PER, ORG, LOC, or O?	O
# I_Want_to_Cross_Over is PER, ORG, LOC, or O?	O
# Liz_McComb is PER, ORG, LOC, or O?	PER
# Donald_Baechler is PER, ORG, LOC, or O?	PER
# Ballet_da_Ópera_de_Lyon is PER, ORG, LOC, or O?	ORG
# Maguy_Marin is PER, ORG, LOC, or O?	PER
# Extra_Veinous is PER, ORG, LOC, or O?	O
# Susan_Marshall is PER, ORG, LOC, or O?	PER
# Ballet_de_Lyon is PER, ORG, LOC, or O?	ORG
# Central_Figure is PER, ORG, LOC, or O?	O
# Philip_Glass is PER, ORG, LOC, or O?	PER
# Julia_Child is PER, ORG, LOC, or O?	PER
# Marcella_Hazan is PER, ORG, LOC, or O?	PER
# Patricia_Wells is PER, ORG, LOC, or O?	PER
# Someone_to_Watch_Over_Me is PER, ORG, LOC, or O?	O
# Roberto_de_Oliveira is PER, ORG, LOC, or O?	PER
# Campanha_Contra_a_Fome is PER, ORG, LOC, or O?	O
# Prêmio_Nobel_da_Paz is PER, ORG, LOC, or O?	O
# Nelson_Mandela is PER, ORG, LOC, or O?	EPR
# Nelson_Mandela is PER, ORG, LOC, or O?	PER
# Tatau_Godinho is PER, ORG, LOC, or O?	PER
# Antônio_Amaral_de_Sampaio is PER, ORG, LOC, or O?	PER
# Constituição_Federal is PER, ORG, LOC, or O?	O
# Amauri_Mascaro_Nascimento is PER, ORG, LOC, or O?	PER
# Direito_Sindical is PER, ORG, LOC, or O?	O
# Santa_Casa is PER, ORG, LOC, or O?	O
# Mercedes_Ribeiro_de_Miranda is PER, ORG, LOC, or O?	PER
# Ana_Paula_Junqueira is PER, ORG, LOC, or O?	PER
# Ces-Senac is PER, ORG, LOC, or O?	ORG
# Oficina_de_Artes_do_Livro is PER, ORG, LOC, or O?	ORG
# Papel_Artesanal:_Processamento_de_Fibras_Vegetais is PER, ORG, LOC, or O?	O
# Elvis:_From_Nashville_To_Memphis is PER, ORG, LOC, or O?	O
# It\'s_Now_or_Never is PER, ORG, LOC, or O?	O
# Elvis_Aaron_Presley is PER, ORG, LOC, or O?	PER
# Elvis_Presley is PER, ORG, LOC, or O?	PER
# Monte_Aprazível is PER, ORG, LOC, or O?	O
# Rio_Preto-SP is PER, ORG, LOC, or O?	LOC
# Escritório_Regional_de_Saúde is PER, ORG, LOC, or O?	ORG
# Distrito_Federal is PER, ORG, LOC, or O?	LOC
# Ricardo_Jordão is PER, ORG, LOC, or O?	PER
# Arret_Chanin is PER, ORG, LOC, or O?	PER
# Gloria_Pires is PER, ORG, LOC, or O?	PER
# Orlando_Moraes is PER, ORG, LOC, or O?	PER
# Rita_Lee is PER, ORG, LOC, or O?	PER
# Enciclopédia_Britânica is PER, ORG, LOC, or O?	O
# Pearl_Harbour is PER, ORG, LOC, or O?	LOC
# Franklin_Delano_Roosevelt is PER, ORG, LOC, or O?	EPR
# Franklin_Delano_Roosevelt is PER, ORG, LOC, or O?	PER
# Nossa_Caixa is PER, ORG, LOC, or O?	O
# Paulo_Araújo is PER, ORG, LOC, or O?	PER
# Câmara_de_Comércio_Brasil-Estados_Unidos is PER, ORG, LOC, or O?	ORG
# Phillip_Trent is PER, ORG, LOC, or O?	PER
# Brian_Fagerburg is PER, ORG, LOC, or O?	PER
# Doreste_Batista is PER, ORG, LOC, or O?	PER
# Nilo_Batista is PER, ORG, LOC, or O?	PER
# Time_dos_Sonhos is PER, ORG, LOC, or O?	O
# Montoro_Filho is PER, ORG, LOC, or O?	PER
# Jovem_Pan is PER, ORG, LOC, or O?	ORG
# Guilherme_Palmeira is PER, ORG, LOC, or O?	PER
# Beavis_e_Butt-Head is PER, ORG, LOC, or O?	O
# Vara_Central_da_Infância_e_Juventude is PER, ORG, LOC, or O?	ORG
# Cristou is PER, ORG, LOC, or O?	O
# Bayern_Leverkusen is PER, ORG, LOC, or O?	PER
# Shalk-04 is PER, ORG, LOC, or O?	O
# Ponte_Preta is PER, ORG, LOC, or O?	ORG
# Francesco_Farina is PER, ORG, LOC, or O?	PER
# Gloria_Attanasio is PER, ORG, LOC, or O?	PER
# Mark_Fischer is PER, ORG, LOC, or O?	PER
# Steel_Wheels is PER, ORG, LOC, or O?	O
# Pink_Floyd is PER, ORG, LOC, or O?	ORG
# U2 is PER, ORG, LOC, or O?	ORG
# Chico_de_Miguel is PER, ORG, LOC, or O?	PER
# Liga_de_Assistência_e_Recuperação is PER, ORG, LOC, or O?	ORG
# Secretaria_de_Saúde is PER, ORG, LOC, or O?	ORG
# Conferência_sobre_Segurança_e_Cooperação_na_Europa is PER, ORG, LOC, or O?	ORG
# Jogos_da_Amizade is PER, ORG, LOC, or O?	O
# Hubert_Imóveis_e_Administração_Ltda is PER, ORG, LOC, or O?	ORG
# Avenida_Faria_Lima is PER, ORG, LOC, or O?	LOC
# Cartel_de_Cáli is PER, ORG, LOC, or O?	ORG
# Vicente_Wilson_Rivera_Ramos is PER, ORG, LOC, or O?	PER
# Vicente_Rivera_Gonzalez is PER, ORG, LOC, or O?	PER
# Leonel_Brizola is PER, ORG, LOC, or O?	PER
# Wapsa is PER, ORG, LOC, or O?	O
# A_Interpretação_dos_Sonhos is PER, ORG, LOC, or O?	O
# Roman_Jakobson is PER, ORG, LOC, or O?	PER
# Antonio_Britto is PER, ORG, LOC, or O?	PER
# Maria_Elisa_Flora_Demarchi is PER, ORG, LOC, or O?	PER
# Hospital_do_Mandaqui is PER, ORG, LOC, or O?	O
# Francis_Bacon is PER, ORG, LOC, or O?	PER
# Vila_Madalena is PER, ORG, LOC, or O?	LOC
# DJs_Bidi is PER, ORG, LOC, or O?	O
# Pailista is PER, ORG, LOC, or O?	O
# Brigadeiro_Luís_Antônio is PER, ORG, LOC, or O?	PER
# Eliseu_Francisco_de_Lyra is PER, ORG, LOC, or O?	PER
# Richard_Dart is PER, ORG, LOC, or O?	PER
# Richard_Gustafson is PER, ORG, LOC, or O?	PER
# Universidade_de_Arizona is PER, ORG, LOC, or O?	ORG
# Agência_Meteorológica_Japonesa is PER, ORG, LOC, or O?	ORG
# Engenheiro_Marsilac is PER, ORG, LOC, or O?	O
# Cidade_Tiradentes is PER, ORG, LOC, or O?	LOC
# Eduardo_Lourenço is PER, ORG, LOC, or O?	PER
# José_Saramago is PER, ORG, LOC, or O?	PER
# Aldegy_do_Nascimento is PER, ORG, LOC, or O?	PER
# Ary_Chagas_de_Aguiar is PER, ORG, LOC, or O?	PER
# Lúcia_Atalla is PER, ORG, LOC, or O?	PER
# Spike_Lee is PER, ORG, LOC, or O?	PER
# The_Jackson_5 is PER, ORG, LOC, or O?	ORG
# Jimi_Hendrix is PER, ORG, LOC, or O?	PER
# James_Brown is PER, ORG, LOC, or O?	PER
# Dave_Bruce is PER, ORG, LOC, or O?	PER
# Adroaldo_Streck is PER, ORG, LOC, or O?	PER
# Barra_Funda is PER, ORG, LOC, or O?	O
# G._Love_and_Special_Sauce is PER, ORG, LOC, or O?	O
# Tribunal_Superior_do_Trabalho is PER, ORG, LOC, or O?	ORG
# Ordem_dos_Advogados_do_Brasil is PER, ORG, LOC, or O?	ORG
# Serviço_de_Apoio_à_Pequena_e_Média_Empresa is PER, ORG, LOC, or O?	ORG
# Conflitos_no_Campo_Brasil_1993 is PER, ORG, LOC, or O?	O
# Associação_Brasileira_de_Imprensa is PER, ORG, LOC, or O?	ORG
# Comissão_Pastoral_da_Terra is PER, ORG, LOC, or O?	ORG
# Andrew_Duncan is PER, ORG, LOC, or O?	PER
# José_Nazar is PER, ORG, LOC, or O?	PER
# Miguel_Reale_Jr. is PER, ORG, LOC, or O?	PER
# Anna_Lee-Feldstein is PER, ORG, LOC, or O?	PER
# Universidade_da_Califórnia is PER, ORG, LOC, or O?	ORG
# Marcus_Vinícius is PER, ORG, LOC, or O?	PER
# Anderson_Leão is PER, ORG, LOC, or O?	PER
# Silvio_Santos is PER, ORG, LOC, or O?	PER
# Esplanada_Grill is PER, ORG, LOC, or O?	ORG
# Rubinho_Gimenes is PER, ORG, LOC, or O?	PER
# Kazuo_Tamura is PER, ORG, LOC, or O?	PER
# Lélio_Viana_Lôbo is PER, ORG, LOC, or O?	PER
# Dia_do_Soldado is PER, ORG, LOC, or O?	O
# Frank_Zappa is PER, ORG, LOC, or O?	PER
# Mano_Bap is PER, ORG, LOC, or O?	O
# The_Central_Scrutinizer is PER, ORG, LOC, or O?	O
# Christoph_Heinrich_Von_Beackedorff is PER, ORG, LOC, or O?	PER
# Free_Jazz_Festival is PER, ORG, LOC, or O?	ORG
# US3 is PER, ORG, LOC, or O?	O
# Associação_Brasileira_da_Indústria_de_Máquinas is PER, ORG, LOC, or O?	ORG
# Gelaguela_Sobremesas is PER, ORG, LOC, or O?	ORG
# Juarez_Rizzieri is PER, ORG, LOC, or O?	PER
# Body_for_Sure is PER, ORG, LOC, or O?	O
# Humberto_Nastari is PER, ORG, LOC, or O?	PER
# Universidade_Yale is PER, ORG, LOC, or O?	ORG
# Adventure_in_Castle is PER, ORG, LOC, or O?	O
# Journey_in_the_Universe is PER, ORG, LOC, or O?	O
# Multimídia_Center is PER, ORG, LOC, or O?	O
# Carlos_Mariani_Bittencourt is PER, ORG, LOC, or O?	PER
# Sinn_Fein is PER, ORG, LOC, or O?	PER
# Patrick_Mayhew is PER, ORG, LOC, or O?	PER
# Conselho_Regional_de_Economia is PER, ORG, LOC, or O?	ORG
# Sistema_de_Projeções_Qualificadas is PER, ORG, LOC, or O?	O
# Hélio_Portocarrero is PER, ORG, LOC, or O?	PER
# Vicente_Amato_Neto is PER, ORG, LOC, or O?	PER
# Amato_Neto is PER, ORG, LOC, or O?	PER
# Campeonato_Italiano is PER, ORG, LOC, or O?	ORG
# Zdenek_Zeman is PER, ORG, LOC, or O?	PER
# Alan_Boksic is PER, ORG, LOC, or O?	PER
# Otto_Reiter is PER, ORG, LOC, or O?	PER
# Ricardo_Fiuza is PER, ORG, LOC, or O?	PER
# Cid_Carvalho is PER, ORG, LOC, or O?	PER
# José_Geraldo is PER, ORG, LOC, or O?	PER
# Manoel_Moreira is PER, ORG, LOC, or O?	PER
# Fábio_Raunheitti is PER, ORG, LOC, or O?	PER
# Paulo_Portugal is PER, ORG, LOC, or O?	PER
# Olacyr_de_Moraes is PER, ORG, LOC, or O?	PER
# Alfredo_Saad is PER, ORG, LOC, or O?	PER
# Rolim_Amaro is PER, ORG, LOC, or O?	PER
# Maja_Desnuda is PER, ORG, LOC, or O?	PER
# Idade_Média is PER, ORG, LOC, or O?	O
# Boris_Gorentzvaig is PER, ORG, LOC, or O?	PER
# Vera_Melo_Araújo is PER, ORG, LOC, or O?	PER
# Departamento_de_Fiscalização is PER, ORG, LOC, or O?	ORG
# Fábio_Igel is PER, ORG, LOC, or O?	PER
# João_Herreras is PER, ORG, LOC, or O?	PER
# Marcelo_Loureiro is PER, ORG, LOC, or O?	PER
# Mulher,_a_Melhor_Opção_de_Investimento is PER, ORG, LOC, or O?	O
# Teatro_Itália is PER, ORG, LOC, or O?	LOC
# Vera_Lúcia_Barbosa is PER, ORG, LOC, or O?	PER
# Rio-São_Paulo is PER, ORG, LOC, or O?	O
# René_Scorsa is PER, ORG, LOC, or O?	PER
# Sérgio_Duran is PER, ORG, LOC, or O?	PER
# Serviço_de_Segurança_ao_Crédito_e_Informações is PER, ORG, LOC, or O?	ORG
# Indústrias_J.B._Duarte is PER, ORG, LOC, or O?	ORG
# Antonio_Delapieve is PER, ORG, LOC, or O?	PER
# Henry_Kissinger is PER, ORG, LOC, or O?	PER
# Mangosuthu_Buthelezi is PER, ORG, LOC, or O?	PER
# Burhanuddin_Rabbani is PER, ORG, LOC, or O?	PER
# Gulbuddin_Hekmatyar is PER, ORG, LOC, or O?	PER
# Cachoeiro_do_Itapemirim is PER, ORG, LOC, or O?	O
# Partido_Liberal_Democrático is PER, ORG, LOC, or O?	ORG
# Yohei_Kono is PER, ORG, LOC, or O?	PER
# James_McDougal is PER, ORG, LOC, or O?	PER
# Bruno_Maranhão is PER, ORG, LOC, or O?	PER
# Movimento_por_Terra,_Trabalho_e_Liberdade is PER, ORG, LOC, or O?	ORG
# Sérgio_Machado is PER, ORG, LOC, or O?	PER
# Smirnoff_International_Fashion_Awards is PER, ORG, LOC, or O?	O
# Raoul_Coutard is PER, ORG, LOC, or O?	PER
# Junta_da_Justiça_do_Trabalho is PER, ORG, LOC, or O?	ORG
# Sindicato_dos_Jornalistas is PER, ORG, LOC, or O?	ORG
# Leonardo_Romanioli_Filho is PER, ORG, LOC, or O?	PER
# Luís_Silveira is PER, ORG, LOC, or O?	PER
# José_Fioravanti is PER, ORG, LOC, or O?	PER
# Santana_Quantum is PER, ORG, LOC, or O?	O
# Sérgio_Fioravanti is PER, ORG, LOC, or O?	PER
# Campeonato_Brasileiro is PER, ORG, LOC, or O?	ORG
# Emily_Lloyd is PER, ORG, LOC, or O?	PER
# Tank_Girl is PER, ORG, LOC, or O?	O
# TV_Doctor_Who is PER, ORG, LOC, or O?	O
# Chris_Columbus is PER, ORG, LOC, or O?	PER
# Quarteto_Fantástico is PER, ORG, LOC, or O?	O
# Sargento_Rock is PER, ORG, LOC, or O?	PER
# Joel_Silver is PER, ORG, LOC, or O?	PER
# Arnold_Schwarzenegger is PER, ORG, LOC, or O?	PER
# Bruce_Willis is PER, ORG, LOC, or O?	PER
# Dia_das_Mães is PER, ORG, LOC, or O?	O
# West_Plaza is PER, ORG, LOC, or O?	LOC
# Guarda_Nacional is PER, ORG, LOC, or O?	ORG
# Waldemar_de_Brito is PER, ORG, LOC, or O?	PER
# São_Januário is PER, ORG, LOC, or O?	LOC
# Centro_de_Biologia_Marinha is PER, ORG, LOC, or O?	ORG
# Centro_de_Ambulâncias is PER, ORG, LOC, or O?	ORG
# Nova_Zelândia is PER, ORG, LOC, or O?	LOC
# Algirdas_Zebrauskas is PER, ORG, LOC, or O?	PER
# Leonid_Kravtchuk is PER, ORG, LOC, or O?	PER
# Parceria_pela_Paz is PER, ORG, LOC, or O?	O
# Leste_Europeu is PER, ORG, LOC, or O?	LOC
# Armando_Laganá is PER, ORG, LOC, or O?	PER
# Márcio_Rillo is PER, ORG, LOC, or O?	PER
# Stephen_Freehill is PER, ORG, LOC, or O?	PER
# Michael_Fay is PER, ORG, LOC, or O?	PER
# Al_Anad is PER, ORG, LOC, or O?	PER
# Ali_Abdulllah_Saleh is PER, ORG, LOC, or O?	PER
# Virginia_de_la_Guardia is PER, ORG, LOC, or O?	O
# Médicos_Sem_Fronteiras is PER, ORG, LOC, or O?	ORG
# Rubens_Gonçalves_Barrichello is PER, ORG, LOC, or O?	PER
# Campeonato_Brasileiro_de_Fórmula_Ford is PER, ORG, LOC, or O?	ORG
# Marcos_Augusto_Gonçalves is PER, ORG, LOC, or O?	PER
# Revista_da_Folha is PER, ORG, LOC, or O?	O
# Superintendência_Nacional_de_Abastecimento is PER, ORG, LOC, or O?	ORG
# Eduardo_Lago is PER, ORG, LOC, or O?	PER
# Joseph_McCarthy is PER, ORG, LOC, or O?	PER
# Novo_México is PER, ORG, LOC, or O?	LOC
# Ministério_das_Relações_Exteriores is PER, ORG, LOC, or O?	ORG
# Carlos_Alberto_Dias is PER, ORG, LOC, or O?	PER
# California_State_University is PER, ORG, LOC, or O?	ORG
# República_Movimento is PER, ORG, LOC, or O?	ORG
# Orquestra_Estadual is PER, ORG, LOC, or O?	ORG
# Nona_de_Beethoven is PER, ORG, LOC, or O?	O
# Simon_Franco is PER, ORG, LOC, or O?	PER
# Simon_Franco_Recursos_Humanos is PER, ORG, LOC, or O?	PER
# Conselho_Federal_de_Medicina is PER, ORG, LOC, or O?	ORG
# Antonio_Henrique_Pedrosa_Neto is PER, ORG, LOC, or O?	PER
# Nova_Brasília is PER, ORG, LOC, or O?	O
# Mauro_Pereira is PER, ORG, LOC, or O?	PER
# Gilson_Paulino_dos_Santos is PER, ORG, LOC, or O?	PER
# Batalhão_de_Choque is PER, ORG, LOC, or O?	ORG
# Vila_do_João is PER, ORG, LOC, or O?	LOC
# Adriano_Herculano_da_Silva is PER, ORG, LOC, or O?	PER
# Onaldo_Pereira is PER, ORG, LOC, or O?	PER
# Comunidade_Pacifista_Cristã is PER, ORG, LOC, or O?	ORG
# Torneio_Internacional_de_Basquete is PER, ORG, LOC, or O?	ORG
# Miguel_Ângelo_da_Luz is PER, ORG, LOC, or O?	PER
# Terra_Boa is PER, ORG, LOC, or O?	O
# Mata_Velha is PER, ORG, LOC, or O?	O
# Santya is PER, ORG, LOC, or O?	O
# Chummak is PER, ORG, LOC, or O?	O
# Times_Square is PER, ORG, LOC, or O?	LOC
# Ministério_da_Previdência is PER, ORG, LOC, or O?	ORG
# Alexandre_Dupeyrat is PER, ORG, LOC, or O?	ORG
# Olhos_de_Serpente is PER, ORG, LOC, or O?	O
# Snake_Eyes is PER, ORG, LOC, or O?	O
# Abel_Ferrara is PER, ORG, LOC, or O?	PER
# Harvey_Keitel is PER, ORG, LOC, or O?	PER
# James_Russo is PER, ORG, LOC, or O?	PER
# Serena_Cay is PER, ORG, LOC, or O?	PER
# Casa_de_Campo is PER, ORG, LOC, or O?	O
# Sérgio_Motta is PER, ORG, LOC, or O?	PER
# Paulo_Renato_de_Souza is PER, ORG, LOC, or O?	PER
# Maria_Carey is PER, ORG, LOC, or O?	PER
# Irene_Papas is PER, ORG, LOC, or O?	PER
# Dalmo_Rosalen is PER, ORG, LOC, or O?	PER
# Secretaria_do_Meio_Ambiente is PER, ORG, LOC, or O?	ORG
# Vale_do_Piracicaba is PER, ORG, LOC, or O?	LOC
# Julie_Halard is PER, ORG, LOC, or O?	PER
# Virginia_Slims_Masters is PER, ORG, LOC, or O?	PER
# Madison_Square_Garden is PER, ORG, LOC, or O?	LOC
# Osny_Silveira_Neto is PER, ORG, LOC, or O?	PER
# Guilherme_Silveira is PER, ORG, LOC, or O?	PER
# Marilena_Chaui is PER, ORG, LOC, or O?	PER
# Gloria_Kalil is PER, ORG, LOC, or O?	PER
# Jorge_da_Cunha_Lima is PER, ORG, LOC, or O?	PER
# Claude_Lefort is PER, ORG, LOC, or O?	PER
# Sérgio_Cardoso is PER, ORG, LOC, or O?	PER
# Cláudia_Morgado is PER, ORG, LOC, or O?	PER
# Dick_Advocaat is PER, ORG, LOC, or O?	PER
# Manoel_Salviano is PER, ORG, LOC, or O?	PER
# Renata_Queiróz is PER, ORG, LOC, or O?	PER
# Patrícia_Gomes is PER, ORG, LOC, or O?	PER
# Ciro_Gomes is PER, ORG, LOC, or O?	PER
# Ruth_Cardoso is PER, ORG, LOC, or O?	PER
# ColorEdge is PER, ORG, LOC, or O?	O
# Lono_Island is PER, ORG, LOC, or O?	O
# Southern_Methodist_University is PER, ORG, LOC, or O?	ORG
# Manuel_Tavares_da_Graça is PER, ORG, LOC, or O?	PER
# José_Tavares_da_Graça is PER, ORG, LOC, or O?	PER
# Floriano_Graça is PER, ORG, LOC, or O?	PER
# John_Cassavettes is PER, ORG, LOC, or O?	PER
# Kim_Ho is PER, ORG, LOC, or O?	PER
# Conselho_de_Segurança is PER, ORG, LOC, or O?	ORG
# Boutros_Boutros-Ghali is PER, ORG, LOC, or O?	O
# Fernando_Belo is PER, ORG, LOC, or O?	PER
# Marcello_Alencar is PER, ORG, LOC, or O?	PER
# André_Penner is PER, ORG, LOC, or O?	PER
# Eduardo_Castanho is PER, ORG, LOC, or O?	PER
# Saul_Queiroz is PER, ORG, LOC, or O?	PER
# Rogério_Voltan is PER, ORG, LOC, or O?	PER
# Ricardo_Hantzchel is PER, ORG, LOC, or O?	PER
# Fausto_Chermont is PER, ORG, LOC, or O?	PER
# Eliana_Lopes is PER, ORG, LOC, or O?	PER
# Ribeirão_Preto is PER, ORG, LOC, or O?	PER
# Castelo_Branco is PER, ORG, LOC, or O?	O
# Serra_das_Conchas is PER, ORG, LOC, or O?	LOC
# Cidade_do_México is PER, ORG, LOC, or O?	LOC
# Mercedes_Rossi_de_Almeida is PER, ORG, LOC, or O?	PER
# Sven-Goran_Eriksson is PER, ORG, LOC, or O?	PER
# Ruud_Gullit is PER, ORG, LOC, or O?	PER
# Giampiero_Boniperti is PER, ORG, LOC, or O?	PER
# Roberto_Bettega is PER, ORG, LOC, or O?	PER
# Giovanni_Trapattoni is PER, ORG, LOC, or O?	PER
# Marcello_Lippi is PER, ORG, LOC, or O?	PER
# Roberto_Baggio is PER, ORG, LOC, or O?	PER
# Visconde_de_Porto_Seguro is PER, ORG, LOC, or O?	O
# Godofredo_Furtado is PER, ORG, LOC, or O?	PER
# Antonio_Carlos_Gomes_da_Silva is PER, ORG, LOC, or O?	PER
# VERA_LÚCIA_DA_COSTA_ANTUNES is PER, ORG, LOC, or O?	PER
# Arnaldo_Montenegro is PER, ORG, LOC, or O?	EPR
# Arnaldo_Montenegro is PER, ORG, LOC, or O?	pER
# Arnaldo_Montenegro is PER, ORG, LOC, or O?	PER
# Andrade_Martins is PER, ORG, LOC, or O?	PER
# Robert_Winston is PER, ORG, LOC, or O?	PER
# Franco_Zefirelli is PER, ORG, LOC, or O?	PER
# Abram_Szajman is PER, ORG, LOC, or O?	PER
# Conselho_Deliberatico is PER, ORG, LOC, or O?	ORG
# Mauro_Salles is PER, ORG, LOC, or O?	PER
# Alexandra_Brochen is PER, ORG, LOC, or O?	PER

# %% [markdown]
# #### 3.1 Estimate distribution

# %%
df_ner= pd.read_csv('corpus-words-missing-ner-tags.txt', sep='\t', index_col=False)
df_ner.sort_values('TOKEN', axis=0, inplace=True)
table= pd.pivot_table(data=df_ner, index='NER_TAG', values='TOKEN', aggfunc=len)
table
# Out:
#          TOKEN
# NER_TAG
# LOC         78
# O          332
# ORG        265
# PER        629

# %%
df_orgs= df_ner[df_ner['NER_TAG']=='ORG']
df_orgs.sort_values('TOKEN', axis=0, inplace=True)
df_orgs.to_csv('corpus-word-missing-orgs.txt', sep='\t', index=False)

# %%
df_pers= df_ner[df_ner['NER_TAG']=='PER']
df_pers.sort_values('TOKEN', axis=0, inplace=True)
df_pers.to_csv('corpus-word-missing-pers.txt', sep='\t', index=False)

# %%
df_locs= df_ner[df_ner['NER_TAG']=='LOC']
df_locs.sort_values('TOKEN', axis=0, inplace=True)
df_locs.to_csv('corpus-word-missing-locs.txt', sep='\t', index=False)

# %%
df_o= df_ner[df_ner['NER_TAG']=='O']
df_o.sort_values('TOKEN', axis=0, inplace=True)
df_o.to_csv('corpus-word-missing-o.txt', sep='\t')
# Out:
# /Users/Varela/anaconda/envs/tensorflow/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
