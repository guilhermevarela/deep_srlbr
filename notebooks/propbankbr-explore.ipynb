# %%
import pandas as pd 
from propbankbr_utils import propbankbr_parser, propbankbr_argument_stats, propbankbr_split

# %%
df = propbankbr_parser() 
df.head(30)
# Out:
#     ID  S  P                FORM               LEMMA   GPOS       MORF DTREE  \
# 0    1  1  0            Brasília            Brasília   PROP        F|S     5
# 1    2  1  0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S     5
# 2    3  1  0           publicada            publicar  V-PCP        F|S     2
# 3    4  1  0                hoje                hoje    ADV          -     3
# 4    5  1  1              revela             revelar  V-FIN  PR|3S|IND     0
# 5    6  1  1                  um                  um    ART        M|S     7
# 6    7  1  1                dado                dado      N        M|S     5
# 7    8  1  1        supreendente       surpreendente    ADJ        M|S     7
# 8    9  1  1                   :                   -     PU          -     7
# 9   10  1  2           recusando             recusar  V-GER          -    25
# 10  11  1  2                 uma                  um    ART        F|S    12
# 11  12  1  2             postura             postura      N        F|S    10
# 12  13  1  2             radical             radical    ADJ        F|S    12
# 13  14  1  2                   ,                   -     PU          -    25
# 14  15  1  2                   a                   o    ART        F|S    17
# 15  16  1  2          esmagadora           esmagador    ADJ        F|S    17
# 16  17  1  2             maioria             maioria      N        F|S    25
# 17  18  1  2                   (                   -     PU          -    17
# 18  19  1  2                  77                  77    NUM        M|P    20
# 19  20  1  2                   %                   %      N        M|P    17
# 20  21  1  2                   )                   -     PU          -    17
# 21  22  1  2                  de                  de    PRP          -    17
# 22  23  1  2                  os                   o    ART        M|P    24
# 23  24  1  2           eleitores             eleitor      N        M|P    22
# 24  25  1  3                quer              querer  V-FIN  PR|3S|IND     7
# 25  26  1  3                   o                   o    ART        M|S    27
# 26  27  1  3                  PT                  PT   PROP        M|S    25
# 27  28  1  4        participando          participar  V-GER          -    25
# 28  29  1  4                  de                  de    PRP          -    28
# 29  30  1  4                   o                   o    ART        M|S    31
#
#       FUNC          CTREE        PRED  ARG0  ARG1      ARG2  ARG3 ARG4 ARG5  \
# 0     ADVL      (FCL(NP*)           -     *     *         *     *  NaN  NaN
# 1     SUBJ           (NP*           -  (A0*     *         *     *  NaN  NaN
# 2       N<      (ICL(VP*)           -     *     *         *     *  NaN  NaN
# 3     ADVL      (ADVP*)))           -    *)     *         *     *  NaN  NaN
# 4      STA          (VP*)     revelar  (V*)     *         *     *  NaN  NaN
# 5       >N           (NP*           -  (A1*     *         *     *  NaN  NaN
# 6      ACC              *           -     *     *         *     *  NaN  NaN
# 7       N<        (ADJP*)           -     *     *         *     *  NaN  NaN
# 8       PU              *           -     *     *         *     *  NaN  NaN
# 9     ADVL  (FCL(ICL(VP*)     recusar     *  (V*)  (AM-ADV*     *  NaN  NaN
# 10      >N           (NP*           -     *  (A1*         *     *  NaN  NaN
# 11     ACC              *           -     *     *         *     *  NaN  NaN
# 12      N<      (ADJP*)))           -     *    *)        *)     *  NaN  NaN
# 13      PU              *           -     *     *         *     *  NaN  NaN
# 14      >N           (NP*           -     *     *      (A0*     *  NaN  NaN
# 15      >N              *           -     *     *         *     *  NaN  NaN
# 16    SUBJ              *           -     *     *         *     *  NaN  NaN
# 17      PU              *           -     *     *         *     *  NaN  NaN
# 18      >N           (NP*           -     *     *         *     *  NaN  NaN
# 19  N<PRED             *)           -     *     *         *     *  NaN  NaN
# 20      PU              *           -     *     *         *     *  NaN  NaN
# 21      N<           (PP*           -     *     *         *     *  NaN  NaN
# 22      >N           (NP*           -     *     *         *     *  NaN  NaN
# 23      P<           *)))           -     *     *        *)     *  NaN  NaN
# 24  N<PRED          (VP*)      querer     *     *      (V*)     *  NaN  NaN
# 25      >N           (NP*           -     *     *      (A1*  (A0*  NaN  NaN
# 26     ACC             *)           -     *     *        *)    *)  NaN  NaN
# 27      OC      (ICL(VP*)  participar     *     *  (AM-LOC*  (V*)  NaN  NaN
# 28     PIV           (PP*           -     *     *         *  (A1*  NaN  NaN
# 29      >N           (NP*           -     *     *         *     *  NaN  NaN
#
#    ARG6
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN
# 26  NaN
# 27  NaN
# 28  NaN
# 29  NaN

# %%
dfdevel, dfvalid, dftest= propbankbr_split(df)
dftrain= pd.concat((dfdevel,dfvalid))

# %%
print('====train database====')
prop_train=max(dftrain['P'])-min(dftrain['P'])
sent_train=max(dftrain['S'])-min(dftrain['S'])
verb_train=len(set(dftrain['PRED']))-1

prop_develop=max(dfdevel['P'])-min(dfdevel['P'])
sent_develop=max(dfdevel['S'])-min(dfdevel['S'])
verb_develop=len(set(dfdevel['PRED']))-1


prop_develop_perc= (float(prop_develop) / prop_train)*100
sent_develop_perc= (float(sent_develop) / sent_train)*100
verb_develop_perc= (float(verb_develop) / verb_train)*100


prop_valid=max(dfvalid['P'])-min(dfvalid['P'])
sent_valid=max(dfvalid['S'])-min(dfvalid['S'])
verb_valid=len(set(dfvalid['PRED']))-1

prop_valid_perc= (float(prop_valid) / prop_train)*100
sent_valid_perc= (float(sent_valid) / sent_train)*100
verb_valid_perc= (float(verb_valid) / verb_train)*100

print('\t\t\ttrain\t\tdevel\t\tvalid')
values=('Proposições',prop_train,100.0,prop_develop, prop_develop_perc, prop_valid, prop_valid_perc)
buff= '%s\t%d %.2f\t%d %.2f\t%d %.2f\t' %  values
print(buff)    
values=('Sentenças',sent_train,100.0,sent_develop, sent_develop_perc, sent_valid, sent_valid_perc)
buff= '%s\t%d %.2f\t%d %.2f\t%d %.2f\t' %  values
print(buff)    
values=('Verbos Distintos',verb_train,100.0,verb_develop, verb_develop_perc, verb_valid, verb_valid_perc)
buff= '%s\t%d %.2f\t%d %.2f\t%d %.2f\t' %  values
print(buff)
# Out:
# ====train database====
# 			train		devel		valid
# Proposições	5668 100.00	5099 89.96	569 10.04
# Sentenças	3203 100.00	2877 89.82	325 10.15
# Verbos Distintos	1005 100.00	973 96.82	255 25.37

# %%
print('====test database====')
print('propositions:', max(dftest['P'])-min(dftest['P']))
print('sentences:', max(dftest['S'])-min(dftest['S']))
print('verbs distinct:', len(set(dftest['PRED']))-1)

print('====total database====')
print('propositions:', max(df['P'])-min(df['P']))
print('sentences:', max(df['S'])-min(df['S']))
print('verbs distinct:', len(set(df['PRED']))-1)


print('propositions:',(max(dftest['P'])-min(dftest['P'])) /(max(df['P'])-min(df['P']) ))
# Out:
# ====test database====
# propositions: 263
# sentences: 143
# verbs distinct: 156
# ====total database====
# propositions: 5931
# sentences: 3347
# verbs distinct: 1026
# propositions: 0.04434328106558759

# %%
stats = propbankbr_argument_stats(df)
stats_train= propbankbr_argument_stats(dftrain)
stats_devel= propbankbr_argument_stats(dfdevel)
stats_valid= propbankbr_argument_stats(dfvalid)
stats_test=  propbankbr_argument_stats(dftest)

devel_total=0
train_total=0
valid_total=0
arguments=['A0','A1','A2','A3','A4','A5',
'AM-ADV','AM-CAU','AM-DIR','AM-DIS','AM-EXT','AM-LOC',
'AM-MED','AM-MNR','AM-NEG','AM-PNC','AM-PRD','AM-REC',
'AM-TMP']
print('ARG\ttrain\t\tdevel\t\tvalid')
for key in arguments:
    trainvalue = stats_train.get(key,0)
    trainperc  = 100.0
    develvalue = stats_devel.get(key,0)
    develperc  = 100*(float(develvalue) / trainvalue)
    validvalue = stats_valid.get(key,0)
    validperc  = 100*(float(validvalue) / trainvalue)
    values=(key, trainvalue, trainperc, develvalue, develperc, validvalue, validperc)
    devel_total+=    develvalue
    train_total+=    trainvalue
    valid_total+=    validvalue
    buff= '%s\t%d %.2f\t%d %.2f\t%d %.2f\t' %  values
    print(buff)    
    
print('train total:',train_total,float(train_total)*100/train_total)    
print('devel total:',devel_total,float(devel_total)*100/train_total)    
print('valid total:',valid_total,float(valid_total)*100/train_total)
# Out:
# ARG	train		devel		valid
# A0	2953 100.00	2693 91.20	260 8.80
# A1	5182 100.00	4663 89.98	519 10.02
# A2	1332 100.00	1130 84.83	202 15.17
# A3	148 100.00	131 88.51	17 11.49
# A4	110 100.00	99 90.00	11 10.00
# A5	1 100.00	1 100.00	0 0.00
# AM-ADV	357 100.00	334 93.56	23 6.44
# AM-CAU	152 100.00	135 88.82	17 11.18
# AM-DIR	12 100.00	11 91.67	1 8.33
# AM-DIS	295 100.00	269 91.19	26 8.81
# AM-EXT	78 100.00	72 92.31	6 7.69
# AM-LOC	686 100.00	629 91.69	57 8.31
# AM-MED	3 100.00	3 100.00	0 0.00
# AM-MNR	392 100.00	363 92.60	29 7.40
# AM-NEG	324 100.00	286 88.27	38 11.73
# AM-PNC	153 100.00	144 94.12	9 5.88
# AM-PRD	182 100.00	164 90.11	18 9.89
# AM-REC	8 100.00	8 100.00	0 0.00
# AM-TMP	1117 100.00	1025 91.76	92 8.24
# train total: 13485 100.0
# devel total: 12160 90.17426770485724
# valid total: 1325 9.825732295142751
