# %%
import pandas as pd 
from propbankbr_utils import propbankbr_parser2, propbankbr_argument_stats

# %%
df = propbankbr_parser2() 
df.head(30)
# Out:
#        ID  S  P                       FORM                      LEMMA  \
# 0   1      1  0  Brasília                   Brasília
# 1   2      1  0  Pesquisa_Datafolha         Pesquisa_Datafolha
# 2   3      1  0  publicada                  publicar
# 3   4      1  0  hoje                       hoje
# 4   5      1  1  revela                     revelar
# 5   6      1  1  um                         um
# 6   7      1  1  dado                       dado
# 7   8      1  1  supreendente               surpreendente
# 8   9      1  1  :                          -
# 9   10     1  2  recusando                  recusar
# 10  11     1  2  uma                        um
# 11  12     1  2  postura                    postura
# 12  13     1  2  radical                    radical
# 13  14     1  2  ,                          -
# 14  15     1  2  a                          o
# 15  16     1  2  esmagadora                 esmagador
# 16  17     1  2  maioria                    maioria
# ...

# %%
print('propositions:', max(df['P']))
print('sentences:', max(df['S']))
print('verbs distinct:', len(set(df['PRED']))-1)
# Out:
# propositions: 5931
# sentences: 3348
# verbs distinct: 1026

# %%
stats = propbankbr_argument_stats(df)
for key in set(stats.keys()):
    print(key,':',stats[key])
# Out:
# AM-REC : 8
# AM-MNR : 410
# AM-PRD : 188
# AM-NEG : 346
# A4 : 114
# AM-ADV : 377
# A2 : 1406
# AM-TMP : 1155
# A1 : 5419
# A5 : 1
# AM-DIS : 310
# A3 : 150
# AM-DIR : 13
# AM-MED : 3
# A0 : 3068
# AM-EXT : 79
# AM-CAU : 154
# AM-PNC : 157
# AM-LOC : 715
