# %%
import sys
sys.path.insert(0,'../models/')
sys.path.insert(0,'../datasets/')
sys.path.insert(0,'..')

import pandas as pd
import numpy as np
import json
from subprocess import Popen, PIPE, STDOUT
import re
from collections import defaultdict

import tensorflow as tf
import tqdm
from models import PropbankEncoder
import config

INPUT_DIR = '../datasets/binaries/'
PROPBANK_GLO50_PATH = '{:}deep_glo50.pickle'.format(INPUT_DIR)
PEARL_SRLEVAL_PATH = '../srlconll-1.1/bin/srl-eval.pl'

# %% [markdown]
# <h1><center>Structured Prediction Network CWIS SRL (BR)</center></h1>

# %% [markdown]
# <center>In this notebook we solve the semantic role labeling task using structured predictions networks.</center>

# %% [markdown]
# ## 1. Builds a "human friendly" version of the dataset

# %%
dfgs = pd.read_csv('../datasets/csvs/gs.csv', index_col=0, sep=',', encoding='utf-8')
column_files = [
    '../datasets/csvs/column_chunks/chunks.csv',
    '../datasets/csvs/column_predmarker/predicate_marker.csv',
    '../datasets/csvs/column_shifts_ctx_p/form.csv',
    '../datasets/csvs/column_shifts_ctx_p/gpos.csv',
    '../datasets/csvs/column_shifts_ctx_p/lemma.csv',
    '../datasets/csvs/column_t/t.csv',
    '../datasets/csvs/column_iob/iob.csv'
]

for col_f in column_files:
    _df = pd.read_csv(col_f, index_col=0, encoding='utf-8')
    dfgs = pd.concat((dfgs, _df), axis=1)

DISPLAY_COLUMNS = ['ID', 'P', 'FORM', 'ARG', 'T', 
                   'CHUNK_ID', 'CHUNK_START', 'CHUNK_FINISH', 'CHUNK_LEN', 'CHUNK_CANDIDATE_ID']            
dfgs[DISPLAY_COLUMNS].head(33)
# Out:
#        ID  P                       FORM   ARG   T  CHUNK_ID  CHUNK_START  \
# INDEX
# 0       1  1                   Brasília     *   *         1            0
# 1       2  1         Pesquisa_Datafolha  (A0*  A0         2            1
# 2       3  1                  publicada     *  A0         2            1
# 3       4  1                       hoje    *)  A0         2            1
# 4       5  1                     revela  (V*)   V         3            4
# 5       6  1                         um  (A1*  A1         4            5
# 6       7  1                       dado     *  A1         4            5
# 7       8  1               supreendente     *  A1         4            5
# 8       9  1                          :     *  A1         4            5
# 9      10  1                  recusando     *  A1         4            5
# 10     11  1                        uma     *  A1         4            5
# 11     12  1                    postura     *  A1         4            5
# 12     13  1                    radical     *  A1         4            5
# 13     14  1                          ,     *  A1         4            5
# 14     15  1                          a     *  A1         4            5
# 15     16  1                 esmagadora     *  A1         4            5
# 16     17  1                    maioria     *  A1         4            5
# 17     18  1                          (     *  A1         4            5
# 18     19  1                         77     *  A1         4            5
# 19     20  1                          %     *  A1         4            5
# 20     21  1                          )     *  A1         4            5
# 21     22  1                         de     *  A1         4            5
# 22     23  1                         os     *  A1         4            5
# 23     24  1                  eleitores     *  A1         4            5
# 24     25  1                       quer     *  A1         4            5
# 25     26  1                          o     *  A1         4            5
# 26     27  1                         PT     *  A1         4            5
# 27     28  1               participando     *  A1         4            5
# 28     29  1                         de     *  A1         4            5
# 29     30  1                          o     *  A1         4            5
# 30     31  1                    Governo     *  A1         4            5
# 31     32  1  Fernando_Henrique_Cardoso    *)  A1         4            5
# 32     33  1                          .     *   *         5           32
#
#        CHUNK_FINISH  CHUNK_LEN  CHUNK_CANDIDATE_ID
# INDEX
# 0                 1          1                   0
# 1                 4          3                  35
# 2                 4          3                  35
# 3                 4          3                  35
# 4                 5          1                 126
# 5                32         27                 181
# 6                32         27                 181
# 7                32         27                 181
# 8                32         27                 181
# 9                32         27                 181
# 10               32         27                 181
# 11               32         27                 181
# 12               32         27                 181
# 13               32         27                 181
# 14               32         27                 181
# 15               32         27                 181
# 16               32         27                 181
# 17               32         27                 181
# 18               32         27                 181
# 19               32         27                 181
# 20               32         27                 181
# 21               32         27                 181
# 22               32         27                 181
# 23               32         27                 181
# 24               32         27                 181
# 25               32         27                 181
# 26               32         27                 181
# 27               32         27                 181
# 28               32         27                 181
# 29               32         27                 181
# 30               32         27                 181
# 31               32         27                 181
# 32               33          1                 560

# %% [markdown]
# ## 2. Gets encodings
#
# Propbank Encoder holds an indexed version of propbank dataset an answers to FOUR different dataformats:
# * CAT: this is the raw categorical data.
# * EMB: tokens are embedding using GloVe embeddings.
# * HOT: onehot encoding of the words and tokens.
# * IDX: dense indexed representations.

# %%
# LOAD ENCODER
propbank_encoder = PropbankEncoder.recover(PROPBANK_GLO50_PATH)
db = propbank_encoder.db
lex2idx = propbank_encoder.lex2idx
idx2lex = propbank_encoder.idx2lex

# FOR TEXTUAL DATA ONLY
embeddings = propbank_encoder.embeddings

n_targets = len(lex2idx['T'])

# %%
print('attributes\t',
       len(db),
      '\n',             
      'records\t',
       len(db['ARG'].keys()))
# Out:
# attributes	 44
#  records	 141730

# %%
def filter_type(ds_type, db):
    '''Filters only records from train dataset
    '''
    ds_types = ('train', 'test', 'valid')
    if ds_type not in ds_types:
        _msg = 'ds_type must be in {:} got {:}'
        _msg = _msg.format(ds_types, ds_type)
        raise ValueError(_msg)
    elif ds_type in ('train',):
        lb = 0 
        ub = config.DATASET_TRAIN_SIZE
    elif ds_type in ('test',):        
        lb = config.DATASET_TRAIN_SIZE
        ub = lb + config.DATASET_VALID_SIZE         
    elif ds_type in ('valid',):                
        lb = config.DATASET_TRAIN_SIZE + config.DATASET_VALID_SIZE
        ub = lb + config.DATASET_TEST_SIZE         

    sel_keys_ = {key_ for key_, prop_ in db['P'].items() if prop_ > lb and prop_ <= ub}

    return {
                attr_:{ idx_: i_
                        for idx_, i_ in dict_.items() if idx_ in sel_keys_
                      }        
                for attr_, dict_  in db.items()
            }

def make_propositions_dict(db):
    '''Reindex db by propositions creating a nested dict in which the
        outer key is the proposition        
    '''
    
    triple_list = []
    prev_idx = -1
    prev_prop = -1
    for idx, prop in db['P'].items():
        if prev_prop != prop:
            if idx > 0:
                ub = prev_idx
                triple_list.append((lb, ub, prev_prop))
            lb = idx
        prev_prop = prop
        prev_idx = idx
    triple_list.append((lb, prev_idx, prev_prop))
            

        
    prop_set = set(db['P'].values())
    return { prop_:
                    {
                        attr_:{ idx_: dict_[idx_]
                                for idx_ in range(lb_, ub_ + 1, 1)
                          }        
                        for attr_, dict_ in db.items() if attr_ not in ('P',)
                    }
             for lb_, ub_, prop_ in  triple_list
            }, {prop_: ub_ - lb_ + 1 for lb_, ub_, prop_ in  triple_list}   


def numpfy_propositions_dict(prop_dict, proplen_dict):
    '''Converts inner dict examples into numpy arrays
    '''
    prop_dict_ = defaultdict(dict)    
    for prop, columns_dict in prop_dict.items():
        len_ = proplen_dict[prop]
        shape_ = (len_, 1)
        for column, values_dict in columns_dict.items():
            tuple_list = [idx_value 
                          for idx_value in values_dict.items()]
            
            tuple_list = sorted(tuple_list, key=lambda x: x[0])            
            # Converts lexicon (raw/indexed) into token (embedded/indexed)
            if (('FORM' in column) or ('LEMMA' in column)):
                values_list = [idx2lex[column][tuple_[1]]                
                                   for tuple_ in tuple_list]
            else:
                values_list = [tuple_[1] for tuple_ in tuple_list]
            
            prop_dict_[prop][column]  = np.array(values_list).reshape(shape_)
    
    return prop_dict_

# %%
traindb  = filter_type('train', db)
print('attributes\t',
       len(traindb),
      '\n',             
      'records\t',
       len(traindb['ARG'].keys()),
       '\n',             
      'vocab\t',
        max([form for _, form in traindb['FORM'].items()]))
# Out:
# attributes	 44
#  records	 123846
#  vocab	 13289

# %%
prop_dict, proplen_dict = make_propositions_dict(traindb)
print('attributes\t',
       len(prop_dict[1]) + 1,
      '\n',             
      'records\t',
       sum([len(d['ARG']) for p, d in prop_dict.items()]),
        '\n',             
      'vocab\t',
        max([form for _, prop in prop_dict.items() for _, form in prop['FORM'].items()]))
# Out:
# attributes	 44
#  records	 123846
#  vocab	 13289

# %%
prop_dict1 = numpfy_propositions_dict(prop_dict, proplen_dict)
print('attributes\t',
       len(prop_dict1[1]) + 1,
      '\n',             
      'records\t',
       sum([len_ for _, len_ in proplen_dict.items()]),
        '\n',             
      'vocab\t',
        max([max(form) for _, prop in prop_dict1.items() for form in prop['FORM']]))
# Out:
# attributes	 44
#  records	 123846
#  vocab	 12037

# %%
def get_inputs(db1, propid):
    '''Generate inputs
    '''
    propdb = db1[propid] # nested dict of columns and idx value
    if 'CHUNK_SPACE' not in propdb:
        proplen = len(propdb['ID'])
        propdb['CHUNK_SPACE'] = generate_chunk_space(proplen)

    word    = propdb['FORM']
    ctx_p_left  = propdb['FORM_CTX_P-1']
    ctx_p0  = propdb['FORM_CTX_P+0']
    ctx_p_right  = propdb['FORM_CTX_P+1']
    
    marker  = propdb['MARKER']
    pos     = propdb['GPOS']
    chunk_type  = propdb['T']
    chunk_start, chunk_finish = propdb['CHUNK_SPACE']
    
    return word, ctx_p_left, ctx_p0, ctx_p_right, marker, pos, chunk_type, chunk_start, chunk_finish
            
def generate_chunk_space(n):
    '''Generates all possible spaces for chunks
    '''
    start_list = []
    end_list = []
    for i in range(n):
        for j in range(i,n,1):
            start_list.append(i)
            end_list.append(j+1)
    shape_ = (len(start_list), 1)
    start_ = np.array(start_list).reshape(shape_)
    finish_ = np.array(end_list).reshape(shape_)
    return start_, finish_
            

def get_outputs(db1, propid, n_targets):
    ''' Generate outputs
    '''
    propdb = db1[propid] # nested dict of columns and idx value
    if 'OUTPUTS' not in propdb: 
        id_type = np.concatenate(
            ( propdb['CHUNK_CANDIDATE_ID'], propdb['T']), axis=1
        )

        id_type = np.unique( id_type, axis=0)
        propdb['OUTPUTS'] = id_type[:,0] * n_targets + id_type[:,1]

    return propdb['OUTPUTS']

# %%
# %%timeit
propid = 1120
word, ctx_p_left, ctx_p0, ctx_p_right, marker, pos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1, propid)
targets = get_outputs(prop_dict1, propid, n_targets)
# worst proposition 1120 size 92!
# Out:
# 901 ns ± 20.3 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
#  ## MODEL

# %%
propid = 1
word, ctx_p_left, ctx_p0, ctx_p_right, marker, pos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1,  propid)
targets = get_outputs(prop_dict1, propid, n_targets)
print(targets)
_start  = np.repeat(chunk_start, n_targets)
_finish = np.repeat(chunk_finish, n_targets)
print(_start)
print(_finish)
print(list(zip(_start[targets].flatten(), _finish[targets].flatten())))
# Out:
# [    0  1261 20160  4571  6518]
# [ 0  0  0 ..., 32 32 32]
# [ 1  1  1 ..., 33 33 33]
# [(0, 1), (1, 4), (32, 33), (4, 5), (5, 32)]

# %%
import struct_perc.colored_weighted_interval_scheduling as cwis
import struct_perc.weighted_interval_scheduling as wis
import struct_perc.utils as spu

# %% [markdown]
#  ## Tensorflow Graph

# %%
# Parameters
vocab_size = len(embeddings)
embed_size = 50

n_pos = len(lex2idx['GPOS'])
n_classes = len(lex2idx['T'])
n_features = embed_size * 4 + 1 + n_pos

n_hidden = 100
# W_shape = (n_features, n_hidden)
W_shape = (n_hidden, n_hidden)
b_shape = (1, n_hidden)

W_interval_shape = (2 * n_hidden, n_classes)
# W_shape = (hidden_features, n_classes)
b_interval_shape = (1, n_classes)

# word index 
X_words = tf.placeholder(tf.int64, shape=(None,1), name='word')

# predicate context index (left, predicate, right)
X_ctx_p_left = tf.placeholder(tf.int64, shape=(None,1), name='ctx_p_left')
X_ctx_p = tf.placeholder(tf.int64, shape=(None,1), name='ctx_p0')
X_ctx_p_right = tf.placeholder(tf.int64, shape=(None,1), name='ctx_p_right')

# POS tagging feature
X_pos = tf.placeholder(tf.int64, shape=(None,1), name='gpos')
X_marker = tf.cast( tf.placeholder(tf.int64, shape=(None,1), name='marker'), tf.float32 )
EMBS = tf.Variable(embeddings, trainable=False)

# Embedded representation
with tf.variable_scope("features"):
    EMBS_words = tf.gather_nd(EMBS, X_words, name='word_features')

    EMBS_ctx_pleft = tf.gather_nd(EMBS, X_ctx_p_left, name='EMBS_ctx_pleft')
    EMBS_ctx_p0 = tf.gather_nd(EMBS, X_ctx_p, name='EMBS_ctx_p0')
    EMBS_ctx_pright = tf.gather_nd(EMBS, X_ctx_p_right, name='EMBS_ctx_pright')

    X_pos_flat = tf.reshape(X_pos, [-1], name='gpos_flat')
    X_pos_onehot = tf.one_hot(X_pos_flat, depth=n_pos, name='gpos_onehot')

    X = tf.concat((EMBS_words, EMBS_ctx_pleft, EMBS_ctx_p0,
                   EMBS_ctx_pright, X_pos_onehot, X_marker),
                  axis=1, name='X')
    X_batch = tf.expand_dims(X, 0)

with tf.variable_scope('gru', reuse=tf.AUTO_REUSE):

    fw = tf.nn.rnn_cell.GRUCell(num_units=n_hidden / 2)
    bw = tf.nn.rnn_cell.GRUCell(num_units=n_hidden / 2)
    
    Wo = tf.Variable(tf.truncated_normal(W_shape, stddev=1.0 / np.sqrt(n_features * n_hidden)), name='W' )
    bo = tf.Variable(tf.zeros(b_shape, dtype=tf.float32), name='b')

    hidden_outputs, states = tf.nn.bidirectional_dynamic_rnn(
        cell_fw=fw,
        cell_bw=bw,
        inputs=X_batch,
        dtype=tf.float32
    )
    hidden_fw, hidden_bw = hidden_outputs
    Ho = tf.concat((tf.squeeze(hidden_fw, axis=0) ,tf.squeeze(hidden_fw, axis=0)),axis=1)

    Z = tf.nn.tanh( tf.matmul( Ho, Wo ) + bo, name='hidden_layer' )

# Those are the interval parameters
with tf.variable_scope("interval"):
    W_interval = tf.Variable(tf.random_normal(W_interval_shape, mean=0.0, stddev=1.0 / np.sqrt(1.0 * n_hidden * n_classes)), name='W_interval')
    b_interval = tf.Variable(tf.zeros(b_interval_shape, dtype=tf.float32), name='b_interval')
    
    # begin of interval
    IntervalStart = tf.placeholder(tf.int32, shape=(None,1))
    # end of interval
    IntervalFinish = tf.placeholder(tf.int32, shape=(None,1))

# features from intervals
IntervalFinishZ = tf.gather_nd(Z, IntervalFinish-1)
IntervalStartZ = tf.gather_nd(Z, IntervalStart)

IntervalZ = tf.concat((IntervalFinishZ, IntervalStartZ), axis=1)
IntervalScores = tf.matmul(IntervalZ, W_interval) + b_interval

ScoresFlat = tf.reshape(IntervalScores, (-1,1)) # column array n_classes * ((len + 1 ) * len) / 2 
ScoresMean = tf.reduce_mean(ScoresFlat) # scalar
ScoresDiff = ScoresFlat - ScoresMean   # centralize data --> mean zero

ScoresStd = tf.sqrt(tf.reduce_sum(ScoresDiff * ScoresDiff))
ScoresOp = ScoresDiff /( ScoresStd + 1e-8 )

# %% [markdown]
#  ## Tensorflow test session

# %%
propid  = 1
words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1, propid)
targets = get_outputs(prop_dict1, propid, n_targets)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    arg_list = [Z, IntervalZ, IntervalStartZ, IntervalFinishZ, W_interval, b_interval, IntervalScores]
    data_list = sess.run(arg_list, feed_dict={
        X_words:words,
        X_ctx_p_left: ctx_p_left,
        X_ctx_p: ctx_p0,
        X_ctx_p_right: ctx_p_right,        
        X_marker: marker,                
        X_pos:gpos,
        IntervalStart: chunk_start,
        IntervalFinish: chunk_finish
    })
    ZZ, scores, start_scores, finish_scores, Wi, bi, inteval_scores = data_list
    # flat gives the score for each candidate

print(ZZ.shape, scores.shape, start_scores.shape, finish_scores.shape, Wi.shape, bi.shape, inteval_scores.shape)
# Out:
# (33, 100) (561, 200) (561, 100) (561, 100) (200, 36) (1, 36) (561, 36)

# %% [markdown]
# ## Testing prediction

# %%
def pred(sess, x_words, x_ctx_p_left, x_ctx_p0, x_ctx_p_right, x_marker, x_pos, x_chunk_start, x_chunk_finish):
    scores = sess.run(ScoresOp,feed_dict={
        X_words: x_words,
        X_ctx_p_left: x_ctx_p_left,
        X_ctx_p: x_ctx_p0,
        X_ctx_p_right: x_ctx_p_right,        
        X_marker: x_marker,                
        X_pos:x_pos,
        IntervalStart: x_chunk_start,
        IntervalFinish: x_chunk_finish
    })
    # scores is a ((proplen + 1) * (proplen) / 2) * n_classes  
    starts = np.repeat(x_chunk_start, n_classes).reshape((-1,1))
    ends = np.repeat(x_chunk_finish, n_classes).reshape((-1,1))
    
    ck_len = len(x_chunk_start)
    colors = np.array(list(np.arange(n_classes))*ck_len)

    # Finds best allocation given the scores and the chunk_space
    r_int = cwis.compute_schedule(starts.flatten(), ends.flatten(), scores, colors) # index of the cadidates of predicted solution
    r_ext = list(zip(starts[r_int].flatten(),ends[r_int].flatten(), colors[r_int].flatten())) # from integer to triple
    return r_int, r_ext

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
p, pe = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)
print(p)
print(pe)
# Out:
# [20163 20091 19983 19839 19659 19471 19219 18903 18579 18247 17823 17391
#  16923 16419 15879 15303 14691 14043 13359 12639 11911 11119 10263  9427
#   8527  7591  6591  5583  4539  3476  2360  1219    20]
# [(32, 33, 3), (31, 32, 3), (30, 31, 3), (29, 30, 3), (28, 29, 3), (27, 28, 31), (26, 27, 31), (25, 26, 3), (24, 25, 3), (23, 24, 31), (22, 23, 3), (21, 22, 3), (20, 21, 3), (19, 20, 3), (18, 19, 3), (17, 18, 3), (16, 17, 3), (15, 16, 3), (14, 15, 3), (13, 14, 3), (12, 13, 31), (11, 12, 31), (10, 11, 3), (9, 10, 31), (8, 9, 31), (7, 8, 31), (6, 7, 3), (5, 6, 3), (4, 5, 3), (3, 4, 20), (2, 3, 20), (1, 2, 31), (0, 1, 20)]

# %% [markdown]
# ## Training code

# %%
# indices of the correct intervals
T = tf.placeholder(tf.int32, shape=(None,), name='T')
L = tf.placeholder(tf.int32, shape=(), name='L')
# I = tf.to_int32(tf.range(L), name='indices')

T_flat = tf.reshape(T, (-1,1), name='T_flat') # column array
MarginFactor = tf.placeholder(tf.float32)
MarginIndex = tf.ones(tf.shape(T_flat)) * MarginFactor
MarginScores = tf.scatter_nd(T_flat, -MarginIndex, tf.shape(ScoresOp)) # oppposite of gather_nd
ScoresWithMargin = ScoresOp + MarginScores

# %%
# indices containing the predicted labels from Weighted Interval Scheduling
Y = tf.placeholder(tf.int32, shape=(None,), name='predictions')
Y_flat = tf.reshape(Y, (-1, 1))

# score da estrutura predita
ScoreY = tf.gather_nd(ScoresWithMargin, Y_flat, name='predicted_score')
# score da estrutura correta
ScoreT = tf.gather_nd(ScoresWithMargin, T_flat, name='target_score')

# função de custo do perceptron estruturado
CostOp = tf.reduce_sum(ScoreY) - tf.reduce_sum(ScoreT)

# gradiente descendente no custo do perceptron estruturado
Optimizer = tf.train.AdamOptimizer(0.001)
TrainOp = Optimizer.minimize(CostOp)

# %%
predictions, _ = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)
print(targets.shape)
print(targets)
print(predictions.shape)
print(predictions)
# Out:
# (5,)
# [    0  1261 20160  4571  6518]
# (33,)
# [20163 20091 19983 19839 19659 19471 19219 18903 18579 18247 17823 17391
#  16923 16419 15879 15303 14691 14043 13359 12639 11911 11119 10263  9427
#   8527  7591  6591  5583  4539  3476  2360  1219    20]

# %% [markdown]
#  ## Testing cost operation

# %%
predictions, chunk_ext = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)

interval_start = np.repeat(chunk_start, n_classes).reshape((-1,1))
interval_finish = np.repeat(chunk_finish, n_classes).reshape((-1,1))

scores_, cost_ = sess.run([ScoresOp, CostOp], feed_dict={
    X_words: words,
    X_ctx_p_left: ctx_p_left,
    X_ctx_p: ctx_p0,
    X_ctx_p_right: ctx_p_right,        
    X_marker: marker,        
    X_pos: gpos,
    IntervalStart: interval_start,
    IntervalFinish: interval_finish,
    T: targets.flatten(),
    Y: predictions.flatten(),        
    L: proplen_dict[propid],
    MarginFactor:0.01})


print(scores_.shape)
print(cost_)
print(np.max(predictions))
print(np.sum(scores_[predictions]) - np.sum(scores_[targets]))
# Out:
# (727056, 1)
# 0.095378
# 20163
# 0.045378

# %%
colors = np.array(list(np.arange(n_classes))*len(chunk_start))
r_int = cwis.compute_schedule(interval_start.flatten(), interval_finish.flatten(), scores_, colors) 
print(np.mean(scores_[r_int]), ' ', np.mean(scores_[targets]))
# Out:
# 0.00162731   0.000318702

# %%
np.sum(scores_[predictions].flatten())
# Out:
# 0.046971507

# %%
np.sum(scores_[targets].flatten())
# Out:
# 0.0015935113

# %%
print(sorted(predictions))
print(sorted(r_int))
# Out:
# [20, 1219, 2360, 3476, 4539, 5583, 6591, 7591, 8527, 9427, 10263, 11119, 11911, 12639, 13359, 14043, 14691, 15303, 15879, 16419, 16923, 17391, 17823, 18247, 18579, 18903, 19219, 19471, 19659, 19839, 19983, 20091, 20163]
# [20, 1208, 2360, 3476, 4556, 5600, 6591, 7563, 8527, 9427, 10291, 11119, 11911, 12667, 13376, 14060, 14719, 15331, 15907, 16447, 16951, 17419, 17851, 18247, 18607, 18931, 19219, 19471, 19687, 19867, 20011, 20119, 20191]

# %%
propid  = 1
words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1, propid)
targets = get_outputs(prop_dict1, propid, n_targets)

starts = np.repeat(chunk_start,n_classes).reshape((-1,1))
ends = np.repeat(chunk_finish, n_classes).reshape((-1,1))

scores_ = sess.run(ScoresOp, feed_dict={
    X_words: words,
    X_ctx_p_left: ctx_p_left,
    X_ctx_p: ctx_p0,
    X_ctx_p_right: ctx_p_right,        
    X_marker: marker,        
    X_pos: gpos,
    IntervalStart: chunk_start,
    IntervalFinish: chunk_finish,
    T: targets.flatten(),
    Y: predictions.flatten(),        
    MarginFactor:0.01
})

colors = np.repeat(np.arange(n_classes), len(chunk_start))
predictions = cwis.compute_schedule(starts.flatten(), ends.flatten(), scores_, colors) 

cost_ = sess.run(CostOp, feed_dict={
    X_words: words,
    X_ctx_p_left: ctx_p_left,
    X_ctx_p: ctx_p0,
    X_ctx_p_right: ctx_p_right,        
    X_marker: marker,        
    X_pos: gpos,
    IntervalStart: chunk_start,
    IntervalFinish: chunk_finish,
    T:targets.flatten(),
    Y:predictions.flatten(),
    MarginFactor:0.01
})

print(cost_)
print(np.sum(scores_[predictions]) - np.sum(scores_[targets]))
# Out:
# 0.484868
# 0.434868

# %%
print(scores_.shape)
# Out:
# (20196, 1)

# %% [markdown]
# ## Training Single Proposition

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

propid = 1
words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1, propid)
targets = get_outputs(prop_dict1, propid, n_targets)

starts = np.repeat(chunk_start,n_classes).reshape((-1,1))
ends = np.repeat(chunk_finish, n_classes).reshape((-1,1))

for i in range(10000):
    
    scores_ = sess.run(ScoresOp, feed_dict={
        X_words: words,
        X_ctx_p_left: ctx_p_left,
        X_ctx_p: ctx_p0,
        X_ctx_p_right: ctx_p_right,        
        X_marker: marker,        
        X_pos: gpos,
        IntervalStart: chunk_start,
        IntervalFinish: chunk_finish,
        T: targets.flatten(),
        Y: predictions.flatten(),        
        MarginFactor:0.01
    })
    
    predictions, chunk_ext = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)    
    cost_ = sess.run(CostOp, feed_dict={
        X_words: words,
        X_ctx_p_left: ctx_p_left,
        X_ctx_p: ctx_p0,
        X_ctx_p_right: ctx_p_right,        
        X_marker: marker,        
        X_pos: gpos,
        IntervalStart: chunk_start,
        IntervalFinish: chunk_finish,
        T: targets.flatten(),
        Y: predictions.flatten(),        
        MarginFactor:0.01
    })
    
    predictions_score = np.sum(scores_[predictions])
    targets_score = np.sum(scores_[targets])
        
    sess.run(TrainOp, feed_dict={
        X_words: words,
        X_ctx_p_left: ctx_p_left,
        X_ctx_p: ctx_p0,
        X_ctx_p_right: ctx_p_right,        
        X_marker: marker,        
        X_pos: gpos,
        IntervalStart: chunk_start,
        IntervalFinish: chunk_finish,
        T: targets.flatten(),
        Y: predictions.flatten(),        
        MarginFactor:0.01})
    
    colors = np.repeat(np.arange(n_classes), len(chunk_start))
    predictions = cwis.compute_schedule(starts.flatten(), ends.flatten(), scores_, colors) 

    targets_set = set(targets.flatten())
    predictions_set = set(predictions.flatten())
    yp_common = targets_set.intersection(predictions_set)
    yp_total = targets_set.union(predictions_set)
    
    acc_int = len(yp_common)/len(yp_total)
    
    if i % 25 == 0:
        print(acc_int, ' ', cost_)
    
    if cost_ < 0:
        break

    if acc_int == 1:
        print(acc_int, ' ', cost_, ' learnt at epoch ', i)
        break
# Out:
# 0.0   0.616415
# 0.0   0.257976
# 0.02702702702702703   0.186476
# 0.05555555555555555   0.143267
# 0.08571428571428572   0.0922629
# 0.0   0.0878867
# 0.05555555555555555   0.0844578
# 0.02702702702702703   0.0726507
# 0.2727272727272727   0.0357467
# 0.5   0.0196386
# 0.1875   0.0233169
# 1.0   0.0  learnt at epoch  273

# %%
targets_list = list(zip(starts[targets].flatten(), ends[targets].flatten(), colors[targets]))

print(sorted(targets_list, key=lambda x: x[0]))
# Out:
# [(0, 1, 0), (1, 4, 2), (4, 5, 8), (5, 32, 11), (32, 33, 35)]

# %%
predictions_list = list(zip(starts[predictions].flatten(), ends[predictions].flatten(), colors[predictions]))

print(sorted(predictions_list, key=lambda x: x[0]))
# Out:
# [(0, 1, 0), (1, 4, 2), (4, 5, 8), (5, 32, 11), (32, 33, 35)]

# %%
# this should be equal to previous cell result predicitin doesn't changed the weights
predictions1, chunk_ext = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)    
predictions_test_list = list(zip(starts[predictions1].flatten(), ends[predictions1].flatten(), colors[predictions1]))

print(sorted(predictions_test_list, key= lambda x: x[0]))
# Out:
# [(0, 1, 0), (1, 4, 2), (4, 5, 8), (5, 32, 11), (32, 33, 35)]

# %% [markdown]
#  ## ConLL evaluation scripts

# %%
def tag_to_conll(sess, prop_dict, propid, idx2lex):
    gold_list = []
    eval_list = []
        
    words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict, propid)
    targets = get_outputs(prop_dict, propid, n_targets)

    predictions, chunk_ext = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)    


    n_words = len(words)
    default_ck_list_ = [(i,i + 1, '*') for i in range(n_words)]
    
    pred_array = prop_dict[propid]['PRED']
    pred_array = pred_array.flatten()
    
    arg_array = prop_dict[propid]['ARG']
    arg_array = arg_array.flatten()
    
    pred_list = [idx2lex['PRED'][i] for i in pred_array.tolist()]
    gold_list_ = [idx2lex['ARG'][i] for i in arg_array.tolist()]
    
    gold_list += list(zip(pred_list, gold_list_))

    
    ck_list_ = []     
    for triple_ in sorted(chunk_ext, key= lambda x: x[0]):
        lb, ub, ckid = triple_
        # filters default value
        default_ck_list_ = [
            dck_
            for dck_ in default_ck_list_ if dck_[0] < lb or dck_[1] > ub
        ]
        ck_list_.append((lb, ub, idx2lex['T'][ckid]))        

    ck_list_ = default_ck_list_ + ck_list_ 

    arg_list_ = []
    for triple_ in sorted(ck_list_, key= lambda x: x[0]):
        lb, ub, cktype = triple_
        flat_list_ = [ cktype if i == lb else '*' for i in range(lb, ub) ]
            
        if cktype != '*':
            flat_list_[0] = '({:}*'.format(flat_list_[0])
            flat_list_[-1] = '{:})'.format(flat_list_[-1])
        arg_list_ += flat_list_
        
    eval_list += list(zip(pred_list, arg_list_))
    eval_list.append(None)
    gold_list.append(None)
    return gold_list, eval_list

# %% [markdown]
# testamos o modelo na frase usada para treino

# %%
propid = 1
gold_list, eval_list = tag_to_conll(sess, prop_dict1, propid, idx2lex)
for i in range(proplen_dict[propid]):
    if gold_list[i] and eval_list[i]:
        print('{:}\t{:}\t{:}\t{:}'.format(*gold_list[i], *eval_list[i]))
    else:
        print('\n')
    

print(lex2idx['T'])
# Out:
# -	*	-	*
# -	(A0*	-	(A0*
# -	*	-	*
# -	*)	-	*)
# revelar	(V*)	revelar	(V*)
# -	(A1*	-	(A1*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*	-	*
# -	*)	-	*)
# -	*	-	*
# {'*': 0, 'A0': 1, 'A1': 2, 'A2': 3, 'A3': 4, 'A4': 5, 'A5': 6, 'AM-ADV': 7, 'AM-CAU': 8, 'AM-DIR': 9, 'AM-DIS': 10, 'AM-EXT': 11, 'AM-LOC': 12, 'AM-MED': 13, 'AM-MNR': 14, 'AM-NEG': 15, 'AM-PNC': 16, 'AM-PRD': 17, 'AM-REC': 18, 'AM-TMP': 19, 'C-A0': 20, 'C-A1': 21, 'C-A2': 22, 'C-A3': 23, 'C-AM-ADV': 24, 'C-AM-CAU': 25, 'C-AM-DIS': 26, 'C-AM-EXT': 27, 'C-AM-LOC': 28, 'C-AM-MNR': 29, 'C-AM-NEG': 30, 'C-AM-PNC': 31, 'C-AM-PRD': 32, 'C-AM-TMP': 33, 'C-V': 34, 'V': 35}

# %%
def evaluate(gold_list, eval_list, verbose=True):
    gold_path = 'train_gold.props'    
    eval_path = 'train_eval.props'

    with open(gold_path, mode='w') as f:        
        for tuple_ in gold_list:
            if tuple_ is None:
                f.write('\n')
            else:
                f.write('{:}\t{:}\n'.format(*tuple_))

    with open(eval_path, mode='w') as f:        
        for tuple_ in eval_list:
            if tuple_ is None:
                f.write('\n')
            else:
                f.write('{:}\t{:}\n'.format(*tuple_))

    pipe = Popen(['perl',PEARL_SRLEVAL_PATH, gold_path, eval_path], stdout=PIPE, stderr=PIPE)

    txt, err = pipe.communicate()
    txt = txt.decode('UTF-8')
    err = err.decode('UTF-8')
    
    if verbose:
        print(txt)
        with open('train.conll', mode='w') as f:
            f.write(txt)

    # overall is a summary from the list
    # is the seventh line
    lines_list = txt.split('\n')        
    
    # get the numbers from the row 
    overall_list = re.findall(r'[-+]?[0-9]*\.?[0-9]+.', lines_list[6])
    f1 = float(overall_list[-1])

    return f1

# %%
propid = 1
gold_list, eval_list = tag_to_conll(sess, prop_dict1, propid, idx2lex)
f1_score = evaluate(gold_list, eval_list, verbose=True)
print('f1_score: ', f1_score)
# Out:
# Number of Sentences    :           1
# Number of Propositions :           1
# Percentage of perfect props : 100.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        2       0       0   100.00  100.00  100.00
# ----------
#         A0        1       0       0   100.00  100.00  100.00
#         A1        1       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V        1       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#
# f1_score:  100.0

# %%
import time
start = time.time()
print(1111)
gold_list, eval_list = tag_to_conll(sess, prop_dict1, propid, idx2lex)
f1_score = evaluate(gold_list, eval_list, verbose=True)
end = time.time()
print('evaluate: ', (end-start), 's')
print('f1_score: ', f1_score)
# Out:
# 1111
# Number of Sentences    :           1
# Number of Propositions :           1
# Percentage of perfect props : 100.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        2       0       0   100.00  100.00  100.00
# ----------
#         A0        1       0       0   100.00  100.00  100.00
#         A1        1       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V        1       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#
# evaluate:  0.6659700870513916 s
# f1_score:  100.0

# %% [markdown]
# ## Training

# %%
sess= tf.Session()
sess.run(tf.global_variables_initializer())

EPOCHS = 1000
NPROPS = 40
# indices = np.arange(config.DATASET_TRAIN_SIZE)
indices = np.arange(NPROPS) + 1

best_score = 0
saver = tf.train.Saver()

iter_dict = {'iteration': 0, 'epochs': 0, 'accuracy': 0.0, 'cost': 999.0, 'f1_score': 0.0, 'best_score': 0.0}
iter_message = 'iteration:{iteration:05d}\tepochs:{epochs:05d}\t' + \
                'accuracy:{accuracy:0.2f}\tcost:{cost:0.2f}\t' + \
                'f1_score:{f1_score:0.2f}\tbest_score:{best_score:0.2f}'

for j in range(EPOCHS):
    np.random.shuffle(indices)
    total_err = 0
    total_size = 0
    total_cost = 0
    gold_list = []
    eval_list = []         
    for i, propid in enumerate(indices):     
        try: 
            words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_type, chunk_start, chunk_finish = get_inputs(prop_dict1, propid)
            targets = get_outputs(prop_dict1, propid, n_targets)
        except KeyError:
            print(propid)

        predictions, chunk_ext = pred(sess, words, ctx_p_left, ctx_p0, ctx_p_right, marker, gpos, chunk_start, chunk_finish)

        _, cost = sess.run([TrainOp, CostOp], feed_dict={
            X_words: words,
            X_ctx_p_left: ctx_p_left,
            X_ctx_p: ctx_p0,
            X_ctx_p_right: ctx_p_right,        
            X_marker: marker,        
            X_pos: gpos,
            IntervalStart: chunk_start,
            IntervalFinish: chunk_finish,
            T: targets.flatten(),
            Y: predictions.flatten(),        
            MarginFactor:0.01})

        predictions_set = set(predictions.tolist())
        targets_set = set(targets.tolist())
        
        union_set = predictions_set.union(targets_set)
        inter_set = predictions_set.intersection(targets_set)
        
        total_err += len(union_set - inter_set)
        total_size += len(union_set)
        total_cost += cost
        
        gold_list_, eval_list_ = tag_to_conll(sess, prop_dict1, propid, idx2lex)
        gold_list += gold_list_
        eval_list += eval_list_

        iter_dict['iteration'] = i + j * len(indices)
        iter_dict['epochs'] = j
        iter_dict['accuracy'] = 1 - total_err/total_size
        iter_dict['cost'] = total_cost

        
    iter_dict['f1_score'] = evaluate(gold_list, eval_list, verbose=False)    
    if iter_dict['f1_score'] > iter_dict['best_score']:
        iter_dict['best_score'] = iter_dict['f1_score']
        evaluate(gold_list, eval_list, verbose=True)    
        save_path = saver.save(sess, "/tmp/model_spn-pt.ckpt")
    
    print(iter_message.format(**iter_dict))        
    
    if iter_dict['best_score'] > 98:
        print('best_score:',iter_dict['best_score'],'exiting')
        break
# Out:
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        1     463      97     0.22    1.02    0.36
# ----------
#         A0        0      55      21     0.00    0.00    0.00
#         A1        1      72      37     1.37    2.63    1.80
#         A2        0       3      10     0.00    0.00    0.00
#         A3        0       6       2     0.00    0.00    0.00
#         A4        0      44       1     0.00    0.00    0.00
#         A5        0      47       0     0.00    0.00    0.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       3       2     0.00    0.00    0.00
#     AM-DIS        0      14       3     0.00    0.00    0.00
#     AM-EXT        0      52       0     0.00    0.00    0.00
#     AM-LOC        0      38       5     0.00    0.00    0.00
#     AM-MNR        0      21       1     0.00    0.00    0.00
#     AM-NEG        0      41       4     0.00    0.00    0.00
#     AM-PNC        0      51       0     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0      16       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        6      87      34     6.45   15.00    9.02
# ------------------------------------------------------------
#
# iteration:00039	epochs:00000	accuracy:0.01	cost:0.26	f1_score:0.36	best_score:0.36
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        2     530      96     0.38    2.04    0.63
# ----------
#         A0        1      51      20     1.92    4.76    2.74
#         A1        1      72      37     1.37    2.63    1.80
#         A2        0      91      10     0.00    0.00    0.00
#         A3        0      12       2     0.00    0.00    0.00
#         A4        0      24       1     0.00    0.00    0.00
#         A5        0      35       0     0.00    0.00    0.00
#     AM-ADV        0      42       2     0.00    0.00    0.00
#     AM-CAU        0       2       2     0.00    0.00    0.00
#     AM-DIS        0      65       3     0.00    0.00    0.00
#     AM-LOC        0     104       5     0.00    0.00    0.00
#     AM-MNR        0      30       1     0.00    0.00    0.00
#     AM-NEG        0       2       4     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0       0       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        7      47      33    12.96   17.50   14.89
# ------------------------------------------------------------
#
# iteration:00079	epochs:00001	accuracy:0.02	cost:0.16	f1_score:0.63	best_score:0.63
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        3     424      95     0.70    3.06    1.14
# ----------
#         A0        2       5      19    28.57    9.52   14.29
#         A1        0      48      38     0.00    0.00    0.00
#         A2        0      34      10     0.00    0.00    0.00
#         A3        0      50       2     0.00    0.00    0.00
#         A4        0       5       1     0.00    0.00    0.00
#         A5        0       7       0     0.00    0.00    0.00
#     AM-ADV        0      19       2     0.00    0.00    0.00
#     AM-CAU        0      27       2     0.00    0.00    0.00
#     AM-DIS        0      11       3     0.00    0.00    0.00
#     AM-EXT        0       8       0     0.00    0.00    0.00
#     AM-LOC        0      30       5     0.00    0.00    0.00
#     AM-MNR        0      22       1     0.00    0.00    0.00
#     AM-NEG        1      58       3     1.69   25.00    3.17
#     AM-PNC        0      66       0     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0      34       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        3      43      37     6.52    7.50    6.98
# ------------------------------------------------------------
#
# iteration:00119	epochs:00002	accuracy:0.01	cost:0.13	f1_score:1.14	best_score:1.14
# iteration:00159	epochs:00003	accuracy:0.02	cost:0.12	f1_score:1.09	best_score:1.14
# iteration:00199	epochs:00004	accuracy:0.02	cost:0.11	f1_score:1.03	best_score:1.14
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        5     446      93     1.11    5.10    1.82
# ----------
#         A0        3      70      18     4.11   14.29    6.38
#         A1        1      30      37     3.23    2.63    2.90
#         A2        0      26      10     0.00    0.00    0.00
#         A3        0       5       2     0.00    0.00    0.00
#         A4        0      19       1     0.00    0.00    0.00
#         A5        0      55       0     0.00    0.00    0.00
#     AM-ADV        1      32       1     3.03   50.00    5.71
#     AM-CAU        0      19       2     0.00    0.00    0.00
#     AM-DIS        0      33       3     0.00    0.00    0.00
#     AM-EXT        0      41       0     0.00    0.00    0.00
#     AM-LOC        0      27       5     0.00    0.00    0.00
#     AM-MNR        0      20       1     0.00    0.00    0.00
#     AM-NEG        0       8       4     0.00    0.00    0.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        0       4       1     0.00    0.00    0.00
#     AM-TMP        0      56       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        5      74      35     6.33   12.50    8.40
# ------------------------------------------------------------
#
# iteration:00239	epochs:00005	accuracy:0.02	cost:0.09	f1_score:1.82	best_score:1.82
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        6     473      92     1.25    6.12    2.08
# ----------
#         A0        2      88      19     2.22    9.52    3.60
#         A1        3      66      35     4.35    7.89    5.61
#         A2        0      20      10     0.00    0.00    0.00
#         A3        0      59       2     0.00    0.00    0.00
#         A4        0      25       1     0.00    0.00    0.00
#     AM-ADV        0      19       2     0.00    0.00    0.00
#     AM-CAU        0      27       2     0.00    0.00    0.00
#     AM-DIS        1      51       2     1.92   33.33    3.64
#     AM-EXT        0       1       0     0.00    0.00    0.00
#     AM-LOC        0      41       5     0.00    0.00    0.00
#     AM-MNR        0       7       1     0.00    0.00    0.00
#     AM-NEG        0      15       4     0.00    0.00    0.00
#     AM-PNC        0      46       0     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0       8       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V       12      91      28    11.65   30.00   16.78
# ------------------------------------------------------------
#
# iteration:00279	epochs:00006	accuracy:0.03	cost:0.08	f1_score:2.08	best_score:2.08
# iteration:00319	epochs:00007	accuracy:0.02	cost:0.08	f1_score:0.91	best_score:2.08
# iteration:00359	epochs:00008	accuracy:0.02	cost:0.07	f1_score:1.24	best_score:2.08
# iteration:00399	epochs:00009	accuracy:0.02	cost:0.07	f1_score:0.56	best_score:2.08
# iteration:00439	epochs:00010	accuracy:0.03	cost:0.06	f1_score:1.50	best_score:2.08
# iteration:00479	epochs:00011	accuracy:0.02	cost:0.06	f1_score:1.75	best_score:2.08
# iteration:00519	epochs:00012	accuracy:0.04	cost:0.06	f1_score:0.68	best_score:2.08
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        3     180      95     1.64    3.06    2.14
# ----------
#         A0        1      27      20     3.57    4.76    4.08
#         A1        2      68      36     2.86    5.26    3.70
#         A2        0       7      10     0.00    0.00    0.00
#         A3        0       2       2     0.00    0.00    0.00
#         A4        0       1       1     0.00    0.00    0.00
#     AM-ADV        0       2       2     0.00    0.00    0.00
#     AM-CAU        0      12       2     0.00    0.00    0.00
#     AM-DIS        0       1       3     0.00    0.00    0.00
#     AM-EXT        0       9       0     0.00    0.00    0.00
#     AM-LOC        0      17       5     0.00    0.00    0.00
#     AM-MNR        0       5       1     0.00    0.00    0.00
#     AM-NEG        0       6       4     0.00    0.00    0.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-REC        0       5       0     0.00    0.00    0.00
#     AM-TMP        0      17       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        5      41      35    10.87   12.50   11.63
# ------------------------------------------------------------
#
# iteration:00559	epochs:00013	accuracy:0.04	cost:0.05	f1_score:2.14	best_score:2.14
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        4     172      94     2.27    4.08    2.92
# ----------
#         A0        1      33      20     2.94    4.76    3.64
#         A1        2      33      36     5.71    5.26    5.48
#         A2        0      22      10     0.00    0.00    0.00
#         A3        0       0       2     0.00    0.00    0.00
#         A4        0       6       1     0.00    0.00    0.00
#     AM-ADV        1       6       1    14.29   50.00   22.22
#     AM-CAU        0       6       2     0.00    0.00    0.00
#     AM-DIR        0       1       0     0.00    0.00    0.00
#     AM-DIS        0      11       3     0.00    0.00    0.00
#     AM-EXT        0       1       0     0.00    0.00    0.00
#     AM-LOC        0      14       5     0.00    0.00    0.00
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PNC        0      23       0     0.00    0.00    0.00
#     AM-PRD        0       2       1     0.00    0.00    0.00
#     AM-TMP        0      13       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        2      25      38     7.41    5.00    5.97
# ------------------------------------------------------------
#
# iteration:00599	epochs:00014	accuracy:0.03	cost:0.05	f1_score:2.92	best_score:2.92
# iteration:00639	epochs:00015	accuracy:0.03	cost:0.05	f1_score:2.46	best_score:2.92
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        5     106      93     4.50    5.10    4.78
# ----------
#         A0        0      27      21     0.00    0.00    0.00
#         A1        5      18      33    21.74   13.16   16.39
#         A2        0      14      10     0.00    0.00    0.00
#         A3        0      10       2     0.00    0.00    0.00
#         A4        0      14       1     0.00    0.00    0.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       8       2     0.00    0.00    0.00
#     AM-DIS        0       4       3     0.00    0.00    0.00
#     AM-EXT        0       5       0     0.00    0.00    0.00
#     AM-LOC        0       3       5     0.00    0.00    0.00
#     AM-MED        0       1       0     0.00    0.00    0.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       1       4     0.00    0.00    0.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0       0       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        2      17      38    10.53    5.00    6.78
# ------------------------------------------------------------
#
# iteration:00679	epochs:00016	accuracy:0.05	cost:0.05	f1_score:4.78	best_score:4.78
# iteration:00719	epochs:00017	accuracy:0.05	cost:0.05	f1_score:2.93	best_score:4.78
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        6      84      92     6.67    6.12    6.38
# ----------
#         A0        2       7      19    22.22    9.52   13.33
#         A1        1      29      37     3.33    2.63    2.94
#         A2        1      15       9     6.25   10.00    7.69
#         A3        0       1       2     0.00    0.00    0.00
#         A4        0       1       1     0.00    0.00    0.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        2       6       1    25.00   66.67   36.36
#     AM-EXT        0      11       0     0.00    0.00    0.00
#     AM-LOC        0       4       5     0.00    0.00    0.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       4       4     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        0       6       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        2      24      38     7.69    5.00    6.06
# ------------------------------------------------------------
#
# iteration:00759	epochs:00018	accuracy:0.06	cost:0.05	f1_score:6.38	best_score:6.38
# iteration:00799	epochs:00019	accuracy:0.08	cost:0.05	f1_score:5.13	best_score:6.38
# iteration:00839	epochs:00020	accuracy:0.06	cost:0.05	f1_score:6.22	best_score:6.38
# iteration:00879	epochs:00021	accuracy:0.07	cost:0.05	f1_score:1.99	best_score:6.38
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   2.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        9     103      89     8.04    9.18    8.57
# ----------
#         A0        2      22      19     8.33    9.52    8.89
#         A1        4      43      34     8.51   10.53    9.41
#         A2        0       9      10     0.00    0.00    0.00
#         A3        0      10       2     0.00    0.00    0.00
#         A4        0       0       1     0.00    0.00    0.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        2       4       1    33.33   66.67   44.44
#     AM-LOC        0       6       5     0.00    0.00    0.00
#     AM-MED        0       1       0     0.00    0.00    0.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PNC        0       2       0     0.00    0.00    0.00
#     AM-PRD        1       1       0    50.00  100.00   66.67
#     AM-TMP        0       5       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        2      36      38     5.26    5.00    5.13
# ------------------------------------------------------------
#
# iteration:00919	epochs:00022	accuracy:0.05	cost:0.05	f1_score:8.57	best_score:8.57
# iteration:00959	epochs:00023	accuracy:0.07	cost:0.05	f1_score:7.07	best_score:8.57
# iteration:00999	epochs:00024	accuracy:0.09	cost:0.05	f1_score:8.25	best_score:8.57
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall        8      74      90     9.76    8.16    8.89
# ----------
#         A0        1      21      20     4.55    4.76    4.65
#         A1        5      30      33    14.29   13.16   13.70
#         A2        0       8      10     0.00    0.00    0.00
#         A3        0       0       2     0.00    0.00    0.00
#         A4        0       0       1     0.00    0.00    0.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        1       3       2    25.00   33.33   28.57
#     AM-EXT        0       1       0     0.00    0.00    0.00
#     AM-LOC        1       9       4    10.00   20.00   13.33
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        0       1       1     0.00    0.00    0.00
#     AM-TMP        0       0       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V        3      16      37    15.79    7.50   10.17
# ------------------------------------------------------------
# iteration:01039	epochs:00025	accuracy:0.07	cost:0.05	f1_score:8.89	best_score:8.89
# iteration:01079	epochs:00026	accuracy:0.11	cost:0.05	f1_score:8.33	best_score:8.89
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       14      86      84    14.00   14.29   14.14
# ----------
#         A0        1      29      20     3.33    4.76    3.92
#         A1        6      22      32    21.43   15.79   18.18
#         A2        3       6       7    33.33   30.00   31.58
#         A3        0       1       2     0.00    0.00    0.00
#         A4        1       6       0    14.29  100.00   25.00
#     AM-ADV        0       1       2     0.00    0.00    0.00
#     AM-CAU        0       5       2     0.00    0.00    0.00
#     AM-DIS        0       0       3     0.00    0.00    0.00
#     AM-LOC        2      10       3    16.67   40.00   23.53
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       1       4     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        1       4       7    20.00   12.50   15.38
# ------------------------------------------------------------
#          V        6      20      34    23.08   15.00   18.18
# ------------------------------------------------------------
#
# iteration:01119	epochs:00027	accuracy:0.11	cost:0.05	f1_score:14.14	best_score:14.14
# iteration:01159	epochs:00028	accuracy:0.12	cost:0.04	f1_score:13.40	best_score:14.14
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   0.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       16      72      82    18.18   16.33   17.20
# ----------
#         A0        1      10      20     9.09    4.76    6.25
#         A1        8      18      30    30.77   21.05   25.00
#         A2        0      10      10     0.00    0.00    0.00
#         A3        0       2       2     0.00    0.00    0.00
#         A4        1       5       0    16.67  100.00   28.57
#     AM-ADV        1       3       1    25.00   50.00   33.33
#     AM-CAU        0       7       2     0.00    0.00    0.00
#     AM-DIS        2       3       1    40.00   66.67   50.00
#     AM-LOC        1       3       4    25.00   20.00   22.22
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       7       4     0.00    0.00    0.00
#     AM-PRD        1       1       0    50.00  100.00   66.67
#     AM-TMP        1       2       7    33.33   12.50   18.18
# ------------------------------------------------------------
#          V        9      14      31    39.13   22.50   28.57
# ------------------------------------------------------------
#
# iteration:01199	epochs:00029	accuracy:0.13	cost:0.04	f1_score:17.20	best_score:17.20
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   2.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       17      70      81    19.54   17.35   18.38
# ----------
#         A0        3      15      18    16.67   14.29   15.38
#         A1        9      32      29    21.95   23.68   22.78
#         A2        2      10       8    16.67   20.00   18.18
#         A3        0       0       2     0.00    0.00    0.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIR        0       1       0     0.00    0.00    0.00
#     AM-DIS        1       3       2    25.00   33.33   28.57
#     AM-LOC        0       0       5     0.00    0.00    0.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        0       2       1     0.00    0.00    0.00
#     AM-TMP        1       7       7    12.50   12.50   12.50
# ------------------------------------------------------------
#          V        9      29      31    23.68   22.50   23.08
# ------------------------------------------------------------
#
# iteration:01239	epochs:00030	accuracy:0.13	cost:0.04	f1_score:18.38	best_score:18.38
# iteration:01279	epochs:00031	accuracy:0.14	cost:0.04	f1_score:13.48	best_score:18.38
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   2.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       18      78      80    18.75   18.37   18.56
# ----------
#         A0        4      20      17    16.67   19.05   17.78
#         A1        9      25      29    26.47   23.68   25.00
#         A2        1      11       9     8.33   10.00    9.09
#         A3        0       2       2     0.00    0.00    0.00
#         A4        0       0       1     0.00    0.00    0.00
#     AM-ADV        1       3       1    25.00   50.00   33.33
#     AM-CAU        1       4       1    20.00   50.00   28.57
#     AM-DIS        2       4       1    33.33   66.67   44.44
#     AM-LOC        0       1       5     0.00    0.00    0.00
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        0       5       1     0.00    0.00    0.00
#     AM-TMP        0       1       8     0.00    0.00    0.00
# ------------------------------------------------------------
#          V       11      22      29    33.33   27.50   30.14
# ------------------------------------------------------------
#
# iteration:01319	epochs:00032	accuracy:0.12	cost:0.04	f1_score:18.56	best_score:18.56
# iteration:01359	epochs:00033	accuracy:0.11	cost:0.04	f1_score:11.56	best_score:18.56
# iteration:01399	epochs:00034	accuracy:0.13	cost:0.04	f1_score:14.89	best_score:18.56
# iteration:01439	epochs:00035	accuracy:0.15	cost:0.04	f1_score:17.62	best_score:18.56
# iteration:01479	epochs:00036	accuracy:0.14	cost:0.04	f1_score:18.37	best_score:18.56
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   5.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       26      73      72    26.26   26.53   26.40
# ----------
#         A0        5      31      16    13.89   23.81   17.54
#         A1        6      13      32    31.58   15.79   21.05
#         A2        5       9       5    35.71   50.00   41.67
#         A3        1       0       1   100.00   50.00   66.67
#         A4        0       0       1     0.00    0.00    0.00
#         A5        0       2       0     0.00    0.00    0.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        0       1       2     0.00    0.00    0.00
#     AM-DIS        2       1       1    66.67   66.67   66.67
#     AM-EXT        0       1       0     0.00    0.00    0.00
#     AM-LOC        1       1       4    50.00   20.00   28.57
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        4      13       4    23.53   50.00   32.00
# ------------------------------------------------------------
#          V       17      20      23    45.95   42.50   44.16
# ------------------------------------------------------------
#
# iteration:01519	epochs:00037	accuracy:0.18	cost:0.04	f1_score:26.40	best_score:26.40
# iteration:01559	epochs:00038	accuracy:0.14	cost:0.04	f1_score:19.57	best_score:26.40
# iteration:01599	epochs:00039	accuracy:0.17	cost:0.04	f1_score:24.60	best_score:26.40
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  10.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       30      62      68    32.61   30.61   31.58
# ----------
#         A0        6      12      15    33.33   28.57   30.77
#         A1       12      33      26    26.67   31.58   28.92
#         A2        3       5       7    37.50   30.00   33.33
#         A3        1       4       1    20.00   50.00   28.57
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        0       1       2     0.00    0.00    0.00
#     AM-DIS        1       1       2    50.00   33.33   40.00
#     AM-LOC        1       0       4   100.00   20.00   33.33
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        0       1       1     0.00    0.00    0.00
#     AM-TMP        4       5       4    44.44   50.00   47.06
# ------------------------------------------------------------
#          V       11      18      29    37.93   27.50   31.88
# ------------------------------------------------------------
# iteration:01639	epochs:00040	accuracy:0.21	cost:0.04	f1_score:31.58	best_score:31.58
# iteration:01679	epochs:00041	accuracy:0.17	cost:0.04	f1_score:26.42	best_score:31.58
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  17.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       32      69      66    31.68   32.65   32.16
# ----------
#         A0        8      17      13    32.00   38.10   34.78
#         A1       14      26      24    35.00   36.84   35.90
#         A2        1       9       9    10.00   10.00   10.00
#         A3        0       0       2     0.00    0.00    0.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       1       1    50.00   50.00   50.00
#     AM-CAU        1       3       1    25.00   50.00   33.33
#     AM-DIS        1       0       2   100.00   33.33   50.00
#     AM-LOC        3       1       2    75.00   60.00   66.67
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       6       4     0.00    0.00    0.00
#     AM-PNC        0       2       0     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        1       4       7    20.00   12.50   15.38
# ------------------------------------------------------------
#          V       22      33      18    40.00   55.00   46.32
# ------------------------------------------------------------
#
# iteration:01719	epochs:00042	accuracy:0.22	cost:0.04	f1_score:32.16	best_score:32.16
# iteration:01759	epochs:00043	accuracy:0.17	cost:0.04	f1_score:30.05	best_score:32.16
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  12.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       31      56      67    35.63   31.63   33.51
# ----------
#         A0        6      11      15    35.29   28.57   31.58
#         A1       12      27      26    30.77   31.58   31.17
#         A2        4       4       6    50.00   40.00   44.44
#         A3        2       0       0   100.00  100.00  100.00
#         A4        0       0       1     0.00    0.00    0.00
#         A5        0       1       0     0.00    0.00    0.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        0       3       2     0.00    0.00    0.00
#     AM-DIS        2       1       1    66.67   66.67   66.67
#     AM-LOC        1       4       4    20.00   20.00   20.00
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        3       4       5    42.86   37.50   40.00
# ------------------------------------------------------------
#          V       18      21      22    46.15   45.00   45.57
# ------------------------------------------------------------
#
# iteration:01799	epochs:00044	accuracy:0.22	cost:0.04	f1_score:33.51	best_score:33.51
# iteration:01839	epochs:00045	accuracy:0.24	cost:0.03	f1_score:31.75	best_score:33.51
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  17.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       31      49      67    38.75   31.63   34.83
# ----------
#         A0        6      13      15    31.58   28.57   30.00
#         A1       15      19      23    44.12   39.47   41.67
#         A2        2       7       8    22.22   20.00   21.05
#         A3        0       1       2     0.00    0.00    0.00
#         A4        1       0       0   100.00  100.00  100.00
#         A5        0       1       0     0.00    0.00    0.00
#     AM-ADV        0       1       2     0.00    0.00    0.00
#     AM-CAU        0       3       2     0.00    0.00    0.00
#     AM-DIS        1       1       2    50.00   33.33   40.00
#     AM-LOC        2       1       3    66.67   40.00   50.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        3       2       5    60.00   37.50   46.15
# ------------------------------------------------------------
#          V       20      25      20    44.44   50.00   47.06
# ------------------------------------------------------------
#
# iteration:01879	epochs:00046	accuracy:0.23	cost:0.04	f1_score:34.83	best_score:34.83
# iteration:01919	epochs:00047	accuracy:0.25	cost:0.03	f1_score:26.35	best_score:34.83
# iteration:01959	epochs:00048	accuracy:0.22	cost:0.04	f1_score:32.65	best_score:34.83
# iteration:01999	epochs:00049	accuracy:0.18	cost:0.04	f1_score:25.81	best_score:34.83
# iteration:02039	epochs:00050	accuracy:0.21	cost:0.04	f1_score:30.30	best_score:34.83
# iteration:02079	epochs:00051	accuracy:0.19	cost:0.04	f1_score:28.27	best_score:34.83
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :   7.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       30      40      68    42.86   30.61   35.71
# ----------
#         A0        7      12      14    36.84   33.33   35.00
#         A1       13      18      25    41.94   34.21   37.68
#         A2        0       4      10     0.00    0.00    0.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        0       1       2     0.00    0.00    0.00
#     AM-DIS        0       2       3     0.00    0.00    0.00
#     AM-LOC        3       2       2    60.00   60.00   60.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        3       1       5    75.00   37.50   50.00
# ------------------------------------------------------------
#          V       24      32      16    42.86   60.00   50.00
# ------------------------------------------------------------
#
# iteration:02119	epochs:00052	accuracy:0.25	cost:0.03	f1_score:35.71	best_score:35.71
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  10.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       32      37      66    46.38   32.65   38.32
# ----------
#         A0        7       9      14    43.75   33.33   37.84
#         A1       10      10      28    50.00   26.32   34.48
#         A2        4       6       6    40.00   40.00   40.00
#         A3        1       3       1    25.00   50.00   33.33
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       1       1    50.00   50.00   50.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        0       0       3     0.00    0.00    0.00
#     AM-LOC        3       2       2    60.00   60.00   60.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        1       0       3   100.00   25.00   40.00
#     AM-PNC        0       1       0     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        3       5       5    37.50   37.50   37.50
# ------------------------------------------------------------
#          V       21      11      19    65.62   52.50   58.33
# ------------------------------------------------------------
#
# iteration:02159	epochs:00053	accuracy:0.29	cost:0.03	f1_score:38.32	best_score:38.32
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  17.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       44      50      54    46.81   44.90   45.83
# ----------
#         A0       10      11      11    47.62   47.62   47.62
#         A1       18      22      20    45.00   47.37   46.15
#         A2        4       7       6    36.36   40.00   38.10
#         A3        2       1       0    66.67  100.00   80.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        0       2       2     0.00    0.00    0.00
#     AM-DIS        0       1       3     0.00    0.00    0.00
#     AM-LOC        3       0       2   100.00   60.00   75.00
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        4       5       4    44.44   50.00   47.06
# ------------------------------------------------------------
#          V       23      10      17    69.70   57.50   63.01
# ------------------------------------------------------------
# iteration:02199	epochs:00054	accuracy:0.34	cost:0.03	f1_score:45.83	best_score:45.83
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  22.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       49      46      49    51.58   50.00   50.78
# ----------
#         A0        7      11      14    38.89   33.33   35.90
#         A1       21      14      17    60.00   55.26   57.53
#         A2        6       5       4    54.55   60.00   57.14
#         A3        1       1       1    50.00   50.00   50.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        1       6       1    14.29   50.00   22.22
#     AM-DIS        1       4       2    20.00   33.33   25.00
#     AM-LOC        4       1       1    80.00   80.00   80.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        5       4       3    55.56   62.50   58.82
# ------------------------------------------------------------
#          V       25      17      15    59.52   62.50   60.98
# ------------------------------------------------------------
#
# iteration:02239	epochs:00055	accuracy:0.35	cost:0.03	f1_score:50.78	best_score:50.78
# iteration:02279	epochs:00056	accuracy:0.33	cost:0.03	f1_score:48.68	best_score:50.78
# iteration:02319	epochs:00057	accuracy:0.28	cost:0.03	f1_score:36.92	best_score:50.78
# iteration:02359	epochs:00058	accuracy:0.31	cost:0.03	f1_score:45.16	best_score:50.78
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  22.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       51      41      47    55.43   52.04   53.68
# ----------
#         A0        7       6      14    53.85   33.33   41.18
#         A1       26      14      12    65.00   68.42   66.67
#         A2        4       1       6    80.00   40.00   53.33
#         A3        2       0       0   100.00  100.00  100.00
#         A4        0       6       1     0.00    0.00    0.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        1       0       1   100.00   50.00   66.67
#     AM-DIS        2       3       1    40.00   66.67   50.00
#     AM-LOC        2       2       3    50.00   40.00   44.44
#     AM-MNR        0       3       1     0.00    0.00    0.00
#     AM-NEG        0       0       4     0.00    0.00    0.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        5       6       3    45.45   62.50   52.63
# ------------------------------------------------------------
#          V       25       7      15    78.12   62.50   69.44
# ------------------------------------------------------------
#
# iteration:02399	epochs:00059	accuracy:0.35	cost:0.03	f1_score:53.68	best_score:53.68
# iteration:02439	epochs:00060	accuracy:0.15	cost:0.04	f1_score:25.27	best_score:53.68
# iteration:02479	epochs:00061	accuracy:0.04	cost:0.06	f1_score:3.97	best_score:53.68
# iteration:02519	epochs:00062	accuracy:0.03	cost:0.06	f1_score:1.86	best_score:53.68
# iteration:02559	epochs:00063	accuracy:0.06	cost:0.05	f1_score:6.73	best_score:53.68
# iteration:02599	epochs:00064	accuracy:0.06	cost:0.05	f1_score:2.47	best_score:53.68
# iteration:02639	epochs:00065	accuracy:0.10	cost:0.05	f1_score:11.11	best_score:53.68
# iteration:02679	epochs:00066	accuracy:0.14	cost:0.04	f1_score:9.23	best_score:53.68
# iteration:02719	epochs:00067	accuracy:0.13	cost:0.04	f1_score:15.46	best_score:53.68
# iteration:02759	epochs:00068	accuracy:0.14	cost:0.04	f1_score:11.27	best_score:53.68
# iteration:02799	epochs:00069	accuracy:0.18	cost:0.04	f1_score:19.39	best_score:53.68
# iteration:02839	epochs:00070	accuracy:0.16	cost:0.04	f1_score:17.19	best_score:53.68
# iteration:02879	epochs:00071	accuracy:0.16	cost:0.04	f1_score:15.00	best_score:53.68
# iteration:02919	epochs:00072	accuracy:0.20	cost:0.04	f1_score:21.00	best_score:53.68
# iteration:02959	epochs:00073	accuracy:0.22	cost:0.03	f1_score:25.74	best_score:53.68
# iteration:02999	epochs:00074	accuracy:0.25	cost:0.03	f1_score:26.53	best_score:53.68
# iteration:03039	epochs:00075	accuracy:0.25	cost:0.03	f1_score:29.17	best_score:53.68
# iteration:03079	epochs:00076	accuracy:0.30	cost:0.03	f1_score:36.84	best_score:53.68
# iteration:03119	epochs:00077	accuracy:0.29	cost:0.03	f1_score:36.96	best_score:53.68
# iteration:03159	epochs:00078	accuracy:0.23	cost:0.04	f1_score:34.92	best_score:53.68
# iteration:03199	epochs:00079	accuracy:0.27	cost:0.03	f1_score:33.67	best_score:53.68
# iteration:03239	epochs:00080	accuracy:0.27	cost:0.03	f1_score:34.04	best_score:53.68
# iteration:03279	epochs:00081	accuracy:0.28	cost:0.03	f1_score:41.79	best_score:53.68
# iteration:03319	epochs:00082	accuracy:0.34	cost:0.03	f1_score:43.85	best_score:53.68
# iteration:03359	epochs:00083	accuracy:0.39	cost:0.02	f1_score:47.52	best_score:53.68
# iteration:03399	epochs:00084	accuracy:0.36	cost:0.03	f1_score:44.09	best_score:53.68
# iteration:03439	epochs:00085	accuracy:0.36	cost:0.03	f1_score:44.32	best_score:53.68
# iteration:03479	epochs:00086	accuracy:0.34	cost:0.03	f1_score:43.52	best_score:53.68
# iteration:03519	epochs:00087	accuracy:0.39	cost:0.03	f1_score:53.63	best_score:53.68
# iteration:03559	epochs:00088	accuracy:0.26	cost:0.03	f1_score:35.07	best_score:53.68
# iteration:03599	epochs:00089	accuracy:0.33	cost:0.03	f1_score:42.25	best_score:53.68
# iteration:03639	epochs:00090	accuracy:0.43	cost:0.02	f1_score:52.46	best_score:53.68
# iteration:03679	epochs:00091	accuracy:0.37	cost:0.03	f1_score:50.53	best_score:53.68
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  35.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       61      36      37    62.89   62.24   62.56
# ----------
#         A0       12      17       9    41.38   57.14   48.00
#         A1       26       8      12    76.47   68.42   72.22
#         A2        9       2       1    81.82   90.00   85.71
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       0       1   100.00   50.00   66.67
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        2       1       1    66.67   66.67   66.67
#     AM-LOC        4       3       1    57.14   80.00   66.67
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        1       4       3    20.00   25.00   22.22
#     AM-PRD        1       1       0    50.00  100.00   66.67
#     AM-TMP        2       0       6   100.00   25.00   40.00
# ------------------------------------------------------------
#          V       32      11       8    74.42   80.00   77.11
# ------------------------------------------------------------
#
# iteration:03719	epochs:00092	accuracy:0.47	cost:0.02	f1_score:62.56	best_score:62.56
# iteration:03759	epochs:00093	accuracy:0.45	cost:0.02	f1_score:55.92	best_score:62.56
# iteration:03799	epochs:00094	accuracy:0.44	cost:0.02	f1_score:58.38	best_score:62.56
# iteration:03839	epochs:00095	accuracy:0.41	cost:0.02	f1_score:56.68	best_score:62.56
# iteration:03879	epochs:00096	accuracy:0.41	cost:0.02	f1_score:61.29	best_score:62.56
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  42.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       60      28      38    68.18   61.22   64.52
# ----------
#         A0       12       5       9    70.59   57.14   63.16
#         A1       24      14      14    63.16   63.16   63.16
#         A2        8       2       2    80.00   80.00   80.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        0       0       2     0.00    0.00    0.00
#     AM-CAU        1       0       1   100.00   50.00   66.67
#     AM-DIS        2       2       1    50.00   66.67   57.14
#     AM-LOC        4       1       1    80.00   80.00   80.00
#     AM-MNR        0       0       1     0.00    0.00    0.00
#     AM-NEG        1       2       3    33.33   25.00   28.57
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        4       2       4    66.67   50.00   57.14
# ------------------------------------------------------------
#          V       35       9       5    79.55   87.50   83.33
# ------------------------------------------------------------
# iteration:03919	epochs:00097	accuracy:0.51	cost:0.02	f1_score:64.52	best_score:64.52
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  47.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       67      32      31    67.68   68.37   68.02
# ----------
#         A0       15       9       6    62.50   71.43   66.67
#         A1       28      12      10    70.00   73.68   71.79
#         A2        8       1       2    88.89   80.00   84.21
#         A3        2       4       0    33.33  100.00   50.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        0       0       2     0.00    0.00    0.00
#     AM-DIS        2       1       1    66.67   66.67   66.67
#     AM-LOC        3       1       2    75.00   60.00   66.67
#     AM-MNR        0       1       1     0.00    0.00    0.00
#     AM-NEG        1       2       3    33.33   25.00   28.57
#     AM-PRD        0       0       1     0.00    0.00    0.00
#     AM-TMP        5       1       3    83.33   62.50   71.43
# ------------------------------------------------------------
#          V       33       3       7    91.67   82.50   86.84
# ------------------------------------------------------------
#
# iteration:03959	epochs:00098	accuracy:0.52	cost:0.02	f1_score:68.02	best_score:68.02
# iteration:03999	epochs:00099	accuracy:0.58	cost:0.01	f1_score:64.95	best_score:68.02
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  47.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       71      27      27    72.45   72.45   72.45
# ----------
#         A0       13       4       8    76.47   61.90   68.42
#         A1       28      12      10    70.00   73.68   71.79
#         A2       10       2       0    83.33  100.00   90.91
#         A3        1       0       1   100.00   50.00   66.67
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       4       0    33.33  100.00   50.00
#     AM-DIS        1       0       2   100.00   33.33   50.00
#     AM-LOC        4       0       1   100.00   80.00   88.89
#     AM-MNR        0       4       1     0.00    0.00    0.00
#     AM-NEG        2       1       2    66.67   50.00   57.14
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        6       0       2   100.00   75.00   85.71
# ------------------------------------------------------------
#          V       35       6       5    85.37   87.50   86.42
# ------------------------------------------------------------
#
# iteration:04039	epochs:00100	accuracy:0.63	cost:0.01	f1_score:72.45	best_score:72.45
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  57.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ...
# iteration:04239	epochs:00105	accuracy:0.52	cost:0.02	f1_score:70.59	best_score:79.79
# iteration:04279	epochs:00106	accuracy:0.53	cost:0.02	f1_score:64.73	best_score:79.79
# iteration:04319	epochs:00107	accuracy:0.46	cost:0.02	f1_score:65.98	best_score:79.79
# iteration:04359	epochs:00108	accuracy:0.37	cost:0.03	f1_score:47.67	best_score:79.79
# iteration:04399	epochs:00109	accuracy:0.26	cost:0.03	f1_score:30.15	best_score:79.79
# iteration:04439	epochs:00110	accuracy:0.36	cost:0.03	f1_score:52.58	best_score:79.79
# iteration:04479	epochs:00111	accuracy:0.45	cost:0.02	f1_score:56.84	best_score:79.79
# iteration:04519	epochs:00112	accuracy:0.47	cost:0.02	f1_score:52.91	best_score:79.79
# iteration:04559	epochs:00113	accuracy:0.59	cost:0.01	f1_score:72.25	best_score:79.79
# iteration:04599	epochs:00114	accuracy:0.47	cost:0.02	f1_score:61.78	best_score:79.79
# iteration:04639	epochs:00115	accuracy:0.60	cost:0.02	f1_score:73.20	best_score:79.79
# iteration:04679	epochs:00116	accuracy:0.46	cost:0.02	f1_score:67.71	best_score:79.79
# iteration:04719	epochs:00117	accuracy:0.62	cost:0.01	f1_score:79.40	best_score:79.79
# iteration:04759	epochs:00118	accuracy:0.63	cost:0.01	f1_score:77.66	best_score:79.79
# iteration:04799	epochs:00119	accuracy:0.75	cost:0.01	f1_score:79.79	best_score:79.79
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  72.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       84      12      14    87.50   85.71   86.60
# ----------
#         A0       18       4       3    81.82   85.71   83.72
#         A1       33       2       5    94.29   86.84   90.41
#         A2        9       1       1    90.00   90.00   90.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       2       0    50.00  100.00   66.67
#     AM-CAU        1       0       1   100.00   50.00   66.67
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       1       0    83.33  100.00   90.91
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        1       2       3    33.33   25.00   28.57
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        7       0       1   100.00   87.50   93.33
# ------------------------------------------------------------
#          V       37       1       3    97.37   92.50   94.87
# ------------------------------------------------------------
# iteration:04839	epochs:00120	accuracy:0.77	cost:0.01	f1_score:86.60	best_score:86.60
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  77.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       89      14       9    86.41   90.82   88.56
# ----------
#         A0       17       4       4    80.95   80.95   80.95
#         A1       36       2       2    94.74   94.74   94.74
#         A2       10       1       0    90.91  100.00   95.24
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        1       2       1    33.33   50.00   40.00
#     AM-CAU        2       1       0    66.67  100.00   80.00
#     AM-DIS        2       2       1    50.00   66.67   57.14
#     AM-LOC        4       1       1    80.00   80.00   80.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       1       0    80.00  100.00   88.89
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       37       2       3    94.87   92.50   93.67
# ------------------------------------------------------------
#
# iteration:04879	epochs:00121	accuracy:0.81	cost:0.01	f1_score:88.56	best_score:88.56
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  77.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       89       7       9    92.71   90.82   91.75
# ----------
#         A0       18       1       3    94.74   85.71   90.00
#         A1       34       4       4    89.47   89.47   89.47
#         A2        9       1       1    90.00   90.00   90.00
#         A3        2       1       0    66.67  100.00   80.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        2       0       1   100.00   66.67   80.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       0       0   100.00  100.00  100.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       40       3       0    93.02  100.00   96.39
# ------------------------------------------------------------
#
# iteration:04919	epochs:00122	accuracy:0.80	cost:0.01	f1_score:91.75	best_score:91.75
# iteration:04959	epochs:00123	accuracy:0.74	cost:0.01	f1_score:85.57	best_score:91.75
# iteration:04999	epochs:00124	accuracy:0.79	cost:0.01	f1_score:89.01	best_score:91.75
# iteration:05039	epochs:00125	accuracy:0.77	cost:0.01	f1_score:83.84	best_score:91.75
# iteration:05079	epochs:00126	accuracy:0.68	cost:0.01	f1_score:86.32	best_score:91.75
# iteration:05119	epochs:00127	accuracy:0.71	cost:0.01	f1_score:84.54	best_score:91.75
# iteration:05159	epochs:00128	accuracy:0.74	cost:0.01	f1_score:77.61	best_score:91.75
# iteration:05199	epochs:00129	accuracy:0.74	cost:0.01	f1_score:87.63	best_score:91.75
# iteration:05239	epochs:00130	accuracy:0.77	cost:0.01	f1_score:84.69	best_score:91.75
# iteration:05279	epochs:00131	accuracy:0.68	cost:0.01	f1_score:84.04	best_score:91.75
# iteration:05319	epochs:00132	accuracy:0.60	cost:0.01	f1_score:67.00	best_score:91.75
# iteration:05359	epochs:00133	accuracy:0.66	cost:0.01	f1_score:79.79	best_score:91.75
# iteration:05399	epochs:00134	accuracy:0.77	cost:0.01	f1_score:89.12	best_score:91.75
# iteration:05439	epochs:00135	accuracy:0.70	cost:0.01	f1_score:86.73	best_score:91.75
# iteration:05479	epochs:00136	accuracy:0.56	cost:0.02	f1_score:75.13	best_score:91.75
# iteration:05519	epochs:00137	accuracy:0.55	cost:0.02	f1_score:73.47	best_score:91.75
# iteration:05559	epochs:00138	accuracy:0.47	cost:0.02	f1_score:64.36	best_score:91.75
# iteration:05599	epochs:00139	accuracy:0.56	cost:0.01	f1_score:73.12	best_score:91.75
# iteration:05639	epochs:00140	accuracy:0.60	cost:0.01	f1_score:77.49	best_score:91.75
# iteration:05679	epochs:00141	accuracy:0.62	cost:0.01	f1_score:71.50	best_score:91.75
# iteration:05719	epochs:00142	accuracy:0.64	cost:0.01	f1_score:81.05	best_score:91.75
# iteration:05759	epochs:00143	accuracy:0.59	cost:0.01	f1_score:76.38	best_score:91.75
# iteration:05799	epochs:00144	accuracy:0.62	cost:0.01	f1_score:80.83	best_score:91.75
# iteration:05839	epochs:00145	accuracy:0.62	cost:0.01	f1_score:77.39	best_score:91.75
# iteration:05879	epochs:00146	accuracy:0.62	cost:0.01	f1_score:76.60	best_score:91.75
# iteration:05919	epochs:00147	accuracy:0.30	cost:0.03	f1_score:46.08	best_score:91.75
# iteration:05959	epochs:00148	accuracy:0.29	cost:0.03	f1_score:42.51	best_score:91.75
# iteration:05999	epochs:00149	accuracy:0.31	cost:0.03	f1_score:48.78	best_score:91.75
# iteration:06039	epochs:00150	accuracy:0.41	cost:0.02	f1_score:51.23	best_score:91.75
# iteration:06079	epochs:00151	accuracy:0.40	cost:0.02	f1_score:51.58	best_score:91.75
# iteration:06119	epochs:00152	accuracy:0.49	cost:0.02	f1_score:63.10	best_score:91.75
# iteration:06159	epochs:00153	accuracy:0.43	cost:0.02	f1_score:58.00	best_score:91.75
# iteration:06199	epochs:00154	accuracy:0.27	cost:0.03	f1_score:33.20	best_score:91.75
# iteration:06239	epochs:00155	accuracy:0.29	cost:0.03	f1_score:38.14	best_score:91.75
# iteration:06279	epochs:00156	accuracy:0.36	cost:0.03	f1_score:56.84	best_score:91.75
# iteration:06319	epochs:00157	accuracy:0.33	cost:0.03	f1_score:43.48	best_score:91.75
# iteration:06359	epochs:00158	accuracy:0.53	cost:0.02	f1_score:62.56	best_score:91.75
# iteration:06399	epochs:00159	accuracy:0.66	cost:0.01	f1_score:75.13	best_score:91.75
# iteration:06439	epochs:00160	accuracy:0.69	cost:0.01	f1_score:82.83	best_score:91.75
# iteration:06479	epochs:00161	accuracy:0.73	cost:0.01	f1_score:90.16	best_score:91.75
# iteration:06519	epochs:00162	accuracy:0.77	cost:0.01	f1_score:88.21	best_score:91.75
# iteration:06559	epochs:00163	accuracy:0.77	cost:0.01	f1_score:89.45	best_score:91.75
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  90.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       94       2       4    97.92   95.92   96.91
# ----------
#         A0       19       2       2    90.48   90.48   90.48
#         A1       37       0       1   100.00   97.37   98.67
#         A2       10       0       0   100.00  100.00  100.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       0       0   100.00  100.00  100.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        7       0       1   100.00   87.50   93.33
# ------------------------------------------------------------
#          V       38       2       2    95.00   95.00   95.00
# ------------------------------------------------------------
#
# iteration:06599	epochs:00164	accuracy:0.90	cost:0.00	f1_score:96.91	best_score:96.91
# iteration:06639	epochs:00165	accuracy:0.89	cost:0.00	f1_score:94.30	best_score:96.91
# iteration:06679	epochs:00166	accuracy:0.89	cost:0.00	f1_score:94.36	best_score:96.91
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  92.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       95       2       3    97.94   96.94   97.44
# ----------
#         A0       19       0       2   100.00   90.48   95.00
#         A1       37       1       1    97.37   97.37   97.37
#         A2       10       1       0    90.91  100.00   95.24
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       0       0   100.00  100.00  100.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       39       3       1    92.86   97.50   95.12
# ------------------------------------------------------------
# iteration:06719	epochs:00167	accuracy:0.92	cost:0.00	f1_score:97.44	best_score:97.44
# iteration:06759	epochs:00168	accuracy:0.91	cost:0.00	f1_score:96.94	best_score:97.44
# iteration:06799	epochs:00169	accuracy:0.95	cost:0.00	f1_score:97.44	best_score:97.44
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  90.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       97       4       1    96.04   98.98   97.49
# ----------
#         A0       20       3       1    86.96   95.24   90.91
#         A1       38       0       0   100.00  100.00  100.00
#         A2       10       0       0   100.00  100.00  100.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       1       0    80.00  100.00   88.89
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       40       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#
# iteration:06839	epochs:00170	accuracy:0.94	cost:0.00	f1_score:97.49	best_score:97.49
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props :  92.50
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       96       2       2    97.96   97.96   97.96
# ----------
#         A0       19       2       2    90.48   90.48   90.48
#         A1       38       0       0   100.00  100.00  100.00
#         A2       10       0       0   100.00  100.00  100.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       0       0   100.00  100.00  100.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       40       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#
# iteration:06879	epochs:00171	accuracy:0.92	cost:0.00	f1_score:97.96	best_score:97.96
# Number of Sentences    :          40
# Number of Propositions :          40
# Percentage of perfect props : 100.00
#
#               corr.  excess  missed    prec.    rec.      F1
# ------------------------------------------------------------
#    Overall       98       0       0   100.00  100.00  100.00
# ----------
#         A0       21       0       0   100.00  100.00  100.00
#         A1       38       0       0   100.00  100.00  100.00
#         A2       10       0       0   100.00  100.00  100.00
#         A3        2       0       0   100.00  100.00  100.00
#         A4        1       0       0   100.00  100.00  100.00
#     AM-ADV        2       0       0   100.00  100.00  100.00
#     AM-CAU        2       0       0   100.00  100.00  100.00
#     AM-DIS        3       0       0   100.00  100.00  100.00
#     AM-LOC        5       0       0   100.00  100.00  100.00
#     AM-MNR        1       0       0   100.00  100.00  100.00
#     AM-NEG        4       0       0   100.00  100.00  100.00
#     AM-PRD        1       0       0   100.00  100.00  100.00
#     AM-TMP        8       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#          V       40       0       0   100.00  100.00  100.00
# ------------------------------------------------------------
#
# best_score: 100.0 exiting
