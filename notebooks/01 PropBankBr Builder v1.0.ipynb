# %% [markdown]
# # 1. IMPORTS

# %%
#data_propbankbr lives within datasets
import sys
sys.path.append('../datasets/')
sys.path.append('../datasets/scripts')

import re
import numpy as np
import pandas as pd 
from scripts.propbankbr import propbankbr_parser

# %%
# This dataframe has all multiple arguments on columns ARG0 ~ARG6
df = propbankbr_parser('1.0')
print(df.shape)
df.head()
# Out:
# (69122, 17)
#   ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# 0  1  1  0    0            Brasília            Brasília   PROP        F|S
# 1  2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2  3  1  0    0           publicada            publicar  V-PCP        F|S
# 3  4  1  0    0                hoje                hoje    ADV          -
# 4  5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#        CTREE     PRED  ARG0 ARG1 ARG2 ARG3  ARG4  ARG5  ARG6
# 0  (FCL(NP*)        -     *    *    *    *  None  None  None
# 1       (NP*        -  (A0*    *    *    *  None  None  None
# 2  (ICL(VP*)        -     *    *    *    *  None  None  None
# 3  (ADVP*)))        -    *)    *    *    *  None  None  None
# 4      (VP*)  revelar  (V*)    *    *    *  None  None  None

# %%
df.tail()
# Out:
#        ID     S     P  P_S               FORM              LEMMA  GPOS MORF  \
# 69117  31  3308  5776    2                 de                 de   PRP    -
# 69118  32  3308  5776    2          J.R.Duran          J.R.Duran  PROP  M|S
# 69119  33  3308  5776    2                  ,                  -    PU    -
# 69120  34  3308  5776    2  Alexandra_Brochen  Alexandra_Brochen  PROP  F|S
# 69121  35  3308  5776    2                  .                  -    PU    -
#
#           CTREE PRED ARG0 ARG1  ARG2  ARG3  ARG4  ARG5  ARG6
# 69117      (PP*    -    *    *  None  None  None  None  None
# 69118      (NP*    -    *    *  None  None  None  None  None
# 69119         *    -    *    *  None  None  None  None  None
# 69120  (NP*))))    -    *    *  None  None  None  None  None
# 69121        *)    -    *    *  None  None  None  None  None

# %% [markdown]
#  ### 1. 1 Normalization
# Convert each record into a machine learning example i.e one argument per row
# * Filter        .: each ARG column
# * Create        .: tmp row holding the number of the argument ( for further ordering )
# * Concatenate   .: everybody afterwards by rows
# * Sort          .: reorder by S and TMP

# %%
def unstack_df(df):
    '''
        Unstack outputs
        args:
            df :DataFrame ConLL flat tree format
        returns:
            df :DataFrame
    '''
    column_arg0 = list(df.columns).index('ARG0')
    columns_features= df.columns[:column_arg0]
    df_feature= df.loc[:,columns_features].copy()

    dataframes=[]
    num_records=0
    for i in range(7):
        col= 'ARG{:}'.format(i)
        df_target= df[col].dropna().to_frame()
        df_arg = df_feature.join(df_target, how='right')
        df_arg = df_arg.rename(index=str, columns={col: 'ARG'})
        df_arg['TMP']=i+1
    
        num_records+=df_arg.shape[0]
        print('{:}-\tnew records: {:}\ttotal records: {:}'.format(i, df_arg.shape[0],num_records))
        dataframes.append(df_arg)

    #Concatente, sort by sentence & argument, reindex
    df = pd.concat(dataframes,axis=0)
    df.sort_values(by=['S','TMP'],axis=0 ,kind='mergesort', inplace=True)    
    df = df.reset_index(drop=True)
    df.index.names=['INDEX']
    return df

# %%
df = unstack_df(df)
# Out:
# 0-	new records: 69122	total records: 69122
# 1-	new records: 40974	total records: 110096
# 2-	new records: 18593	total records: 128689
# 3-	new records: 6679	total records: 135368
# 4-	new records: 2254	total records: 137622
# 5-	new records: 572	total records: 138194
# 6-	new records: 178	total records: 138372

# %%
df.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#            CTREE     PRED   ARG  TMP
# INDEX
# 0      (FCL(NP*)        -     *    1
# 1           (NP*        -  (A0*    1
# 2      (ICL(VP*)        -     *    1
# 3      (ADVP*)))        -    *)    1
# 4          (VP*)  revelar  (V*)    1

# %% [markdown]
#  ### 1.2 FIXING EXISTING FEATURES
#  #### 1.2.1 FIXING PREDICATE
#   * __PRED__ must be non empty only when ARG is (V*)
#   * Drop column __TMP__

# %%
def fix_pred(df):
    index= (df['TMP'] == df['P_S'])
    df.loc[~index,'PRED']= '-'
    df = df.drop(labels='TMP', axis=1)
    return df

# %%
#Fix predicate 
df = fix_pred(df)
df.head(30)
# Out:
#        ID  S  P  P_S                FORM               LEMMA   GPOS  \
# INDEX
# 0       1  1  0    0            Brasília            Brasília   PROP
# 1       2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N
# 2       3  1  0    0           publicada            publicar  V-PCP
# 3       4  1  0    0                hoje                hoje    ADV
# 4       5  1  1    1              revela             revelar  V-FIN
# 5       6  1  1    1                  um                  um    ART
# 6       7  1  1    1                dado                dado      N
# 7       8  1  1    1        supreendente       surpreendente    ADJ
# 8       9  1  1    1                   :                   -     PU
# 9      10  1  2    2           recusando             recusar  V-GER
# 10     11  1  2    2                 uma                  um    ART
# 11     12  1  2    2             postura             postura      N
# 12     13  1  2    2             radical             radical    ADJ
# 13     14  1  2    2                   ,                   -     PU
# 14     15  1  2    2                   a                   o    ART
# 15     16  1  2    2          esmagadora           esmagador    ADJ
# 16     17  1  2    2             maioria             maioria      N
# 17     18  1  2    2                   (                   -     PU
# 18     19  1  2    2                  77                  77    NUM
# 19     20  1  2    2                   %                   %      N
# 20     21  1  2    2                   )                   -     PU
# 21     22  1  2    2                  de                  de    PRP
# 22     23  1  2    2                  os                   o    ART
# 23     24  1  2    2           eleitores             eleitor      N
# 24     25  1  3    3                quer              querer  V-FIN
# 25     26  1  3    3                   o                   o    ART
# 26     27  1  3    3                  PT                  PT   PROP
# 27     28  1  4    4        participando          participar  V-GER
# 28     29  1  4    4                  de                  de    PRP
# 29     30  1  4    4                   o                   o    ART
#
#             MORF          CTREE     PRED   ARG
# INDEX
# 0            F|S      (FCL(NP*)        -     *
# 1            F|S           (NP*        -  (A0*
# 2            F|S      (ICL(VP*)        -     *
# 3              -      (ADVP*)))        -    *)
# 4      PR|3S|IND          (VP*)  revelar  (V*)
# 5            M|S           (NP*        -  (A1*
# 6            M|S              *        -     *
# 7            M|S        (ADJP*)        -     *
# 8              -              *        -     *
# 9              -  (FCL(ICL(VP*)        -     *
# 10           F|S           (NP*        -     *
# 11           F|S              *        -     *
# 12           F|S      (ADJP*)))        -     *
# 13             -              *        -     *
# 14           F|S           (NP*        -     *
# 15           F|S              *        -     *
# 16           F|S              *        -     *
# 17             -              *        -     *
# 18           M|P           (NP*        -     *
# 19           M|P             *)        -     *
# 20             -              *        -     *
# 21             -           (PP*        -     *
# 22           M|P           (NP*        -     *
# 23           M|P           *)))        -     *
# 24     PR|3S|IND          (VP*)        -     *
# 25           M|S           (NP*        -     *
# 26           M|S             *)        -     *
# 27             -      (ICL(VP*)        -     *
# 28             -           (PP*        -     *
# 29           M|S           (NP*        -     *

# %%
df.tail(35)
# Out:
#         ID     S     P  P_S               FORM              LEMMA       GPOS  \
# INDEX
# 138337   1  3308  5774    0            Além_de            além_de        PRP
# 138338   2  3308  5774    0       Mauro_Salles       Mauro_Salles       PROP
# 138339   3  3308  5774    0                que                que  PRON-INDP
# 138340   4  3308  5775    1        surpreendeu        surpreender      V-FIN
# 138341   5  3308  5775    1                  a                  o        ART
# 138342   6  3308  5775    1             galera             galera          N
# 138343   7  3308  5775    1                  a                  a        PRP
# 138344   8  3308  5775    1                  o                  o        ART
# 138345   9  3308  5776    2            revelar            revelar      V-INF
# 138346  10  3308  5776    2                seu                seu   PRON-DET
# 138347  11  3308  5776    2               côté               côté          N
# 138348  12  3308  5776    2                 de                 de        PRP
# 138349  13  3308  5776    2          fotógrafo          fotógrafo          N
# 138350  14  3308  5776    2       profissional       profissional        ADJ
# 138351  15  3308  5776    2                 em                 em        PRP
# 138352  16  3308  5776    2                  o                  o        ART
# 138353  17  3308  5776    2              ínico             início          N
# 138354  18  3308  5776    2                 de                 de        PRP
# 138355  19  3308  5776    2                  a                  o        ART
# 138356  20  3308  5776    2           carreira           carreira          N
# 138357  21  3308  5776    2                  ,                  -         PU
# 138358  22  3308  5776    2                  o                  o        ART
# 138359  23  3308  5776    2               foco               foco          N
# 138360  24  3308  5776    2          principal          principal        ADJ
# 138361  25  3308  5776    2                 de                 de        PRP
# 138362  26  3308  5776    2                  o                  o        ART
# 138363  27  3308  5776    2           encontro           encontro          N
# 138364  28  3308  5776    2                foi                ser      V-FIN
# 138365  29  3308  5776    2                  a                  o        ART
# 138366  30  3308  5776    2             mulher             mulher          N
# 138367  31  3308  5776    2                 de                 de        PRP
# 138368  32  3308  5776    2          J.R.Duran          J.R.Duran       PROP
# 138369  33  3308  5776    2                  ,                  -         PU
# 138370  34  3308  5776    2  Alexandra_Brochen  Alexandra_Brochen       PROP
# 138371  35  3308  5776    2                  .                  -         PU
#
#              MORF        CTREE     PRED       ARG
# INDEX
# 138337          -     (FCL(PP*        -         *
# 138338        M|S         (NP*        -         *
# 138339        M|S    (FCL(NP*)        -         *
# 138340  PS|3S|IND        (VP*)        -         *
# 138341        F|S         (NP*        -         *
# 138342        F|S           *)        -         *
# 138343          -         (PP*        -         *
# 138344        M|S        (ICL*        -         *
# 138345          -        (VP*)  revelar      (V*)
# 138346        M|S         (NP*        -      (A1*
# 138347        M|S            *        -         *
# 138348          -         (PP*        -         *
# 138349        M|S         (NP*        -         *
# 138350        M|S   (ADJP*))))        -        *)
# 138351          -         (PP*        -  (AM-TMP*
# 138352        M|S         (NP*        -         *
# 138353        M|S         (NP*        -         *
# 138354          -         (PP*        -         *
# 138355        F|S         (NP*        -         *
# 138356        F|S  *))))))))))        -        *)
# 138357          -            *        -         *
# 138358        M|S         (NP*        -         *
# 138359        M|S            *        -         *
# 138360        M|S      (ADJP*)        -         *
# 138361          -         (PP*        -         *
# 138362        M|S         (NP*        -         *
# 138363        M|S         *)))        -         *
# 138364  PS|3S|IND        (VP*)        -         *
# 138365        F|S         (NP*        -         *
# 138366        F|S            *        -         *
# 138367          -         (PP*        -         *
# 138368        M|S         (NP*        -         *
# 138369          -            *        -         *
# 138370        F|S     (NP*))))        -         *
# 138371          -           *)        -         *

# %% [markdown]
#  #### 1.2.2 FIXING P
#   __P__ will be a range like id over the predicates.

# %%
def fix_p(df):
    P=[]
    P_S=[]
    S= list(set(df['S'].values))
    p=1

    for s in S:
        sindex = df['S'] == s
        idx = [int(x) for x in 
            df.loc[sindex,'ID'].values]
        
        P += [p + int(i / idx[-1])
                for i, _ in enumerate(idx)]
        
        P_S += [int(i / idx[-1])
                for i, _ in enumerate(idx)]

        p = P[-1]

    df['P']=P        
    df['P_S']=P_S        
    return df

# %%
df = fix_p(df)
df.head(35)
# Out:
#        ID  S  P  P_S                       FORM                      LEMMA  \
# INDEX
# 0       1  1  1    0                   Brasília                   Brasília
# 1       2  1  1    0         Pesquisa_Datafolha         Pesquisa_Datafolha
# 2       3  1  1    0                  publicada                   publicar
# 3       4  1  1    0                       hoje                       hoje
# 4       5  1  1    0                     revela                    revelar
# 5       6  1  1    0                         um                         um
# 6       7  1  1    0                       dado                       dado
# 7       8  1  1    0               supreendente              surpreendente
# 8       9  1  1    0                          :                          -
# 9      10  1  1    0                  recusando                    recusar
# 10     11  1  1    0                        uma                         um
# 11     12  1  1    0                    postura                    postura
# 12     13  1  1    0                    radical                    radical
# 13     14  1  1    0                          ,                          -
# 14     15  1  1    0                          a                          o
# 15     16  1  1    0                 esmagadora                  esmagador
# 16     17  1  1    0                    maioria                    maioria
# 17     18  1  1    0                          (                          -
# 18     19  1  1    0                         77                         77
# 19     20  1  1    0                          %                          %
# 20     21  1  1    0                          )                          -
# 21     22  1  1    0                         de                         de
# 22     23  1  1    0                         os                          o
# 23     24  1  1    0                  eleitores                    eleitor
# 24     25  1  1    0                       quer                     querer
# 25     26  1  1    0                          o                          o
# 26     27  1  1    0                         PT                         PT
# 27     28  1  1    0               participando                 participar
# 28     29  1  1    0                         de                         de
# 29     30  1  1    0                          o                          o
# 30     31  1  1    0                    Governo                    governo
# 31     32  1  1    0  Fernando_Henrique_Cardoso  Fernando_Henrique_Cardoso
# 32     33  1  1    0                          .                          -
# 33      1  1  2    1                   Brasília                   Brasília
# 34      2  1  2    1         Pesquisa_Datafolha         Pesquisa_Datafolha
#
#         GPOS       MORF          CTREE     PRED   ARG
# INDEX
# 0       PROP        F|S      (FCL(NP*)        -     *
# 1          N        F|S           (NP*        -  (A0*
# 2      V-PCP        F|S      (ICL(VP*)        -     *
# 3        ADV          -      (ADVP*)))        -    *)
# 4      V-FIN  PR|3S|IND          (VP*)  revelar  (V*)
# 5        ART        M|S           (NP*        -  (A1*
# 6          N        M|S              *        -     *
# 7        ADJ        M|S        (ADJP*)        -     *
# 8         PU          -              *        -     *
# 9      V-GER          -  (FCL(ICL(VP*)        -     *
# 10       ART        F|S           (NP*        -     *
# 11         N        F|S              *        -     *
# 12       ADJ        F|S      (ADJP*)))        -     *
# 13        PU          -              *        -     *
# 14       ART        F|S           (NP*        -     *
# 15       ADJ        F|S              *        -     *
# 16         N        F|S              *        -     *
# 17        PU          -              *        -     *
# 18       NUM        M|P           (NP*        -     *
# 19         N        M|P             *)        -     *
# 20        PU          -              *        -     *
# 21       PRP          -           (PP*        -     *
# 22       ART        M|P           (NP*        -     *
# 23         N        M|P           *)))        -     *
# 24     V-FIN  PR|3S|IND          (VP*)        -     *
# 25       ART        M|S           (NP*        -     *
# 26      PROP        M|S             *)        -     *
# 27     V-GER          -      (ICL(VP*)        -     *
# 28       PRP          -           (PP*        -     *
# 29       ART        M|S           (NP*        -     *
# 30         N        M|S              *        -     *
# 31      PROP        M|S     (NP*))))))        -    *)
# 32        PU          -             *)        -     *
# 33      PROP        F|S      (FCL(NP*)        -     *
# 34         N        F|S           (NP*        -     *

# %%
df1.tail(35)
# Out:
#         ID     S     P  P_S               FORM              LEMMA       GPOS  \
# INDEX
# 138337   1  3308  2469    1            Além_de            além_de        PRP
# 138338   2  3308  2469    1       Mauro_Salles       Mauro_Salles       PROP
# 138339   3  3308  2469    1                que                que  PRON-INDP
# 138340   4  3308  2469    1        surpreendeu        surpreender      V-FIN
# 138341   5  3308  2469    1                  a                  o        ART
# 138342   6  3308  2469    1             galera             galera          N
# 138343   7  3308  2469    1                  a                  a        PRP
# 138344   8  3308  2469    1                  o                  o        ART
# 138345   9  3308  2469    1            revelar            revelar      V-INF
# 138346  10  3308  2469    1                seu                seu   PRON-DET
# 138347  11  3308  2469    1               côté               côté          N
# 138348  12  3308  2469    1                 de                 de        PRP
# 138349  13  3308  2469    1          fotógrafo          fotógrafo          N
# 138350  14  3308  2469    1       profissional       profissional        ADJ
# 138351  15  3308  2469    1                 em                 em        PRP
# 138352  16  3308  2469    1                  o                  o        ART
# 138353  17  3308  2469    1              ínico             início          N
# 138354  18  3308  2469    1                 de                 de        PRP
# 138355  19  3308  2469    1                  a                  o        ART
# 138356  20  3308  2469    1           carreira           carreira          N
# 138357  21  3308  2469    1                  ,                  -         PU
# 138358  22  3308  2469    1                  o                  o        ART
# 138359  23  3308  2469    1               foco               foco          N
# 138360  24  3308  2469    1          principal          principal        ADJ
# 138361  25  3308  2469    1                 de                 de        PRP
# 138362  26  3308  2469    1                  o                  o        ART
# 138363  27  3308  2469    1           encontro           encontro          N
# 138364  28  3308  2469    1                foi                ser      V-FIN
# 138365  29  3308  2469    1                  a                  o        ART
# 138366  30  3308  2469    1             mulher             mulher          N
# 138367  31  3308  2469    1                 de                 de        PRP
# 138368  32  3308  2469    1          J.R.Duran          J.R.Duran       PROP
# 138369  33  3308  2469    1                  ,                  -         PU
# 138370  34  3308  2469    1  Alexandra_Brochen  Alexandra_Brochen       PROP
# 138371  35  3308  2469    1                  .                  -         PU
#
#              MORF        CTREE     PRED       ARG
# INDEX
# 138337          -     (FCL(PP*        -         *
# 138338        M|S         (NP*        -         *
# 138339        M|S    (FCL(NP*)        -         *
# 138340  PS|3S|IND        (VP*)        -         *
# 138341        F|S         (NP*        -         *
# 138342        F|S           *)        -         *
# 138343          -         (PP*        -         *
# 138344        M|S        (ICL*        -         *
# 138345          -        (VP*)  revelar      (V*)
# 138346        M|S         (NP*        -      (A1*
# 138347        M|S            *        -         *
# 138348          -         (PP*        -         *
# 138349        M|S         (NP*        -         *
# 138350        M|S   (ADJP*))))        -        *)
# 138351          -         (PP*        -  (AM-TMP*
# 138352        M|S         (NP*        -         *
# 138353        M|S         (NP*        -         *
# 138354          -         (PP*        -         *
# 138355        F|S         (NP*        -         *
# 138356        F|S  *))))))))))        -        *)
# 138357          -            *        -         *
# 138358        M|S         (NP*        -         *
# 138359        M|S            *        -         *
# 138360        M|S      (ADJP*)        -         *
# 138361          -         (PP*        -         *
# 138362        M|S         (NP*        -         *
# 138363        M|S         *)))        -         *
# 138364  PS|3S|IND        (VP*)        -         *
# 138365        F|S         (NP*        -         *
# 138366        F|S            *        -         *
# 138367          -         (PP*        -         *
# 138368        M|S         (NP*        -         *
# 138369          -            *        -         *
# 138370        F|S     (NP*))))        -         *
# 138371          -           *)        -         *

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=138372, step=1, name='INDEX')

# %%
df.to_csv('../datasets/csvs/1.0/gs.csv', encoding='utf-8')
