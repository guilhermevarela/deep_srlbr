# %% [markdown]
# # 1. IMPORTS

# %%
#data_propbankbr lives within datasets
import sys
sys.path.append('../datasets/')
sys.path.append('../datasets/scripts')

import re
import numpy as np
import pandas as pd 
from scripts.propbankbr import propbankbr_parser

REQUIRED_COLUMNS = ['ID', 'S', 'P', 'P_S', 'FORM', 'LEMMA', 'GPOS', 'MORF', 'CTREE', 'PRED', 'ARG0']

# %%
# This dataframe has all multiple arguments on columns ARG0 ~ARG6
df = propbankbr_parser('1.0')
print(df.shape)
df.head()
# Out:
# (69122, 17)
#   ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# 0  1  1  0    0            Brasília            Brasília   PROP        F|S
# 1  2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2  3  1  0    0           publicada            publicar  V-PCP        F|S
# 3  4  1  0    0                hoje                hoje    ADV          -
# 4  5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#        CTREE     PRED  ARG0 ARG1 ARG2 ARG3  ARG4  ARG5  ARG6
# 0  (FCL(NP*)        -     *    *    *    *  None  None  None
# 1       (NP*        -  (A0*    *    *    *  None  None  None
# 2  (ICL(VP*)        -     *    *    *    *  None  None  None
# 3  (ADVP*)))        -    *)    *    *    *  None  None  None
# 4      (VP*)  revelar  (V*)    *    *    *  None  None  None

# %%
df.tail()
# Out:
#        ID     S     P  P_S               FORM              LEMMA  GPOS MORF  \
# 69117  31  3308  5776    2                 de                 de   PRP    -
# 69118  32  3308  5776    2          J.R.Duran          J.R.Duran  PROP  M|S
# 69119  33  3308  5776    2                  ,                  -    PU    -
# 69120  34  3308  5776    2  Alexandra_Brochen  Alexandra_Brochen  PROP  F|S
# 69121  35  3308  5776    2                  .                  -    PU    -
#
#           CTREE PRED ARG0 ARG1  ARG2  ARG3  ARG4  ARG5  ARG6
# 69117      (PP*    -    *    *  None  None  None  None  None
# 69118      (NP*    -    *    *  None  None  None  None  None
# 69119         *    -    *    *  None  None  None  None  None
# 69120  (NP*))))    -    *    *  None  None  None  None  None
# 69121        *)    -    *    *  None  None  None  None  None

# %%
for label in REQUIRED_COLUMNS:
    tmpdf = df[label].to_frame()
    if tmpdf.isnull().values.any():
        print('there are missing values on required fields')

# %%
# dftest = df[ df['FORM'] == 'grevismo']
# P in (870, 871, 872)
dftest = df[ df['S'] == 3165]
# dftest.loc[21486:21516,:].head()
dftest.head(30)
# Out:
#        ID     S     P  P_S       FORM       LEMMA       GPOS         MORF  \
# 66393   1  3165  5537    0          «           -         PU            -
# 66394   2  3165  5537    0         Se          se     CONJ-S            -
# 66395   3  3165  5537    0        for         ser      V-FIN  FUT|3S|SUBJ
# 66396   4  3165  5537    0        uma          um        ART          F|S
# 66397   5  3165  5537    0      greve       greve          N          F|S
# 66398   6  3165  5537    0         só          só        ADV            -
# 66399   7  3165  5537    0        por         por        PRP            -
# 66400   8  3165  5537    0   grevismo    grevismo          N          M|S
# 66401   9  3165  5537    0          ,           -         PU            -
# 66402  10  3165  5537    0         de          de        PRP            -
# 66403  11  3165  5537    0         aí          aí        ADV            -
# 66404  12  3165  5538    1  prejudica  prejudicar      V-FIN    PR|3S|IND
# 66405  13  3165  5538    1          a           a        PRP            -
# 66406  14  3165  5538    1       quem        quem  PRON-INDP        M/F|S
# 66407  15  3165  5538    1          é         ser      V-FIN    PR|3S|IND
# 66408  16  3165  5538    1  favorável   favorável        ADJ        M/F|S
# 66409  17  3165  5538    1          a           a        PRP            -
# 66410  18  3165  5538    1       isso        isso  PRON-INDP          M|S
# 66411  19  3165  5538    1          .           -         PU            -
#
#            CTREE        PRED  ARG0  ARG1  ARG2  ARG3  ARG4  ARG5  ARG6
# 66393  (FCL(FCL*           -     *  None  None  None  None  None  None
# 66394          *           -     *  None  None  None  None  None  None
# 66395      (VP*)           -     *  None  None  None  None  None  None
# 66396       (NP*           -  (A0*  None  None  None  None  None  None
# 66397          *           -     *  None  None  None  None  None  None
# 66398       (PP*           -     *  None  None  None  None  None  None
# 66399          *           -     *  None  None  None  None  None  None
# 66400   (NP*))))           -    *)  None  None  None  None  None  None
# 66401          *           -     *  None  None  None  None  None  None
# 66402     (ADVP*           -     *  None  None  None  None  None  None
# 66403         *)           -     *  None  None  None  None  None  None
# 66404      (VP*)  prejudicar  (V*)  None  None  None  None  None  None
# 66405       (PP*           -  (A1*  None  None  None  None  None  None
# 66406  (FCL(NP*)           -     *  None  None  None  None  None  None
# 66407      (VP*)           -     *  None  None  None  None  None  None
# 66408     (ADJP*           -     *  None  None  None  None  None  None
# 66409       (PP*           -     *  None  None  None  None  None  None
# 66410  (NP*)))))           -    *)  None  None  None  None  None  None
# 66411         *)           -     *  None  None  None  None  None  None

# %% [markdown]
#  ### 1. 1 Normalization
# Convert each record into a machine learning example i.e one argument per row
# * Filter        .: each ARG column
# * Create        .: tmp row holding the number of the argument ( for further ordering )
# * Concatenate   .: everybody afterwards by rows
# * Sort          .: reorder by S and TMP

# %%
def unstack_df(df):
    '''
        Unstack outputs
        args:
            df :DataFrame ConLL flat tree format
        returns:
            df :DataFrame
    '''
    column_arg0 = list(df.columns).index('ARG0')
    columns_features= df.columns[:column_arg0]
    df_feature= df.loc[:,columns_features].copy()

    dataframes=[]
    num_records=0
    for i in range(7):
        col= 'ARG{:}'.format(i)
        df_target= df[col].dropna().to_frame()
        df_arg = df_feature.join(df_target, how='right')
        df_arg = df_arg.rename(index=str, columns={col: 'ARG'})
        df_arg['TMP']=i+1
    
        num_records+=df_arg.shape[0]
        print('{:}-\tnew records: {:}\ttotal records: {:}'.format(i, df_arg.shape[0],num_records))
        dataframes.append(df_arg)

    #Concatente, sort by sentence & argument, reindex
    df = pd.concat(dataframes,axis=0)
    df.sort_values(by=['S','TMP'],axis=0 ,kind='mergesort', inplace=True)    
    df = df.reset_index(drop=True)
    df.index.names=['INDEX']
    return df

# %%
df = unstack_df(df)
# Out:
# 0-	new records: 69122	total records: 69122
# 1-	new records: 40975	total records: 110097
# 2-	new records: 18598	total records: 128695
# 3-	new records: 6679	total records: 135374
# 4-	new records: 2254	total records: 137628
# 5-	new records: 572	total records: 138200
# 6-	new records: 178	total records: 138378

# %%
df.head()
# Out:
#       ID  S  P  P_S                FORM               LEMMA   GPOS       MORF  \
# INDEX
# 0      1  1  0    0            Brasília            Brasília   PROP        F|S
# 1      2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N        F|S
# 2      3  1  0    0           publicada            publicar  V-PCP        F|S
# 3      4  1  0    0                hoje                hoje    ADV          -
# 4      5  1  1    1              revela             revelar  V-FIN  PR|3S|IND
#
#            CTREE     PRED   ARG  TMP
# INDEX
# 0      (FCL(NP*)        -     *    1
# 1           (NP*        -  (A0*    1
# 2      (ICL(VP*)        -     *    1
# 3      (ADVP*)))        -    *)    1
# 4          (VP*)  revelar  (V*)    1

# %%
test_columns = list(REQUIRED_COLUMNS)
test_columns[-1] = 'ARG'
test_columns.append('TMP')
for label in test_columns:
    tmpdf = df[label].to_frame()
    if tmpdf.isnull().values.any():
        print('there are missing values on required fields')

# %%
# dftest = df[ df['FORM'] == 'no_entanto']
# P in (870, 871, 872)
dftest = df[ df['S'] == 472]
# dftest.loc[21486:21516,:].head()
dftest.head(30)
# Out:
#        ID    S    P  P_S           FORM          LEMMA       GPOS        MORF  \
# INDEX
# 21491   1  472  870    1             Há          haver      V-FIN   PR|3S|IND
# 21492   2  472  870    1            uma             um        ART         F|S
# 21493   3  472  870    1        pequena        pequeno        ADJ         F|S
# 21494   4  472  870    1        parcela        parcela          N         F|S
# 21495   5  472  870    1              ,              -         PU           -
# 21496   6  472  870    1     no_entanto     no_entanto        ADV           -
# 21497   7  472  870    1              ,              -         PU           -
# 21498   8  472  870    1            que            que  PRON-INDP         F|S
# 21499   9  472  870    1              é            ser      V-FIN   PR|3S|IND
# 21500  10  472  870    1  catastrofista  catastrofista        ADJ         F|S
# 21501  11  472  870    1              a              a        PRP           -
# 21502  12  472  870    1              o              o        ART         M|S
# 21503  13  472  870    1          ponto          ponto          N         M|S
# 21504  14  472  870    1             de             de        PRP           -
# 21505  15  472  871    2        afirmar        afirmar      V-INF           -
# 21506  16  472  871    2            que            que     CONJ-S           -
# 21507  17  472  871    2           Lula           Lula       PROP         M|S
# 21508  18  472  871    2         sequer         sequer        ADV           -
# 21509  19  472  871    2     conseguirá      conseguir      V-FIN  FUT|3S|IND
# 21510  20  472  872    3          tomar          tomar      V-INF           -
# 21511  21  472  872    3          posse          posse          N         F|S
# 21512  22  472  872    3              .              -         PU           -
# 21513   1  472  870    1             Há          haver      V-FIN   PR|3S|IND
# 21514   2  472  870    1            uma             um        ART         F|S
# 21515   3  472  870    1        pequena        pequeno        ADJ         F|S
# 21516   4  472  870    1        parcela        parcela          N         F|S
# 21517   5  472  870    1              ,              -         PU           -
# 21518   6  472  870    1     no_entanto     no_entanto        ADV           -
# 21519   7  472  870    1              ,              -         PU           -
# 21520   8  472  870    1            que            que  PRON-INDP         F|S
#
#                CTREE     PRED        ARG  TMP
# INDEX
# 21491      (FCL(VP*)    haver       (V*)    1
# 21492          (NP-*        -       (A1*    1
# 21493              *        -          *    1
# 21494             *)        -         *)    1
# 21495              *        -          *    1
# 21496        (ADVP*)        -  (AM-DIS*)    1
# 21497              *        -          *    1
# 21498  (-NP(FCL(NP*)        -     (C-A1*    1
# 21499          (VP*)        -          *    1
# 21500        (ADJP*)        -          *    1
# 21501           (PP*        -          *    1
# 21502           (NP*        -          *    1
# 21503              *        -          *    1
# 21504           (PP*        -          *    1
# 21505      (ICL(VP*)  afirmar          *    1
# 21506          (FCL*        -          *    1
# 21507          (NP*)        -          *    1
# 21508        (ADVP*)        -          *    1
# 21509          (VP*)        -          *    1
# 21510      (ICL(VP*)    tomar          *    1
# 21511  (NP*)))))))))        -         *)    1
# 21512             *)        -          *    1
# 21513      (FCL(VP*)    haver          *    2
# 21514          (NP-*        -          *    2
# 21515              *        -          *    2
# 21516             *)        -          *    2
# 21517              *        -          *    2
# 21518        (ADVP*)        -          *    2
# 21519              *        -          *    2
# 21520  (-NP(FCL(NP*)        -          *    2

# %% [markdown]
#  ### 1.2 FIXING EXISTING FEATURES
#  #### 1.2.1 FIXING PREDICATE
#   * __PRED__ must be non empty only when ARG is (V*)
#   * Drop column __TMP__

# %%
def fix_pred(df):
    index= (df['TMP'] == df['P_S'])
    df.loc[~index,'PRED']= '-'
    df = df.drop(labels='TMP', axis=1)
    return df

# %%
#Fix predicate 
df = fix_pred(df)
df.head(30)
# Out:
#        ID  S  P  P_S                FORM               LEMMA   GPOS  \
# INDEX
# 0       1  1  0    0            Brasília            Brasília   PROP
# 1       2  1  0    0  Pesquisa_Datafolha  Pesquisa_Datafolha      N
# 2       3  1  0    0           publicada            publicar  V-PCP
# 3       4  1  0    0                hoje                hoje    ADV
# 4       5  1  1    1              revela             revelar  V-FIN
# 5       6  1  1    1                  um                  um    ART
# 6       7  1  1    1                dado                dado      N
# 7       8  1  1    1        supreendente       surpreendente    ADJ
# 8       9  1  1    1                   :                   -     PU
# 9      10  1  2    2           recusando             recusar  V-GER
# 10     11  1  2    2                 uma                  um    ART
# 11     12  1  2    2             postura             postura      N
# 12     13  1  2    2             radical             radical    ADJ
# 13     14  1  2    2                   ,                   -     PU
# 14     15  1  2    2                   a                   o    ART
# 15     16  1  2    2          esmagadora           esmagador    ADJ
# 16     17  1  2    2             maioria             maioria      N
# 17     18  1  2    2                   (                   -     PU
# 18     19  1  2    2                  77                  77    NUM
# 19     20  1  2    2                   %                   %      N
# 20     21  1  2    2                   )                   -     PU
# 21     22  1  2    2                  de                  de    PRP
# 22     23  1  2    2                  os                   o    ART
# 23     24  1  2    2           eleitores             eleitor      N
# 24     25  1  3    3                quer              querer  V-FIN
# 25     26  1  3    3                   o                   o    ART
# 26     27  1  3    3                  PT                  PT   PROP
# 27     28  1  4    4        participando          participar  V-GER
# 28     29  1  4    4                  de                  de    PRP
# 29     30  1  4    4                   o                   o    ART
#
#             MORF          CTREE     PRED   ARG
# INDEX
# 0            F|S      (FCL(NP*)        -     *
# 1            F|S           (NP*        -  (A0*
# 2            F|S      (ICL(VP*)        -     *
# 3              -      (ADVP*)))        -    *)
# 4      PR|3S|IND          (VP*)  revelar  (V*)
# 5            M|S           (NP*        -  (A1*
# 6            M|S              *        -     *
# 7            M|S        (ADJP*)        -     *
# 8              -              *        -     *
# 9              -  (FCL(ICL(VP*)        -     *
# 10           F|S           (NP*        -     *
# 11           F|S              *        -     *
# 12           F|S      (ADJP*)))        -     *
# 13             -              *        -     *
# 14           F|S           (NP*        -     *
# 15           F|S              *        -     *
# 16           F|S              *        -     *
# 17             -              *        -     *
# 18           M|P           (NP*        -     *
# 19           M|P             *)        -     *
# 20             -              *        -     *
# 21             -           (PP*        -     *
# 22           M|P           (NP*        -     *
# 23           M|P           *)))        -     *
# 24     PR|3S|IND          (VP*)        -     *
# 25           M|S           (NP*        -     *
# 26           M|S             *)        -     *
# 27             -      (ICL(VP*)        -     *
# 28             -           (PP*        -     *
# 29           M|S           (NP*        -     *

# %%
# dftest = df[ df['FORM'] == 'no_entanto']
# P in (870, 871, 872)
dftest = df[ df['S'] == 472]
# dftest.loc[21486:21516,:].head()
dftest.head(30)
# Out:
#        ID    S    P  P_S           FORM          LEMMA       GPOS        MORF  \
# INDEX
# 21491   1  472  870    1             Há          haver      V-FIN   PR|3S|IND
# 21492   2  472  870    1            uma             um        ART         F|S
# 21493   3  472  870    1        pequena        pequeno        ADJ         F|S
# 21494   4  472  870    1        parcela        parcela          N         F|S
# 21495   5  472  870    1              ,              -         PU           -
# 21496   6  472  870    1     no_entanto     no_entanto        ADV           -
# 21497   7  472  870    1              ,              -         PU           -
# 21498   8  472  870    1            que            que  PRON-INDP         F|S
# 21499   9  472  870    1              é            ser      V-FIN   PR|3S|IND
# 21500  10  472  870    1  catastrofista  catastrofista        ADJ         F|S
# 21501  11  472  870    1              a              a        PRP           -
# 21502  12  472  870    1              o              o        ART         M|S
# 21503  13  472  870    1          ponto          ponto          N         M|S
# 21504  14  472  870    1             de             de        PRP           -
# 21505  15  472  871    2        afirmar        afirmar      V-INF           -
# 21506  16  472  871    2            que            que     CONJ-S           -
# 21507  17  472  871    2           Lula           Lula       PROP         M|S
# 21508  18  472  871    2         sequer         sequer        ADV           -
# 21509  19  472  871    2     conseguirá      conseguir      V-FIN  FUT|3S|IND
# 21510  20  472  872    3          tomar          tomar      V-INF           -
# 21511  21  472  872    3          posse          posse          N         F|S
# 21512  22  472  872    3              .              -         PU           -
# 21513   1  472  870    1             Há          haver      V-FIN   PR|3S|IND
# 21514   2  472  870    1            uma             um        ART         F|S
# 21515   3  472  870    1        pequena        pequeno        ADJ         F|S
# 21516   4  472  870    1        parcela        parcela          N         F|S
# 21517   5  472  870    1              ,              -         PU           -
# 21518   6  472  870    1     no_entanto     no_entanto        ADV           -
# 21519   7  472  870    1              ,              -         PU           -
# 21520   8  472  870    1            que            que  PRON-INDP         F|S
#
#                CTREE   PRED        ARG
# INDEX
# 21491      (FCL(VP*)  haver       (V*)
# 21492          (NP-*      -       (A1*
# 21493              *      -          *
# 21494             *)      -         *)
# 21495              *      -          *
# 21496        (ADVP*)      -  (AM-DIS*)
# 21497              *      -          *
# 21498  (-NP(FCL(NP*)      -     (C-A1*
# 21499          (VP*)      -          *
# 21500        (ADJP*)      -          *
# 21501           (PP*      -          *
# 21502           (NP*      -          *
# 21503              *      -          *
# 21504           (PP*      -          *
# 21505      (ICL(VP*)      -          *
# 21506          (FCL*      -          *
# 21507          (NP*)      -          *
# 21508        (ADVP*)      -          *
# 21509          (VP*)      -          *
# 21510      (ICL(VP*)      -          *
# 21511  (NP*)))))))))      -         *)
# 21512             *)      -          *
# 21513      (FCL(VP*)      -          *
# 21514          (NP-*      -          *
# 21515              *      -          *
# 21516             *)      -          *
# 21517              *      -          *
# 21518        (ADVP*)      -          *
# 21519              *      -          *
# 21520  (-NP(FCL(NP*)      -          *

# %% [markdown]
#  #### 1.2.2 FIXING P
#   __P__ will be a range like id over the predicates.

# %%
def fix_p(df):
    P=[]
    P_S=[]
    S= list(set(df['S'].values))
    p=1

    for s in S:
        sindex = df['S'] == s
        idx = [int(x) for x in 
            df.loc[sindex,'ID'].values]
        
        P += [p + int(i / idx[-1])
                for i, _ in enumerate(idx)]
        
        P_S += [int(i / idx[-1])
                for i, _ in enumerate(idx)]

        p = P[-1] + 1

    df['P']=P        
    df['P_S']=P_S        
    return df

# %%
df = fix_p(df)
df.head(150)
# Out:
#        ID  S  P  P_S                       FORM                      LEMMA  \
# INDEX
# 0       1  1  1    0                   Brasília                   Brasília
# 1       2  1  1    0         Pesquisa_Datafolha         Pesquisa_Datafolha
# 2       3  1  1    0                  publicada                   publicar
# 3       4  1  1    0                       hoje                       hoje
# 4       5  1  1    0                     revela                    revelar
# 5       6  1  1    0                         um                         um
# 6       7  1  1    0                       dado                       dado
# 7       8  1  1    0               supreendente              surpreendente
# 8       9  1  1    0                          :                          -
# 9      10  1  1    0                  recusando                    recusar
# 10     11  1  1    0                        uma                         um
# 11     12  1  1    0                    postura                    postura
# 12     13  1  1    0                    radical                    radical
# 13     14  1  1    0                          ,                          -
# 14     15  1  1    0                          a                          o
# 15     16  1  1    0                 esmagadora                  esmagador
# 16     17  1  1    0                    maioria                    maioria
# 17     18  1  1    0                          (                          -
# 18     19  1  1    0                         77                         77
# 19     20  1  1    0                          %                          %
# 20     21  1  1    0                          )                          -
# 21     22  1  1    0                         de                         de
# 22     23  1  1    0                         os                          o
# 23     24  1  1    0                  eleitores                    eleitor
# 24     25  1  1    0                       quer                     querer
# 25     26  1  1    0                          o                          o
# 26     27  1  1    0                         PT                         PT
# 27     28  1  1    0               participando                 participar
# 28     29  1  1    0                         de                         de
# 29     30  1  1    0                          o                          o
# ...    .. .. ..  ...                        ...                        ...
# 120    22  1  4    3                         de                         de
# 121    23  1  4    3                         os                          o
# 122    24  1  4    3                  eleitores                    eleitor
# 123    25  1  4    3                       quer                     querer
# 124    26  1  4    3                          o                          o
# 125    27  1  4    3                         PT                         PT
# 126    28  1  4    3               participando                 participar
# 127    29  1  4    3                         de                         de
# 128    30  1  4    3                          o                          o
# 129    31  1  4    3                    Governo                    governo
# 130    32  1  4    3  Fernando_Henrique_Cardoso  Fernando_Henrique_Cardoso
# 131    33  1  4    3                          .                          -
# 132     1  2  5    0                        Tem                        ter
# 133     2  2  5    0                    sentido                    sentido
# 134     3  2  5    0                         --                          -
# 135     4  2  5    0                      aliás                      aliás
# 136     5  2  5    0                          ,                          -
# 137     6  2  5    0                 muitíssimo                 muitíssimo
# 138     7  2  5    0                    sentido                    sentido
# 139     8  2  5    0                          .                          -
# 140     1  3  6    0                        Nem                        nem
# 141     2  3  6    0                       Lula                       Lula
# 142     3  3  6    0                        nem                        nem
# 143     4  3  6    0                          o                          o
# 144     5  3  6    0                    partido                    partido
# 145     6  3  6    0                      ainda                      ainda
# 146     7  3  6    0                encontraram                  encontrar
# 147     8  3  6    0                         um                         um
# 148     9  3  6    0                   discurso                   discurso
# 149    10  3  6    0                       para                       para
#
#            GPOS           MORF          CTREE        PRED        ARG
# INDEX
# 0          PROP            F|S      (FCL(NP*)           -          *
# 1             N            F|S           (NP*           -       (A0*
# 2         V-PCP            F|S      (ICL(VP*)           -          *
# 3           ADV              -      (ADVP*)))           -         *)
# 4         V-FIN      PR|3S|IND          (VP*)     revelar       (V*)
# 5           ART            M|S           (NP*           -       (A1*
# 6             N            M|S              *           -          *
# 7           ADJ            M|S        (ADJP*)           -          *
# 8            PU              -              *           -          *
# 9         V-GER              -  (FCL(ICL(VP*)           -          *
# 10          ART            F|S           (NP*           -          *
# 11            N            F|S              *           -          *
# 12          ADJ            F|S      (ADJP*)))           -          *
# 13           PU              -              *           -          *
# 14          ART            F|S           (NP*           -          *
# 15          ADJ            F|S              *           -          *
# 16            N            F|S              *           -          *
# 17           PU              -              *           -          *
# 18          NUM            M|P           (NP*           -          *
# 19            N            M|P             *)           -          *
# 20           PU              -              *           -          *
# 21          PRP              -           (PP*           -          *
# 22          ART            M|P           (NP*           -          *
# 23            N            M|P           *)))           -          *
# 24        V-FIN      PR|3S|IND          (VP*)           -          *
# 25          ART            M|S           (NP*           -          *
# 26         PROP            M|S             *)           -          *
# 27        V-GER              -      (ICL(VP*)           -          *
# 28          PRP              -           (PP*           -          *
# 29          ART            M|S           (NP*           -          *
# ...         ...            ...            ...         ...        ...
# 120         PRP              -           (PP*           -          *
# 121         ART            M|P           (NP*           -          *
# 122           N            M|P           *)))           -          *
# 123       V-FIN      PR|3S|IND          (VP*)           -          *
# 124         ART            M|S           (NP*           -       (A0*
# 125        PROP            M|S             *)           -         *)
# 126       V-GER              -      (ICL(VP*)  participar       (V*)
# 127         PRP              -           (PP*           -       (A1*
# 128         ART            M|S           (NP*           -          *
# 129           N            M|S              *           -          *
# 130        PROP            M|S     (NP*))))))           -         *)
# 131          PU              -             *)           -          *
# 132       V-FIN      PR|3S|IND      (FCL(VP*)         ter       (V*)
# 133           N            M|S         (NP-*)           -      (A1*)
# 134          PU              -              *           -          *
# 135         ADV              -        (ADVP*)           -  (AM-DIS*)
# 136          PU              -              *           -          *
# 137    PRON-DET            M|S       (-NP(NP*           -     (C-A1*
# 138           N            M|S            *))           -         *)
# 139          PU              -             *)           -          *
# 140      CONJ-C              -       (FCL(CU*           -       (A0*
# 141        PROP            M|S          (NP*)           -          *
# 142      CONJ-C              -              *           -          *
# 143         ART            M|S           (NP*           -          *
# 144           N            M|S            *))           -         *)
# 145         ADV              -        (ADVP*)           -  (AM-ADV*)
# 146       V-FIN  PS/MQP|3P|IND          (VP*)   encontrar       (V*)
# 147         ART            M|S           (NP*           -       (A1*
# 148           N            M|S              *           -          *
# 149         PRP              -              *           -          *
#
# [150 rows x 11 columns]

# %%
# dftest = df[ df['FORM'] == 'no_entanto']
# P in (870, 871, 872)
dftest = df[ df['S'] == 472]
# dftest.loc[21486:21516,:].head()
dftest.head(90)
# Out:
#        ID    S    P  P_S           FORM          LEMMA       GPOS        MORF  \
# INDEX
# 21491   1  472  870    0             Há          haver      V-FIN   PR|3S|IND
# 21492   2  472  870    0            uma             um        ART         F|S
# 21493   3  472  870    0        pequena        pequeno        ADJ         F|S
# 21494   4  472  870    0        parcela        parcela          N         F|S
# 21495   5  472  870    0              ,              -         PU           -
# 21496   6  472  870    0     no_entanto     no_entanto        ADV           -
# 21497   7  472  870    0              ,              -         PU           -
# 21498   8  472  870    0            que            que  PRON-INDP         F|S
# 21499   9  472  870    0              é            ser      V-FIN   PR|3S|IND
# 21500  10  472  870    0  catastrofista  catastrofista        ADJ         F|S
# 21501  11  472  870    0              a              a        PRP           -
# 21502  12  472  870    0              o              o        ART         M|S
# 21503  13  472  870    0          ponto          ponto          N         M|S
# 21504  14  472  870    0             de             de        PRP           -
# 21505  15  472  870    0        afirmar        afirmar      V-INF           -
# 21506  16  472  870    0            que            que     CONJ-S           -
# 21507  17  472  870    0           Lula           Lula       PROP         M|S
# 21508  18  472  870    0         sequer         sequer        ADV           -
# 21509  19  472  870    0     conseguirá      conseguir      V-FIN  FUT|3S|IND
# 21510  20  472  870    0          tomar          tomar      V-INF           -
# 21511  21  472  870    0          posse          posse          N         F|S
# 21512  22  472  870    0              .              -         PU           -
# 21513   1  472  871    1             Há          haver      V-FIN   PR|3S|IND
# 21514   2  472  871    1            uma             um        ART         F|S
# 21515   3  472  871    1        pequena        pequeno        ADJ         F|S
# 21516   4  472  871    1        parcela        parcela          N         F|S
# 21517   5  472  871    1              ,              -         PU           -
# 21518   6  472  871    1     no_entanto     no_entanto        ADV           -
# 21519   7  472  871    1              ,              -         PU           -
# 21520   8  472  871    1            que            que  PRON-INDP         F|S
# ...    ..  ...  ...  ...            ...            ...        ...         ...
# 21527  15  472  871    1        afirmar        afirmar      V-INF           -
# 21528  16  472  871    1            que            que     CONJ-S           -
# 21529  17  472  871    1           Lula           Lula       PROP         M|S
# 21530  18  472  871    1         sequer         sequer        ADV           -
# 21531  19  472  871    1     conseguirá      conseguir      V-FIN  FUT|3S|IND
# 21532  20  472  871    1          tomar          tomar      V-INF           -
# 21533  21  472  871    1          posse          posse          N         F|S
# 21534  22  472  871    1              .              -         PU           -
# 21535   1  472  872    2             Há          haver      V-FIN   PR|3S|IND
# 21536   2  472  872    2            uma             um        ART         F|S
# 21537   3  472  872    2        pequena        pequeno        ADJ         F|S
# 21538   4  472  872    2        parcela        parcela          N         F|S
# 21539   5  472  872    2              ,              -         PU           -
# 21540   6  472  872    2     no_entanto     no_entanto        ADV           -
# 21541   7  472  872    2              ,              -         PU           -
# 21542   8  472  872    2            que            que  PRON-INDP         F|S
# 21543   9  472  872    2              é            ser      V-FIN   PR|3S|IND
# 21544  10  472  872    2  catastrofista  catastrofista        ADJ         F|S
# 21545  11  472  872    2              a              a        PRP           -
# 21546  12  472  872    2              o              o        ART         M|S
# 21547  13  472  872    2          ponto          ponto          N         M|S
# 21548  14  472  872    2             de             de        PRP           -
# 21549  15  472  872    2        afirmar        afirmar      V-INF           -
# 21550  16  472  872    2            que            que     CONJ-S           -
# 21551  17  472  872    2           Lula           Lula       PROP         M|S
# 21552  18  472  872    2         sequer         sequer        ADV           -
# 21553  19  472  872    2     conseguirá      conseguir      V-FIN  FUT|3S|IND
# 21554  20  472  872    2          tomar          tomar      V-INF           -
# 21555  21  472  872    2          posse          posse          N         F|S
# 21556  22  472  872    2              .              -         PU           -
#
#                CTREE     PRED        ARG
# INDEX
# 21491      (FCL(VP*)    haver       (V*)
# 21492          (NP-*        -       (A1*
# 21493              *        -          *
# 21494             *)        -         *)
# 21495              *        -          *
# 21496        (ADVP*)        -  (AM-DIS*)
# 21497              *        -          *
# 21498  (-NP(FCL(NP*)        -     (C-A1*
# 21499          (VP*)        -          *
# 21500        (ADJP*)        -          *
# 21501           (PP*        -          *
# 21502           (NP*        -          *
# 21503              *        -          *
# 21504           (PP*        -          *
# 21505      (ICL(VP*)        -          *
# 21506          (FCL*        -          *
# 21507          (NP*)        -          *
# 21508        (ADVP*)        -          *
# 21509          (VP*)        -          *
# 21510      (ICL(VP*)        -          *
# 21511  (NP*)))))))))        -         *)
# 21512             *)        -          *
# 21513      (FCL(VP*)        -          *
# 21514          (NP-*        -          *
# 21515              *        -          *
# 21516             *)        -          *
# 21517              *        -          *
# 21518        (ADVP*)        -          *
# 21519              *        -          *
# 21520  (-NP(FCL(NP*)        -          *
# ...              ...      ...        ...
# 21527      (ICL(VP*)  afirmar       (V*)
# 21528          (FCL*        -       (A1*
# 21529          (NP*)        -          *
# 21530        (ADVP*)        -          *
# 21531          (VP*)        -          *
# 21532      (ICL(VP*)        -          *
# 21533  (NP*)))))))))        -         *)
# 21534             *)        -          *
# 21535      (FCL(VP*)        -          *
# 21536          (NP-*        -          *
# 21537              *        -          *
# 21538             *)        -          *
# 21539              *        -          *
# 21540        (ADVP*)        -          *
# 21541              *        -          *
# 21542  (-NP(FCL(NP*)        -          *
# 21543          (VP*)        -          *
# 21544        (ADJP*)        -          *
# 21545           (PP*        -          *
# 21546           (NP*        -          *
# 21547              *        -          *
# 21548           (PP*        -          *
# 21549      (ICL(VP*)        -          *
# 21550          (FCL*        -          *
# 21551          (NP*)        -          *
# 21552        (ADVP*)        -          *
# 21553          (VP*)        -          *
# 21554      (ICL(VP*)    tomar       (V*)
# 21555  (NP*)))))))))        -      (A1*)
# 21556             *)        -          *
#
# [66 rows x 11 columns]

# %%
print(df.index)
# Out:
# RangeIndex(start=0, stop=138378, step=1, name='INDEX')

# %%
print(set(df['ARG'].values))
# Out:
# {'(AM-MNR*', '(AM-CAU*', '(C-A0*', '(AM-LOC*', '(C-AM-LOC*', '(AM-LOC*)', '(AM-PNC*)', '(AM-DIR*', '(C-A1*', '(C-A1*)', '(AM-REC*)', '(A2*', '(C-AM-TMP*)', '(C-A2*', '(C-AM-EXT*)', '(A1*)', '(A0*)', '(C-AM-PRD*', '(A2*)', '(AM-EXT*)', '(AM-NEG*', '(A3*', '(AM-DIS*)', '(AM-TMP*', '(C-A3*', '(C-AM-CAU*', '(C-AM-DIS*)', '(AM-CAU*)', '(C-A2*)', '(C-AM-NEG*)', '(C-AM-MNR*', '*)', '(AM-ADV*', '(AM-PNC*', '(AM-PRD*', '(A3*)', '(A1*', '(C-AM-ADV*', '(V*)', '(AM-NEG*)', '(C-V*)', '(A4*', '(AM-MNR*)', '(AM-EXT*', '(A0*', '(A4*)', '(C-AM-TMP*', '(AM-DIS*', '(C-V*', '(C-A0*)', '(AM-ADV*)', '(AM-TMP*)', '(AM-PRD*)', '(AM-REC*', '*'}

# %%
del test_columns[-1]

for label in test_columns:
    tmpdf = df[label].to_frame()
    if tmpdf.isnull().values.any():
        print('there are missing values on required fields')

# %%
df.to_csv('../datasets/csvs/1.0/gs.csv', encoding='utf-8')

# %%
testdf = df.loc[133236:133253,:]
testdf.head(100)
# Out:
#         ID     S     P  P_S       FORM       LEMMA       GPOS         MORF  \
# INDEX
# 133236   2  3165  5538    0         Se          se     CONJ-S            -
# 133237   3  3165  5538    0        for         ser      V-FIN  FUT|3S|SUBJ
# 133238   4  3165  5538    0        uma          um        ART          F|S
# 133239   5  3165  5538    0      greve       greve          N          F|S
# 133240   6  3165  5538    0         só          só        ADV            -
# 133241   7  3165  5538    0        por         por        PRP            -
# 133242   8  3165  5538    0   grevismo    grevismo          N          M|S
# 133243   9  3165  5538    0          ,           -         PU            -
# 133244  10  3165  5538    0         de          de        PRP            -
# 133245  11  3165  5538    0         aí          aí        ADV            -
# 133246  12  3165  5538    0  prejudica  prejudicar      V-FIN    PR|3S|IND
# 133247  13  3165  5538    0          a           a        PRP            -
# 133248  14  3165  5538    0       quem        quem  PRON-INDP        M/F|S
# 133249  15  3165  5538    0          é         ser      V-FIN    PR|3S|IND
# 133250  16  3165  5538    0  favorável   favorável        ADJ        M/F|S
# 133251  17  3165  5538    0          a           a        PRP            -
# 133252  18  3165  5538    0       isso        isso  PRON-INDP          M|S
# 133253  19  3165  5538    0          .           -         PU            -
#
#             CTREE        PRED   ARG
# INDEX
# 133236          *           -     *
# 133237      (VP*)           -     *
# 133238       (NP*           -  (A0*
# 133239          *           -     *
# 133240       (PP*           -     *
# 133241          *           -     *
# 133242   (NP*))))           -    *)
# 133243          *           -     *
# 133244     (ADVP*           -     *
# 133245         *)           -     *
# 133246      (VP*)  prejudicar  (V*)
# 133247       (PP*           -  (A1*
# 133248  (FCL(NP*)           -     *
# 133249      (VP*)           -     *
# 133250     (ADJP*           -     *
# 133251       (PP*           -     *
# 133252  (NP*)))))           -    *)
# 133253         *)           -     *
